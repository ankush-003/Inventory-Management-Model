# %%
# !pip install neuralprophet
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: neuralprophet in /usr/local/lib/python3.9/dist-packages (0.5.3)
# Requirement already satisfied: ipywidgets>=7.5.1 in /usr/local/lib/python3.9/dist-packages (from neuralprophet) (8.0.5)
# Requirement already satisfied: numpy<1.24.0,>=1.15.4 in /usr/local/lib/python3.9/dist-packages (from neuralprophet) (1.22.4)
# Requirement already satisfied: pytorch-lightning<2.0.0,>=1.7 in /usr/local/lib/python3.9/dist-packages (from neuralprophet) (1.9.4)
# Requirement already satisfied: pandas>=1.0.4 in /usr/local/lib/python3.9/dist-packages (from neuralprophet) (1.4.4)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.9/dist-packages (from neuralprophet) (2.11.2)
# Requirement already satisfied: widgetsnbextension>=4.0.5 in /usr/local/lib/python3.9/dist-packages (from neuralprophet) (4.0.6)
# Requirement already satisfied: matplotlib>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from neuralprophet) (3.7.1)
# Requirement already satisfied: dash<2.9 in /usr/local/lib/python3.9/dist-packages (from neuralprophet) (2.8.1)
# Requirement already satisfied: torchmetrics>=0.9.3 in /usr/local/lib/python3.9/dist-packages (from neuralprophet) (0.11.4)
# Requirement already satisfied: plotly>=5.12.0 in /usr/local/lib/python3.9/dist-packages (from neuralprophet) (5.13.1)
# Requirement already satisfied: holidays>=0.20 in /usr/local/lib/python3.9/dist-packages (from neuralprophet) (0.21.13)
# Requirement already satisfied: convertdate>=2.1.2 in /usr/local/lib/python3.9/dist-packages (from neuralprophet) (2.4.0)
# Requirement already satisfied: captum>=0.5.0 in /usr/local/lib/python3.9/dist-packages (from neuralprophet) (0.6.0)
# Requirement already satisfied: plotly-resampler>=0.8.3 in /usr/local/lib/python3.9/dist-packages (from neuralprophet) (0.8.3.2)
# Requirement already satisfied: torch<2.0,>=1.8.0 in /usr/local/lib/python3.9/dist-packages (from neuralprophet) (1.13.1+cu116)
# Requirement already satisfied: LunarCalendar>=0.0.9 in /usr/local/lib/python3.9/dist-packages (from neuralprophet) (0.0.9)
# Requirement already satisfied: python-dateutil>=2.8.0 in /usr/local/lib/python3.9/dist-packages (from neuralprophet) (2.8.2)
# Requirement already satisfied: pymeeus<=1,>=0.3.13 in /usr/local/lib/python3.9/dist-packages (from convertdate>=2.1.2->neuralprophet) (0.5.12)
# Requirement already satisfied: dash-core-components==2.0.0 in /usr/local/lib/python3.9/dist-packages (from dash<2.9->neuralprophet) (2.0.0)
# Requirement already satisfied: dash-html-components==2.0.0 in /usr/local/lib/python3.9/dist-packages (from dash<2.9->neuralprophet) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in /usr/local/lib/python3.9/dist-packages (from dash<2.9->neuralprophet) (5.0.0)
# Requirement already satisfied: Flask>=1.0.4 in /usr/local/lib/python3.9/dist-packages (from dash<2.9->neuralprophet) (2.2.3)
# Requirement already satisfied: hijri-converter in /usr/local/lib/python3.9/dist-packages (from holidays>=0.20->neuralprophet) (2.2.4)
# Requirement already satisfied: korean-lunar-calendar in /usr/local/lib/python3.9/dist-packages (from holidays>=0.20->neuralprophet) (0.3.1)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in /usr/local/lib/python3.9/dist-packages (from ipywidgets>=7.5.1->neuralprophet) (3.0.6)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.9/dist-packages (from ipywidgets>=7.5.1->neuralprophet) (5.7.1)
# Requirement already satisfied: ipython>=6.1.0 in /usr/local/lib/python3.9/dist-packages (from ipywidgets>=7.5.1->neuralprophet) (7.9.0)
# Requirement already satisfied: pytz in /usr/local/lib/python3.9/dist-packages (from LunarCalendar>=0.0.9->neuralprophet) (2022.7.1)
# Requirement already satisfied: ephem>=3.7.5.3 in /usr/local/lib/python3.9/dist-packages (from LunarCalendar>=0.0.9->neuralprophet) (4.1.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=2.0.0->neuralprophet) (23.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=2.0.0->neuralprophet) (1.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=2.0.0->neuralprophet) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=2.0.0->neuralprophet) (0.11.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=2.0.0->neuralprophet) (5.12.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=2.0.0->neuralprophet) (4.39.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=2.0.0->neuralprophet) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=2.0.0->neuralprophet) (8.4.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from plotly>=5.12.0->neuralprophet) (8.2.2)
# Requirement already satisfied: trace-updater>=0.0.8 in /usr/local/lib/python3.9/dist-packages (from plotly-resampler>=0.8.3->neuralprophet) (0.0.9)
# Requirement already satisfied: orjson<4.0.0,>=3.8.0 in /usr/local/lib/python3.9/dist-packages (from plotly-resampler>=0.8.3->neuralprophet) (3.8.8)
# Requirement already satisfied: jupyter-dash>=0.4.2 in /usr/local/lib/python3.9/dist-packages (from plotly-resampler>=0.8.3->neuralprophet) (0.4.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.0->neuralprophet) (1.16.0)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.9/dist-packages (from pytorch-lightning<2.0.0,>=1.7->neuralprophet) (4.5.0)
# Requirement already satisfied: tqdm>=4.57.0 in /usr/local/lib/python3.9/dist-packages (from pytorch-lightning<2.0.0,>=1.7->neuralprophet) (4.65.0)
# Requirement already satisfied: fsspec[http]>2021.06.0 in /usr/local/lib/python3.9/dist-packages (from pytorch-lightning<2.0.0,>=1.7->neuralprophet) (2023.3.0)
# Requirement already satisfied: PyYAML>=5.4 in /usr/local/lib/python3.9/dist-packages (from pytorch-lightning<2.0.0,>=1.7->neuralprophet) (6.0)
# Requirement already satisfied: lightning-utilities>=0.6.0.post0 in /usr/local/lib/python3.9/dist-packages (from pytorch-lightning<2.0.0,>=1.7->neuralprophet) (0.8.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from tensorboard->neuralprophet) (2.2.3)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.9/dist-packages (from tensorboard->neuralprophet) (0.40.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard->neuralprophet) (0.6.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard->neuralprophet) (2.27.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.9/dist-packages (from tensorboard->neuralprophet) (2.16.2)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.9/dist-packages (from tensorboard->neuralprophet) (1.51.3)
# Requirement already satisfied: protobuf<4,>=3.9.2 in /usr/local/lib/python3.9/dist-packages (from tensorboard->neuralprophet) (3.19.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard->neuralprophet) (1.8.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.9/dist-packages (from tensorboard->neuralprophet) (0.4.6)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard->neuralprophet) (67.6.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.9/dist-packages (from tensorboard->neuralprophet) (1.4.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.9/dist-packages (from tensorboard->neuralprophet) (3.4.2)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.9/dist-packages (from Flask>=1.0.4->dash<2.9->neuralprophet) (8.1.3)
# Requirement already satisfied: importlib-metadata>=3.6.0 in /usr/local/lib/python3.9/dist-packages (from Flask>=1.0.4->dash<2.9->neuralprophet) (6.1.0)
# Requirement already satisfied: Jinja2>=3.0 in /usr/local/lib/python3.9/dist-packages (from Flask>=1.0.4->dash<2.9->neuralprophet) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.9/dist-packages (from Flask>=1.0.4->dash<2.9->neuralprophet) (2.1.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.9/dist-packages (from fsspec[http]>2021.06.0->pytorch-lightning<2.0.0,>=1.7->neuralprophet) (3.8.4)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard->neuralprophet) (5.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard->neuralprophet) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard->neuralprophet) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard->neuralprophet) (1.3.1)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib>=2.0.0->neuralprophet) (3.15.0)
# Requirement already satisfied: pygments in /usr/local/lib/python3.9/dist-packages (from ipython>=6.1.0->ipywidgets>=7.5.1->neuralprophet) (2.14.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.9/dist-packages (from ipython>=6.1.0->ipywidgets>=7.5.1->neuralprophet) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.9/dist-packages (from ipython>=6.1.0->ipywidgets>=7.5.1->neuralprophet) (0.7.5)
# Requirement already satisfied: backcall in /usr/local/lib/python3.9/dist-packages (from ipython>=6.1.0->ipywidgets>=7.5.1->neuralprophet) (0.2.0)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.9/dist-packages (from ipython>=6.1.0->ipywidgets>=7.5.1->neuralprophet) (4.8.0)
# Requirement already satisfied: jedi>=0.10 in /usr/local/lib/python3.9/dist-packages (from ipython>=6.1.0->ipywidgets>=7.5.1->neuralprophet) (0.18.2)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from ipython>=6.1.0->ipywidgets>=7.5.1->neuralprophet) (2.0.10)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.9/dist-packages (from jupyter-dash>=0.4.2->plotly-resampler>=0.8.3->neuralprophet) (1.5.6)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.9/dist-packages (from jupyter-dash>=0.4.2->plotly-resampler>=0.8.3->neuralprophet) (5.3.4)
# Requirement already satisfied: retrying in /usr/local/lib/python3.9/dist-packages (from jupyter-dash>=0.4.2->plotly-resampler>=0.8.3->neuralprophet) (1.3.4)
# Requirement already satisfied: ansi2html in /usr/local/lib/python3.9/dist-packages (from jupyter-dash>=0.4.2->plotly-resampler>=0.8.3->neuralprophet) (1.8.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard->neuralprophet) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard->neuralprophet) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard->neuralprophet) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard->neuralprophet) (1.26.15)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.9/dist-packages (from werkzeug>=1.0.1->tensorboard->neuralprophet) (2.1.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning<2.0.0,>=1.7->neuralprophet) (1.3.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.9/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning<2.0.0,>=1.7->neuralprophet) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.9/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning<2.0.0,>=1.7->neuralprophet) (4.0.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning<2.0.0,>=1.7->neuralprophet) (22.2.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning<2.0.0,>=1.7->neuralprophet) (1.8.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.9/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning<2.0.0,>=1.7->neuralprophet) (1.3.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.9/dist-packages (from jedi>=0.10->ipython>=6.1.0->ipywidgets>=7.5.1->neuralprophet) (0.8.3)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.9/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython>=6.1.0->ipywidgets>=7.5.1->neuralprophet) (0.2.6)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.9/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->neuralprophet) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.9/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard->neuralprophet) (3.2.2)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.9/dist-packages (from ipykernel->jupyter-dash>=0.4.2->plotly-resampler>=0.8.3->neuralprophet) (6.2)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.9/dist-packages (from ipykernel->jupyter-dash>=0.4.2->plotly-resampler>=0.8.3->neuralprophet) (6.1.12)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.9/dist-packages (from pexpect->ipython>=6.1.0->ipywidgets>=7.5.1->neuralprophet) (0.7.0)
# Requirement already satisfied: jupyter-core>=4.6.0 in /usr/local/lib/python3.9/dist-packages (from jupyter-client->ipykernel->jupyter-dash>=0.4.2->plotly-resampler>=0.8.3->neuralprophet) (5.3.0)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.9/dist-packages (from jupyter-client->ipykernel->jupyter-dash>=0.4.2->plotly-resampler>=0.8.3->neuralprophet) (23.2.1)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.9/dist-packages (from jupyter-core>=4.6.0->jupyter-client->ipykernel->jupyter-dash>=0.4.2->plotly-resampler>=0.8.3->neuralprophet) (3.1.1)

# %%
import pandas as pd
from neuralprophet import NeuralProphet
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error
import warnings

# %%
warnings.filterwarnings("ignore")
plt.style.use('ggplot')
plt.style.use('fivethirtyeight')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/hashcode11/demand.csv')
df.head()
# Out:
#    Product_Code Warehouse Product_Category       Date Order_Demand
# 0  Product_0993    Whse_J     Category_028  2012/7/27         100
# 1  Product_0979    Whse_J     Category_028  2012/1/19         500
# 2  Product_0979    Whse_J     Category_028   2012/2/3         500
# 3  Product_0979    Whse_J     Category_028   2012/2/9         500
# 4  Product_0979    Whse_J     Category_028   2012/3/2         500

# %%
df.dtypes
df.tail()
# Out:
#          Product_Code Warehouse Product_Category       Date Order_Demand
# 1048570  Product_1791    Whse_J     Category_006  2016/4/27        1000
# 1048571  Product_1974    Whse_J     Category_006  2016/4/27           1
# 1048572  Product_1787    Whse_J     Category_006  2016/4/28        2500
# 1048573  Product_0901    Whse_J     Category_023  2016/10/7          50
# 1048574  Product_0704    Whse_J     Category_001  2016/6/27           4

# %%
df = df[df['Warehouse'] == 'Whse_J']
df
# Out:
#          Product_Code Warehouse Product_Category       Date Order_Demand
# 0        Product_0993    Whse_J     Category_028  2012/7/27         100
# 1        Product_0979    Whse_J     Category_028  2012/1/19         500
# 2        Product_0979    Whse_J     Category_028   2012/2/3         500
# 3        Product_0979    Whse_J     Category_028   2012/2/9         500
# 4        Product_0979    Whse_J     Category_028   2012/3/2         500
# ...               ...       ...              ...        ...          ...
# 1048570  Product_1791    Whse_J     Category_006  2016/4/27        1000
# 1048571  Product_1974    Whse_J     Category_006  2016/4/27           1
# 1048572  Product_1787    Whse_J     Category_006  2016/4/28        2500
# 1048573  Product_0901    Whse_J     Category_023  2016/10/7          50
# 1048574  Product_0704    Whse_J     Category_001  2016/6/27           4
#
# [764447 rows x 5 columns]

# %%
df1 = df[df['Product_Category'] == 'Category_019']

#filtering the other product categories

# %%
df1['Product_Code'].unique()
# Out:
# array(['Product_1234', 'Product_1451', 'Product_1274', 'Product_1512',
#        'Product_1372', 'Product_1900', 'Product_1248', 'Product_1278',
#        'Product_1359', 'Product_1270', 'Product_1486', 'Product_1246',
#        'Product_1262', 'Product_1430', 'Product_1469', 'Product_1250',
#        'Product_1316', 'Product_1410', 'Product_1315', 'Product_1371',
#        'Product_1470', 'Product_1286', 'Product_1489', 'Product_1400',
#        'Product_1357', 'Product_1294', 'Product_1377', 'Product_1452',
#        'Product_1381', 'Product_1632', 'Product_1312', 'Product_1427',
#        'Product_1350', 'Product_1513', 'Product_1996', 'Product_1360',
#        'Product_1264', 'Product_1432', 'Product_2043', 'Product_2047',
#        'Product_2048', 'Product_2045', 'Product_2042', 'Product_2044',
#        'Product_1995', 'Product_1643', 'Product_2046', 'Product_0639',
#        'Product_1226', 'Product_1570', 'Product_1648', 'Product_1651',
#        'Product_1905', 'Product_1901', 'Product_1903', 'Product_1186',
#        'Product_1349', 'Product_1279', 'Product_1394', 'Product_1511',
#        'Product_1280', 'Product_1406', 'Product_2014', 'Product_1391',
#        'Product_1275', 'Product_2003', 'Product_1241', 'Product_1387',
#        'Product_1364', 'Product_1518', 'Product_1477', 'Product_1994',
#        'Product_0832', 'Product_1463', 'Product_1194', 'Product_1523',
#        'Product_1505', 'Product_1219', 'Product_1447', 'Product_1273',
#        'Product_1527', 'Product_1356', 'Product_1218', 'Product_1515',
#        'Product_0831', 'Product_1501', 'Product_0083', 'Product_1552',
#        'Product_1290', 'Product_1287', 'Product_1652', 'Product_1288',
#        'Product_1538', 'Product_0127', 'Product_1295', 'Product_1378',
#        'Product_1382', 'Product_1453', 'Product_1456', 'Product_1455',
#        'Product_1222', 'Product_0098', 'Product_0070', 'Product_0082',
#        'Product_0093', 'Product_1198', 'Product_1193', 'Product_1636',
#        'Product_0079', 'Product_1407', 'Product_0095', 'Product_1398',
#        'Product_1213', 'Product_1622', 'Product_1217', 'Product_1502',
#        'Product_1521', 'Product_1306', 'Product_0406', 'Product_1541',
#        'Product_1418', 'Product_1465', 'Product_1403', 'Product_1479',
#        'Product_1458', 'Product_1454', 'Product_1289', 'Product_1457',
#        'Product_1383', 'Product_1297', 'Product_1380', 'Product_0407',
#        'Product_1637', 'Product_1641', 'Product_1450', 'Product_1416',
#        'Product_1419', 'Product_1420', 'Product_1424', 'Product_1520',
#        'Product_1348', 'Product_1379', 'Product_1355', 'Product_0071',
#        'Product_0064', 'Product_0089', 'Product_1554', 'Product_1216',
#        'Product_1508', 'Product_1401', 'Product_1439', 'Product_1269',
#        'Product_1492', 'Product_1530', 'Product_1493', 'Product_1555',
#        'Product_1459', 'Product_1529', 'Product_1532', 'Product_1531',
#        'Product_0408', 'Product_0409', 'Product_0410', 'Product_0086',
#        'Product_0099', 'Product_0074', 'Product_0055', 'Product_0063',
#        'Product_1259', 'Product_1300', 'Product_1301', 'Product_1305',
#        'Product_1307', 'Product_1309', 'Product_1310', 'Product_1368',
#        'Product_1367', 'Product_1244', 'Product_1304', 'Product_1308',
#        'Product_0066', 'Product_1904', 'Product_1224', 'Product_1556',
#        'Product_1626', 'Product_1540', 'Product_1215', 'Product_1225',
#        'Product_1196', 'Product_1242', 'Product_1202', 'Product_1227',
#        'Product_1285', 'Product_1393', 'Product_1239', 'Product_1468',
#        'Product_1557', 'Product_1404', 'Product_1475', 'Product_1474',
#        'Product_1374', 'Product_1480', 'Product_1399', 'Product_1268',
#        'Product_0640', 'Product_1318', 'Product_1323', 'Product_1328',
#        'Product_1333', 'Product_1338', 'Product_1319', 'Product_1324',
#        'Product_1329', 'Product_1334', 'Product_1339', 'Product_1317',
#        'Product_1322', 'Product_1327', 'Product_1332', 'Product_1337',
#        'Product_1335', 'Product_1330', 'Product_1336', 'Product_1340',
#        'Product_1209', 'Product_0072', 'Product_1385', 'Product_1461',
#        'Product_1496', 'Product_1313', 'Product_1495', 'Product_0080',
#        'Product_0090', 'Product_1499', 'Product_1539', 'Product_1653',
#        'Product_1195', 'Product_1629', 'Product_1231', 'Product_1906',
#        'Product_1534', 'Product_1351', 'Product_1369', 'Product_1256',
#        'Product_1272', 'Product_1438', 'Product_1536', 'Product_1402',
#        'Product_0101', 'Product_1346', 'Product_1296', 'Product_1281',
#        'Product_1243', 'Product_1464', 'Product_1370', 'Product_0061',
#        'Product_0068', 'Product_0054', 'Product_0067', 'Product_1352',
#        'Product_1354', 'Product_1257', 'Product_1210', 'Product_0642',
#        'Product_1578', 'Product_1460', 'Product_1533', 'Product_1624',
#        'Product_1258', 'Product_1254', 'Product_1260', 'Product_1251',
#        'Product_1255', 'Product_1261', 'Product_1425', 'Product_1417',
#        'Product_1201', 'Product_0367', 'Product_1466', 'Product_1375',
#        'Product_1564', 'Product_1899', 'Product_1228', 'Product_1396',
#        'Product_0087', 'Product_1229', 'Product_0837', 'Product_1467',
#        'Product_0641', 'Product_1314', 'Product_1392', 'Product_1478',
#        'Product_1639', 'Product_1909', 'Product_1550', 'Product_1634',
#        'Product_1412', 'Product_1200', 'Product_1240', 'Product_1526',
#        'Product_1506', 'Product_1232', 'Product_1642', 'Product_1546',
#        'Product_1204', 'Product_1449', 'Product_0833', 'Product_1435',
#        'Product_1621', 'Product_1628', 'Product_1236', 'Product_1623',
#        'Product_1388', 'Product_1223', 'Product_1292', 'Product_1635',
#        'Product_1199', 'Product_0062', 'Product_1344', 'Product_1627',
#        'Product_1284', 'Product_1542', 'Product_1649', 'Product_1276',
#        'Product_1247', 'Product_0073', 'Product_1211', 'Product_0065',
#        'Product_1266', 'Product_1271', 'Product_1397', 'Product_1579',
#        'Product_1494', 'Product_0126', 'Product_1345', 'Product_1481',
#        'Product_1436', 'Product_1482', 'Product_1187', 'Product_0081',
#        'Product_1638', 'Product_1630', 'Product_1519', 'Product_1415',
#        'Product_1277', 'Product_1428', 'Product_1429', 'Product_1426',
#        'Product_1252', 'Product_0860', 'Product_0078', 'Product_1205',
#        'Product_1473', 'Product_1509', 'Product_1562', 'Product_1206',
#        'Product_1544', 'Product_1303', 'Product_1389', 'Product_0836',
#        'Product_1188', 'Product_1437', 'Product_1551', 'Product_1471',
#        'Product_1212', 'Product_1500', 'Product_1230', 'Product_1189',
#        'Product_1265', 'Product_1640', 'Product_0056', 'Product_1203',
#        'Product_1543', 'Product_1423', 'Product_1522', 'Product_0861',
#        'Product_1491', 'Product_0862', 'Product_1484', 'Product_1633',
#        'Product_1498', 'Product_1413', 'Product_1497', 'Product_1197',
#        'Product_0058', 'Product_0057', 'Product_0060', 'Product_0059',
#        'Product_1408', 'Product_1207', 'Product_1507', 'Product_1490',
#        'Product_1283', 'Product_1565', 'Product_1559', 'Product_1537',
#        'Product_1547', 'Product_1535', 'Product_0053', 'Product_0830',
#        'Product_1440', 'Product_0085', 'Product_1572', 'Product_1233',
#        'Product_1214', 'Product_1311', 'Product_0865', 'Product_1625',
#        'Product_1569', 'Product_1504', 'Product_1516', 'Product_1390',
#        'Product_1462', 'Product_1411', 'Product_0097', 'Product_1650',
#        'Product_0864', 'Product_1365', 'Product_1386', 'Product_1561',
#        'Product_1487', 'Product_1267', 'Product_0835', 'Product_1191',
#        'Product_0838', 'Product_0088', 'Product_1192', 'Product_0129',
#        'Product_1907', 'Product_1524', 'Product_0069', 'Product_0076',
#        'Product_1575', 'Product_1446', 'Product_1566', 'Product_1320',
#        'Product_1321', 'Product_1325', 'Product_1326', 'Product_1331',
#        'Product_1517', 'Product_1576', 'Product_0834', 'Product_0128',
#        'Product_1302', 'Product_1472', 'Product_1347', 'Product_1414',
#        'Product_1253', 'Product_1373', 'Product_1514', 'Product_1376',
#        'Product_1483', 'Product_1615', 'Product_0096', 'Product_0092',
#        'Product_2151', 'Product_0645', 'Product_0644'], dtype=object)

# %%
df11 = df1[df1['Product_Code'] == 'Product_1359']
df11
# Out:
#          Product_Code Warehouse Product_Category       Date Order_Demand
# 276      Product_1359    Whse_J     Category_019  2012/4/18       80000
# 282      Product_1359    Whse_J     Category_019  2012/5/21       70000
# 289      Product_1359    Whse_J     Category_019  2012/6/26       80000
# 292      Product_1359    Whse_J     Category_019  2012/7/17      100000
# 296      Product_1359    Whse_J     Category_019  2012/8/24      100000
# ...               ...       ...              ...        ...          ...
# 1046514  Product_1359    Whse_J     Category_019  2016/10/3       20000
# 1046515  Product_1359    Whse_J     Category_019  2016/9/16       10000
# 1046516  Product_1359    Whse_J     Category_019  2016/11/1       30000
# 1046517  Product_1359    Whse_J     Category_019  2016/12/1       20000
# 1046518  Product_1359    Whse_J     Category_019  2016/12/9       20000
#
# [16936 rows x 5 columns]

# %%
df11.drop(['Product_Category', 'Product_Code','Warehouse'], axis=1, inplace=True)
df11['Order_Demand'] = df11['Order_Demand'].str.replace('[^0-9-]','').apply(np.int64)
df11['Date'] = pd.to_datetime(df11['Date'])
df11.sort_values(by='Date', inplace = True)
df11
# Out:
#              Date  Order_Demand
# 59646  2012-01-05          1000
# 63099  2012-01-05          5000
# 2577   2012-01-05          2000
# 32610  2012-01-05         10000
# 46739  2012-01-05          5000
# ...           ...           ...
# 870423 2016-12-28          3000
# 863720 2016-12-28         13000
# 864053 2016-12-28         50000
# 877287 2016-12-28          3000
# 921328 2017-01-06        100000
#
# [16936 rows x 2 columns]

# %%
df11 = df11.groupby('Date')['Order_Demand'].sum().reset_index()

# %%
df11
# Out:
#            Date  Order_Demand
# 0    2012-01-05        702000
# 1    2012-01-06        676000
# 2    2012-01-10        783000
# 3    2012-01-11        200000
# 4    2012-01-12        284000
# ...         ...           ...
# 1227 2016-12-22        180000
# 1228 2016-12-26        286000
# 1229 2016-12-27         90000
# 1230 2016-12-28        140000
# 1231 2017-01-06        100000
#
# [1232 rows x 2 columns]

# %%
df11.set_index('Date', inplace=True)
df11
# Out:
#             Order_Demand
# Date
# 2012-01-05        702000
# 2012-01-06        676000
# 2012-01-10        783000
# 2012-01-11        200000
# 2012-01-12        284000
# ...                  ...
# 2016-12-22        180000
# 2016-12-26        286000
# 2016-12-27         90000
# 2016-12-28        140000
# 2017-01-06        100000
#
# [1232 rows x 1 columns]

# %%
def create_feature(dataframe):
    dataframe = dataframe.copy()
    dataframe['day_of_the_week'] = dataframe.index.dayofweek
    dataframe['Quarter'] = dataframe.index.quarter
    dataframe['Month'] = dataframe.index.month
    dataframe['Year'] = dataframe.index.year
    dataframe['Week'] = dataframe.index.isocalendar().week.astype(int)
    return dataframe

df = create_feature(df11)
# features, Target variable
Features = ['day_of_the_week', 'Quarter','Month', 'Year', 'Week']
target = ['Demand']
df
# Out:
#             Order_Demand  day_of_the_week  Quarter  Month  Year  Week
# Date
# 2012-01-05        702000                3        1      1  2012     1
# 2012-01-06        676000                4        1      1  2012     1
# 2012-01-10        783000                1        1      1  2012     2
# 2012-01-11        200000                2        1      1  2012     2
# 2012-01-12        284000                3        1      1  2012     2
# ...                  ...              ...      ...    ...   ...   ...
# 2016-12-22        180000                3        4     12  2016    51
# 2016-12-26        286000                0        4     12  2016    52
# 2016-12-27         90000                1        4     12  2016    52
# 2016-12-28        140000                2        4     12  2016    52
# 2017-01-06        100000                4        1      1  2017     1
#
# [1232 rows x 6 columns]

# %%
fig, ax = plt.subplots(figsize=(20, 5))
sns.boxplot(data=df, x='Week', y='Order_Demand')
ax.set_title('Order Demand per Week')
plt.show()

# %%
# Resample data as Weekly 
df_week = df.resample('W').mean()

# %%
df_week['Order_Demand'].plot(figsize = (15,4), title = 'Weekly Order demand')
plt.show()

# %%
color_pal = sns.color_palette()
df_month = df.resample('MS').mean()
df_month.Order_Demand.plot(figsize = (25,5), title = 'Monthly Order Demand', color = color_pal[2])
plt.ylabel('Order_Demand')
plt.show()

# %%
#for fashion purposes ezez
plt.style.use('fivethirtyeight')

# %%
color_pal = sns.color_palette()
df_Q= df.resample('Q').mean()
df_Q.Order_Demand.plot(figsize = (25,5), title = 'Quarterly Order Demand', color = color_pal[2])
plt.ylabel('Order_Demand')
plt.show()

# %%
#Seasonal decomposition using moving averages
from pylab import rcParams
from statsmodels.tsa.seasonal import seasonal_decompose
rcParams['figure.figsize'] = 25, 10
decomposition = seasonal_decompose(df_month.Order_Demand.values, model='additive', period = 12)
                   
fig = decomposition.plot()
plt.show()

# %%
from datetime import datetime
from datetime import timedelta
train_end = datetime(2016,1,1)
test_end = datetime(2017,1,1)

df_train = df_month[:train_end]
df_test = df_month[train_end:test_end]

# plot train and test dataset on the same graph
fig, ax = plt.subplots(figsize=(15, 5))
df_train.plot(ax=ax, label='Training Set', title='Data Train/Test Split')
df_test.plot(ax=ax, label='Test Set')
ax.axvline('01-01-2016', color='black', ls='--')
ax.legend(['Training Set', 'Test Set','Split Point'])
plt.show()

# %%
df_train.head()
# Out:
#              Order_Demand  day_of_the_week  Quarter  Month    Year       Week
# Date
# 2012-01-01  495055.555556         2.111111      1.0    1.0  2012.0   3.055556
# 2012-02-01  387190.476190         2.000000      1.0    2.0  2012.0   7.000000
# 2012-03-01  370238.095238         2.190476      1.0    3.0  2012.0  11.238095
# 2012-04-01  358400.000000         2.560000      2.0    4.0  2012.0  15.440000
# 2012-05-01  368478.260870         2.217391      2.0    5.0  2012.0  20.130435

# %%
df_train.drop(['day_of_the_week', 'Quarter','Month','Year','Week'], axis=1, inplace=True)
df_test.drop(['day_of_the_week', 'Quarter','Month','Year','Week'], axis=1, inplace=True)

# %%
df_train = df_train.reset_index()
df_test = df_test.reset_index()

# %%
df_train.columns = ['ds','y']
df_test.columns = ['ds','y']
df_train.head()
# Out:
#           ds              y
# 0 2012-01-01  495055.555556
# 1 2012-02-01  387190.476190
# 2 2012-03-01  370238.095238
# 3 2012-04-01  358400.000000
# 4 2012-05-01  368478.260870

# %%
m = NeuralProphet()

# %%
m.fit(df_train, freq='D', epochs=1000)
# Out:
# WARNING - (NP.forecaster.fit) - When Global modeling with local normalization, metrics are displayed in normalized scale.
# WARNING:NP.forecaster:When Global modeling with local normalization, metrics are displayed in normalized scale.
# INFO - (NP.df_utils._infer_frequency) - Major frequency MS corresponds to 89.796% of the data.
# INFO:NP.df_utils:Major frequency MS corresponds to 89.796% of the data.
# WARNING - (NP.df_utils._infer_frequency) - Defined frequency D is different than major frequency MS
# WARNING:NP.df_utils:Defined frequency D is different than major frequency MS
# INFO - (NP.config.init_data_params) - Setting normalization to global as only one dataframe provided for training.
# INFO:NP.config:Setting normalization to global as only one dataframe provided for training.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling weekly seasonality. Run NeuralProphet with weekly_seasonality=True to override this.
# INFO:NP.utils:Disabling weekly seasonality. Run NeuralProphet with weekly_seasonality=True to override this.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling daily seasonality. Run NeuralProphet with daily_seasonality=True to override this.
# INFO:NP.utils:Disabling daily seasonality. Run NeuralProphet with daily_seasonality=True to override this.
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set batch_size to 16
# INFO:NP.config:Auto-set batch_size to 16
# WARNING - (NP.config.set_lr_finder_args) - Learning rate finder: The number of batches (4) is too small than the required number for the learning rate finder (204). The results might not be optimal.
# WARNING:NP.config:Learning rate finder: The number of batches (4) is too small than the required number for the learning rate finder (204). The results might not be optimal.
# WARNING:pytorch_lightning.loggers.tensorboard:Missing logger folder: /content/lightning_logs
# Finding best initial lr:   0%|          | 0/204 [00:00<?, ?it/s]
# Training: 0it [00:00, ?it/s]
#                MAE           RMSE      Loss  RegLoss  epoch
# 0    239333.078125  266885.687500  0.520682      0.0      0
# 1    166009.593750  190075.000000  0.351466      0.0      1
# 2    230457.812500  257720.562500  0.476398      0.0      2
# 3    271559.187500  295960.281250  0.728815      0.0      3
# 4    186831.359375  212528.890625  0.366395      0.0      4
# ..             ...            ...       ...      ...    ...
# 995   48508.222656   52382.859375  0.025841      0.0    995
# 996   35452.707031   39815.777344  0.013853      0.0    996
# 997   37993.226562   41516.804688  0.014332      0.0    997
# 998   39642.039062   43939.566406  0.014746      0.0    998
# 999   37279.312500   41356.273438  0.013710      0.0    999
#
# [1000 rows x 5 columns]

# %%
pred = m.predict(df_test)
pred
# Out:
# INFO - (NP.df_utils._infer_frequency) - Major frequency MS corresponds to 84.615% of the data.
# INFO:NP.df_utils:Major frequency MS corresponds to 84.615% of the data.
# WARNING - (NP.df_utils._infer_frequency) - Defined frequency D is different than major frequency MS
# WARNING:NP.df_utils:Defined frequency D is different than major frequency MS
# INFO - (NP.df_utils._infer_frequency) - Major frequency MS corresponds to 84.615% of the data.
# INFO:NP.df_utils:Major frequency MS corresponds to 84.615% of the data.
# WARNING - (NP.df_utils._infer_frequency) - Defined frequency D is different than major frequency MS
# WARNING:NP.df_utils:Defined frequency D is different than major frequency MS
# Predicting: 4it [00:00, ?it/s]
# INFO - (NP.df_utils.return_df_in_original_format) - Returning df with no ID column
# INFO:NP.df_utils:Returning df with no ID column
#            ds              y         yhat1         trend  season_yearly
# 0  2016-01-01  407722.222222  441257.18750  352544.50000   88712.671875
# 1  2016-02-01  359800.000000  306379.53125  348827.15625  -42447.636719
# 2  2016-03-01  343454.545455  333458.50000  345349.62500  -11891.125977
# 3  2016-04-01  317050.000000  346289.78125  341632.28125    4657.504883
# 4  2016-05-01  342700.000000  348237.87500  338034.84375   10203.044922
# 5  2016-06-01  357727.272727  316458.31250  334317.50000  -17859.162109
# 6  2016-07-01  338476.190476  314106.31250  330720.06250  -16613.730469
# 7  2016-08-01  330190.476190  286152.65625  327002.68750  -40850.027344
# 8  2016-09-01  348000.000000  330828.15625  323285.34375    7542.820312
# 9  2016-10-01  367952.380952  320520.00000  319687.90625     832.114746
# 10 2016-11-01  440700.000000  342221.62500  315970.56250   26251.076172
# 11 2016-12-01  297526.315789  324807.84375  312373.09375   12434.744141
# 12 2017-01-01  100000.000000  382947.00000  308655.75000   74291.226562

# %%
plot1 = m.plot(pred)
# Out:
# WARNING - (NP.plotting.log_warning_resampler_switch_to_valid_env) - Warning: plotly-resampler not supported for the environment you are using. Plotting backend automatically switched to 'plotly' without resampling
# WARNING:NP.plotting:Warning: plotly-resampler not supported for the environment you are using. Plotting backend automatically switched to 'plotly' without resampling

# %%
df_pred = pred[['ds', 'yhat1']]
df_test
# Out:
#            ds              y
# 0  2016-01-01  407722.222222
# 1  2016-02-01  359800.000000
# 2  2016-03-01  343454.545455
# 3  2016-04-01  317050.000000
# 4  2016-05-01  342700.000000
# 5  2016-06-01  357727.272727
# 6  2016-07-01  338476.190476
# 7  2016-08-01  330190.476190
# 8  2016-09-01  348000.000000
# 9  2016-10-01  367952.380952
# 10 2016-11-01  440700.000000
# 11 2016-12-01  297526.315789
# 12 2017-01-01  100000.000000

# %%
df_pred = df_pred.set_index('ds')
df_test = df_test.set_index('ds')

# %%
fig, ax = plt.subplots(figsize=(15, 5))
df_test.plot(ax=ax, label='Training Set', title='Test Set/ Fitted Values First Difference')
df_pred.plot(ax=ax, label='Prediction')
ax.legend(['Test Set', 'Fitted Values'])
plt.show()

# %%
np.sqrt(mean_squared_error(y_true=df_test['y'],
                   y_pred=df_pred['yhat1']))
# Out:
# 88685.36505988093

# %%
mean_absolute_error(y_true=df_test['y'],
                   y_pred=df_pred['yhat1'])
# Out:
# 54978.2247337823

# %%
mean_absolute_percentage_error(y_true=df_test['y'],
                   y_pred=df_pred['yhat1'])
# Out:
# 0.3086016647187685

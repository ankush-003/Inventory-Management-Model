# %%
import random
import pprint
import time
import copy
import uuid

# %%
# import sys
# old_stdout = sys.stdout

# log_file = open("message.log", "w")

# sys.stdout = log_file

# %%
weights = [0,]
for x in range(1001):
    w = random.randint(1,100)
    weights.append(w)

# %%
itemsInfo = {}
binsInfo = {}
probabilites = [0,]
# weights = [0,78, 88, 52, 77, 17, 85, 39, 95, 37, 58, 39, 21,53, 10, 69, 81, 28, 32, 48, 56, 88, 59, 29, 97, 43]
capacitites = [0,60, 100, 150]
costs = [0, 60, 100, 150]


for x in range(1,len(capacitites)):
    probabilites.append(capacitites[x]/costs[x])

for x in range(1, 1001):
    itemsInfo[f"item{x}"] = weights[x]

for x in range(1, 4):
    binsInfo[x] = {
        "cost": capacitites[x],
        "capacity": costs[x],
        "probability":  probabilites[x]
    }

print(itemsInfo,binsInfo)
# Out:
# {'item1': 24, 'item2': 15, 'item3': 18, 'item4': 56, 'item5': 23, 'item6': 39, 'item7': 40, 'item8': 79, 'item9': 16, 'item10': 6, 'item11': 53, 'item12': 67, 'item13': 84, 'item14': 11, 'item15': 79, 'item16': 94, 'item17': 92, 'item18': 10, 'item19': 49, 'item20': 96, 'item21': 45, 'item22': 70, 'item23': 31, 'item24': 38, 'item25': 20, 'item26': 9, 'item27': 62, 'item28': 63, 'item29': 13, 'item30': 71, 'item31': 26, 'item32': 27, 'item33': 47, 'item34': 69, 'item35': 92, 'item36': 71, 'item37': 77, 'item38': 52, 'item39': 44, 'item40': 38, 'item41': 15, 'item42': 90, 'item43': 82, 'item44': 42, 'item45': 42, 'item46': 43, 'item47': 91, 'item48': 20, 'item49': 32, 'item50': 92, 'item51': 52, 'item52': 37, 'item53': 99, 'item54': 11, 'item55': 86, 'item56': 53, 'item57': 51, 'item58': 4, 'item59': 89, 'item60': 58, 'item61': 49, 'item62': 43, 'item63': 73, 'item64': 20, 'item65': 11, 'item66': 43, 'item67': 73, 'item68': 73, 'item69': 96, 'item70': 85, 'item71': 52, 'item72': 17, 'item73': 15, 'item74': 13, 'item75': 41, 'item76': 10, 'item77': 53, 'item78': 72, 'item79': 29, 'item80': 38, 'item81': 34, 'item82': 5, 'item83': 96, 'item84': 94, 'item85': 15, 'item86': 54, 'item87': 56, 'item88': 32, 'item89': 75, 'item90': 16, 'item91': 7, 'item92': 31, 'item93': 65, 'item94': 31, 'item95': 70, 'item96': 25, 'item97': 8, 'item98': 16, 'item99': 84, 'item100': 88, 'item101': 50, 'item102': 93, 'item103': 58, 'item104': 54, 'item105': 68, 'item106': 63, 'item107': 13, 'item108': 85, 'item109': 99, 'item110': 24, 'item111': 33, 'item112': 7, 'item113': 35, 'item114': 85, 'item115': 75, 'item116': 49, 'item117': 48, 'item118': 98, 'item119': 20, 'item120': 69, 'item121': 83, 'item122': 25, 'item123': 58, 'item124': 74, 'item125': 41, 'item126': 15, 'item127': 8, 'item128': 81, 'item129': 98, 'item130': 51, 'item131': 16, 'item132': 99, 'item133': 7, 'item134': 22, 'item135': 90, 'item136': 66, 'item137': 68, 'item138': 83, 'item139': 2, 'item140': 29, 'item141': 46, 'item142': 67, 'item143': 3, 'item144': 64, 'item145': 9, 'item146': 42, 'item147': 70, 'item148': 34, 'item149': 81, 'item150': 91, 'item151': 16, 'item152': 71, 'item153': 60, 'item154': 84, 'item155': 52, 'item156': 5, 'item157': 81, 'item158': 12, 'item159': 76, 'item160': 31, 'item161': 74, 'item162': 55, 'item163': 15, 'item164': 21, 'item165': 73, 'item166': 7, 'item167': 99, 'item168': 14, 'item169': 70, 'item170': 27, 'item171': 2, 'item172': 16, 'item173': 68, 'item174': 52, 'item175': 37, 'item176': 1, 'item177': 48, 'item178': 28, 'item179': 54, 'item180': 40, 'item181': 10, 'item182': 39, 'item183': 90, 'item184': 95, 'item185': 69, 'item186': 32, 'item187': 47, 'item188': 82, 'item189': 38, 'item190': 17, 'item191': 98, 'item192': 72, 'item193': 94, 'item194': 59, 'item195': 1, 'item196': 88, 'item197': 15, 'item198': 82, 'item199': 88, 'item200': 66, 'item201': 88, 'item202': 22, 'item203': 52, 'item204': 45, 'item205': 1, 'item206': 33, 'item207': 29, 'item208': 71, 'item209': 79, 'item210': 64, 'item211': 39, 'item212': 79, 'item213': 28, 'item214': 25, 'item215': 3, 'item216': 80, 'item217': 12, 'item218': 39, 'item219': 90, 'item220': 8, 'item221': 2, 'item222': 68, 'item223': 17, 'item224': 58, 'item225': 46, 'item226': 72, 'item227': 78, 'item228': 79, 'item229': 44, 'item230': 58, 'item231': 49, 'item232': 72, 'item233': 7, 'item234': 38, 'item235': 65, 'item236': 28, 'item237': 20, 'item238': 61, 'item239': 17, 'item240': 93, 'item241': 73, 'item242': 20, 'item243': 9, 'item244': 61, 'item245': 10, 'item246': 21, 'item247': 62, 'item248': 12, 'item249': 66, 'item250': 39, 'item251': 60, 'item252': 6, 'item253': 46, 'item254': 5, 'item255': 1, 'item256': 43, 'item257': 81, 'item258': 36, 'item259': 94, 'item260': 99, 'item261': 100, 'item262': 61, 'item263': 70, 'item264': 74, 'item265': 15, 'item266': 30, 'item267': 22, 'item268': 51, 'item269': 65, 'item270': 81, 'item271': 7, 'item272': 67, 'item273': 37, 'item274': 79, 'item275': 26, 'item276 ...

# %%
def GenerateInitialSolution() :
    solution = {}
    s = 1
    for id,w in itemsInfo.items():
        newId = uuid.uuid4()
        validBinTypes = list(filter(lambda bin : binsInfo[bin]["capacity"] > w,binsInfo ))
        validProbabilites = tuple(map(lambda bin: binsInfo[bin]["probability"], validBinTypes))
        selectedBin = random.choices(validBinTypes,weights=validProbabilites,k=1)[0]
        remainingCapacity = binsInfo[selectedBin]["capacity"] - itemsInfo[id] 
        solution[newId] = {"bin_type": selectedBin, "item_ids": [id], "remaining_capacity": remainingCapacity}
        s+= 1
    return solution

# %%
def Cost(x : dict):
    totalCost = 0
    for info in x.values() :
        totalCost += binsInfo[info["bin_type"]]["cost"]
    return totalCost

# %%
def ChooseNeightbourhood(c1,c2) :
    k = random.choices([1,2],weights=(c1,c2),k=1)[0]
    return k

# %%
def RemainingCapacity(x,id):
    capacity = binsInfo[x[id]["bin_type"]]["capacity"]
    weight = 0
    if len(x[id]["item_ids"]) == 0 :
        return capacity
    for itemId in x[id]["item_ids"]:
        weight += itemsInfo[itemId]
    return capacity - weight

# %%
def GetWeight(id):
    return itemsInfo[id]

def UnpackRepack(x : dict,binId,newCapacity,newBinType) :
    
    cap = newCapacity
    unpackedItems = []

    #Unpacking 
    while cap < 0 :
        unpackedItem = random.choice(x[binId]["item_ids"])
        unpackedItems.append(unpackedItem)
        x[binId]["item_ids"].remove(unpackedItem)
        cap += itemsInfo[unpackedItem]
    x[binId]["remaining_capacity"] = cap

    if (len(x[binId]["item_ids"]) == 0) :
        del x[binId]

    #Repacking
    unpackedItems.sort(key=GetWeight,reverse=True)
    for id in unpackedItems:
        validBins = list(filter(lambda bin: x[bin]["remaining_capacity"] > itemsInfo[id], x.keys()))
        if (len(validBins) == 0):
            newId = uuid.uuid4()
            validBinTypes = list(filter(lambda bin: binsInfo[bin]["capacity"] > itemsInfo[id], binsInfo))
            validProbabilites = tuple(map(lambda bin: binsInfo[bin]["probability"], validBinTypes))
            selectedBin = random.choices(validBinTypes, weights=validProbabilites, k=1)[0]
            remainingCapacity = binsInfo[selectedBin]["capacity"] - itemsInfo[id]
            x[newId] = {"bin_type": selectedBin, "item_ids": [id], "remaining_capacity": remainingCapacity}
        else :
            validProbabilites = tuple(map(lambda bin: x[bin]["remaining_capacity"], validBins))
            # print(f"Item : {id} {itemsInfo[id]} | Bins : {validBins} {validProbabilites}")
            selectedBin = random.choices(validBins, weights=validProbabilites, k=1)[0]
            x[selectedBin]["item_ids"].append(id)
            x[selectedBin]["remaining_capacity"] = RemainingCapacity(x, selectedBin)
            # print(f"{selectedBin} {x[selectedBin]['remaining_capacity']} ")


    return x

# %%
def ValidateSolution(x : dict):
    for id,info in x.items():
        print(f"Bin type : {info['bin_type']} | Item ID : {info['item_ids']} | Remaining Capacity :{info['remaining_capacity']}")
        weight = 0
        for itemId in info['item_ids'] :
            weight += itemsInfo[itemId]
        capacity = binsInfo[info['bin_type']]['capacity']
        # print(f"Calculated Weight {weight} | Calculated Capacity {capacity} | Calculated Remaining Capacity : {capacity - weight}")
        print("")

# %%
def N1(x: dict):
    binIds = list(x.keys())
    selected_length = int(len(binIds)*0.15)
    bin_samples = random.sample(binIds, selected_length)
    for binId in bin_samples:
        newBinType = random.choice(
            [i for i in range(1, 4) if i != x[binId]["bin_type"]])
        oldCapacity = RemainingCapacity(x, binId)
        oldBinType = x[binId]["bin_type"]
        x[binId]["bin_type"] = newBinType
        newCapacity = RemainingCapacity(x, binId)
        x[binId]["remaining_capacity"] = newCapacity
        # print(f"{binId} | New : {newBinType} {newCapacity} | Old : {oldBinType} {oldCapacity}")

        if newCapacity < 0:
            x = UnpackRepack(x, binId, newCapacity, newBinType)
    return x

# %%
def GetBin(x,itemId):
    for id,info in x.items():
        if itemId in info["item_ids"]:
            info["bin_id"] = id
            return info

# %%
def GetCapacity(bin):
    return bin["remaining_capacity"]


def N4(x : dict):
    itemStuff = {}
    for id,info in x.items() :
        for itemId in info["item_ids"]:
            itemStuff[itemId] = {"bin_id": id, "remaining_capacity": info["remaining_capacity"]}
    for id in itemsInfo :
        binA = GetBin(x,id) 
        validBins = list(filter(lambda bin: x[bin]["remaining_capacity"] > itemsInfo[id] and x[bin]["remaining_capacity"] - itemsInfo[id] < binA["remaining_capacity"] and bin != binA["bin_id"], x.keys()))
        validBinInfo = list(map(lambda bin: {"remaining_capacity": x[bin]["remaining_capacity"], "bin_id": bin}, validBins))
        validBinInfo.sort(key=GetCapacity)
        if len(validBinInfo) == 0 :
            continue 
        binB = validBinInfo[0]
        # print(itemsInfo[id],binA, binB)

        x[binA["bin_id"]]["item_ids"].remove(id)
        x[binA["bin_id"]]["remaining_capacity"] = RemainingCapacity(x, binA["bin_id"])
        if (len(x[binA["bin_id"]]["item_ids"]) == 0):
            del x[binA["bin_id"]]

        x[binB["bin_id"]]["item_ids"].append(id)
        x[binB["bin_id"]]["remaining_capacity"] = RemainingCapacity(x, binB["bin_id"])
        
        # print("After Shift :")
        # print(x[binA["bin_id"]], x[binB["bin_id"]])
        # print()
    return x

def N5(x : dict):
    itemStuff = {}
    for id,info in x.items() :
        for itemId in info["item_ids"]:
            itemStuff[itemId] = {"bin_id": id, "remaining_capacity": info["remaining_capacity"]}
    for itemId in itemsInfo:
        binA = GetBin(x,itemId)
        
        aRemainingCApacity = binA["remaining_capacity"]
        validIds = {}
        for id,info in x.items():
            itemIds = info["item_ids"]
            bRemainingCapacity = info["remaining_capacity"]
            itemIds.sort(key=GetWeight,reverse=True)
            swappedId = ""
            for sId in itemIds:
                # print(itemsInfo[sId], bRemainingCapacity + itemsInfo[sId], itemsInfo[itemId])
                if bRemainingCapacity + itemsInfo[sId] > itemsInfo[itemId] and itemsInfo[itemId] > itemsInfo[sId] and bRemainingCapacity + itemsInfo[sId] - itemsInfo[itemId] < aRemainingCApacity:
                    swappedId = sId
            if swappedId == "" :
                continue
            # print(
            #     f"SWAP : {swappedId} {itemsInfo[swappedId]} | Item : {itemId} {itemsInfo[itemId]}   ")
            validIds[swappedId] =  bRemainingCapacity +itemsInfo[swappedId] - itemsInfo[itemId]
        # print("..................")
        finalId = ""
        for ab in validIds.keys() :
            if finalId == "":
                finalId = ab
                continue
            if validIds[finalId] > validIds[ab]:
                finalId = ab
        # print(validIds,finalId)
        if (finalId == ""):
            continue
        binB = GetBin(x,finalId)
        # print(f"Swapping {x[binA['bin_id']]} and {x[binB['bin_id']]}")
        # print(f"binA item : {itemId} {itemsInfo[itemId]} | binB item : {finalId} {itemsInfo[finalId]}")
        # print(f"binA capacity : {binA['remaining_capacity']} binB capacity : {binB['remaining_capacity']}  ")

        x[binA["bin_id"]]["item_ids"].remove(itemId)
        x[binA["bin_id"]]["item_ids"].append(finalId)
        x[binA["bin_id"]]["remaining_capacity"] = RemainingCapacity(x, binA["bin_id"])
        
        x[binB["bin_id"]]["item_ids"].remove(finalId)
        x[binB["bin_id"]]["item_ids"].append(itemId)
        x[binB["bin_id"]]["remaining_capacity"] = RemainingCapacity(x, binB["bin_id"])
        # print(f"new binA capacity : {x[binA['bin_id']]['remaining_capacity']} new binB capacity : {x[binB['bin_id']]['remaining_capacity']}")
    return x

def ChangeBinType(x):
    for id,info in x.items():
        remainingCapacity = info["remaining_capacity"]
        binSize = binsInfo[info["bin_type"]]["capacity"]
        for type,binInfo in binsInfo.items():
            if binSize - remainingCapacity < binInfo["capacity"] and binSize > binInfo["capacity"]:
                x[id]["bin_type"] = type
                x[id]["remaining_capacity"] = RemainingCapacity(x,id)
                # print(type, binInfo["capacity"], remainingCapacity, binSize, RemainingCapacity(x, id), binInfo["capacity"] - binSize + remainingCapacity)
    return x

def LocalSearch(x1):
    x3 = N4(x1)
    # x4 = N5(x3)
    # x5 = N6(x4)

    return x3

def N6(x):
    high = 0
    removeId = ""
    for id,info in x.items():
        if info["remaining_capacity"] > high:
            removeId = id
            high = info["remaining_capacity"]
    itemIds = x[removeId]["item_ids"]

    for itemId in itemIds:
        low = 9999
        addId = ""
        weight = itemsInfo[itemId]
        for id,info in x.items():
            if (info["remaining_capacity"] < low and info["remaining_capacity"] > weight):
                addId = id
                low = info["remaining_capacity"]
        
        if (addId == ""):
            continue
        # print("Doing stuff")
        x[removeId]["item_ids"].remove(itemId)
        x[removeId]["remaining_capacity"] = RemainingCapacity(x, removeId)

        x[addId]["item_ids"].append(itemId)
        x[addId]["remaining_capacity"] = RemainingCapacity(x, addId)
    
    if len(x[removeId]["item_ids"]) == 0:
        del x[removeId]

    return x
    
        


def LocalSearchv2(x1):
    x3 = N4(x1)
    x4 = N5(x3)
    x5 = N6(x4)
    x6 = ChangeBinType(x4)
    return x6

# %%
def N2(x):
    binIds = list(x.keys())
    selected_length = int(len(binIds)*0.05)
    bin_samples = random.sample(binIds, selected_length)
    for binId in bin_samples:
        itemIds = x[binId]["item_ids"]
        del x[binId]
        for id in itemIds:
            newId = uuid.uuid4()
            w = itemsInfo[id]
            validBinTypes = list(filter(lambda bin: binsInfo[bin]["capacity"] > w, binsInfo))
            validProbabilites = tuple(map(lambda bin: binsInfo[bin]["probability"], validBinTypes))
            selectedBin = random.choices(validBinTypes, weights=validProbabilites, k=1)[0]
            remainingCapacity = binsInfo[selectedBin]["capacity"] - itemsInfo[id]
            x[newId] = {"bin_type": selectedBin, "item_ids": [id], "remaining_capacity": remainingCapacity}
    return x

# %%
def Shaking(x, k):
    if (k == 1):
        shook = N1(x)
    if (k == 2):
        shook = N2(x)
    else:
        return x
    return shook

# %%
def N1N2LS():
    x = GenerateInitialSolution()
    # print(f"Initial Bins Used {len(x.keys())}")
    # print(f"Initial Cost {Cost(x)}\n")
    # ValidateSolution(x)
    finish = False
    count = 0
    c1, c2, c3 = 1, 1, 1
    c1Total, c2Total, c3Total = 1,1,1
    total = 0
    startTime = time.time()
    while not finish:
        k = ChooseNeightbourhood(c1/c1Total,c2/c2Total)
        if k == 1:
            c1Total +=1
        if k == 2:
            c2Total +=1
        oldX = copy.deepcopy(x)
        x1 = Shaking(x, 1)
        x2 = LocalSearchv2(x1)
        # print(f"Old Cost : {Cost(oldX)} New Cost : {Cost(x2)}")
        # print(f"Chosen Neighbourhood {k}")
        if (Cost(x2) < Cost(oldX)):
            if (k== 1):
                c1 += 1
            if (k == 2):
                c2 += 1
            updatedTime = time.time()
            x = x2
        else:
            x = oldX
        if (time.time() - startTime > 50):
            finish = True
    totalTime = updatedTime - startTime
    totalBins = len(x.keys())
    print(f"Total Bins Used {totalBins}")
    print(f"Final Optimised Cost {Cost(x)}")
    print(f"Last updated time : {totalTime}")
    print("")
    ValidateSolution(x)

    return totalBins, Cost(x), totalTime


N1N2LS_BINS, N1N2LS_COST, N1N2LS_TIME = N1N2LS()
# Out:
# Total Bins Used 457
# Final Optimised Cost 51630
# Last updated time : 16.30456280708313
#
# Bin type : 1 | Item ID : ['item11', 'item10'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item13', 'item2'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item196', 'item764'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item37', 'item95', 'item481'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item46', 'item9'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item6', 'item48'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item49', 'item32'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item211', 'item25'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item47', 'item60'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item43', 'item72'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item39', 'item73'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item159', 'item63'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item38', 'item91'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item740', 'item903', 'item64', 'item721', 'item223'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item99', 'item41'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item100', 'item14'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item53', 'item101'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item102', 'item87'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item209', 'item393'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item109'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item113', 'item1'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item121', 'item249'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item118', 'item57'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item124', 'item122'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item571', 'item992', 'item561'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item773', 'item251'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item132'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item52', 'item134'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item135', 'item500', 'item76'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item138', 'item136'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item77', 'item141'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item825', 'item662'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item149', 'item137'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item506', 'item419'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item66', 'item98'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item84', 'item156'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item162', 'item58'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item115', 'item562'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item169', 'item79'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item173', 'item23'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item744', 'item489', 'item139'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item583', 'item690'] | Remaining Capacity :10
#
# Bin type : 1 | Item ID : ['item187', 'item158'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item188', 'item190'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item194', 'item7'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item104', 'item204'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item724', 'item5', 'item82'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item210', 'item402', 'item131'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item161', 'item226', 'item600'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item30', 'item213'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item222', 'item94'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item227', 'item36'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item144', 'item229', 'item31', 'item126'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item230', 'item205'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item33', 'item26', 'item215'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item152', 'item236'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item228', 'item237'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item238', 'item40'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item21', 'item337', 'item387'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item247', 'item175'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item253', 'item74'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item619', 'item244'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item216', 'item3', 'item255'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item179', 'item292', 'item418'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item212', 'item263'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item34', 'item266'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item268', 'item177'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item71', 'item271'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item706', 'item272', 'item252'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item273', 'item267'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item281', 'item143'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item282', 'item133'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item283'] | Remaining Capacity :0
#
# Bin type : 2 | Item ID : ['item933', 'item127', 'item286'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item167', 'item288'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item289', 'item202'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item290', 'item155'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item472', 'item772'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item261', 'item396'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item108', 'item294', 'item543'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item146', 'item874', 'item945'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item303', 'item243'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item307', 'item287'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item693', 'item564'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item315', 'item181'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item321'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item323', 'item231'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item968', 'item278', 'item324'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item482', 'item85', 'item171'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item225', 'item334'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item320', 'item499'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item338', 'item221'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item59', 'item347'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item348', 'item147'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item349', 'item27'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item350'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item274', 'item352'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['
] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item505'] | Remaining Capacity :6
#
# Bin type : 3 | Item ID : ['item635', 'item646'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item354', 'item565', 'item801'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item219', 'item250', 'item423'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item548', 'item859', 'item457'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item20', 'item442', 'item168'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item956', 'item382'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item388', 'item595'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item769', 'item360', 'item836'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item531', 'item516'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item314', 'item777'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item555'] | Remaining Capacity :5
#
# Bin type : 2 | Item ID : ['item944', 'item610'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item977'] | Remaining Capacity :2
#
# Bin type : 2 | Item ID : ['item941'] | Remaining Capacity :6
#
# Bin type : 3 | Item ID : ['item408', 'item106', 'item852'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item806', 'item78'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item257', 'item297'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item900', 'item464'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item16', 'item873'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item598', 'item90'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item70', 'item300'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item260'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item589'] | Remaining Capacity :7
#
# Bin type : 2 | Item ID : ['item748', 'item727'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item705'] | Remaining Capacity :5
#
# Bin type : 2 | Item ID : ['item973'] | Remaining Capacity :7
#
# Bin type : 3 | Item ID : ['item120', 'item450', 'item567'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item830', 'item19'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item28', 'item544'] | Remaining Capacity :16
#
# Bin type : 3 | Item ID : ['item330', 'item837'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item308', 'item116'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item697', 'item495'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item847', 'item509'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item976', 'item377', 'item440'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item634', 'item747'] | Remaining Capacity :13
#
# Bin type : 2 | Item ID : ['item890'] | Remaining Capacity :8
#
# Bin type : 3 | Item ID : ['item826', 'item800'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item93', 'item81'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item370'] | Remaining Capacity :8
#
# Bin type : 2 | Item ID : ['item447', 'item245'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item55', 'item29'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item934'] | Remaining Capacity :11
#
# Bin type : 3 | Item ID : ['item12', 'item792', 'item728'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item35'] | Remaining Capacity :8
#
# Bin type : 2 | Item ID : ['item983', 'item119'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item835'] | Remaining Capacity :12
#
# Bin type : 3 | Item ID : ['item633', 'item364'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item819'] | Remaining Capacity :10
#
# Bin type : 3 | Item ID : ['item89', 'item264'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item378', 'item313'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item150', 'item302'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item563'] | Remaining Capacity :8
#
# Bin type : 2 | Item ID : ['item318'] | Remaining Capacity :5
#
# Bin type : 2 | Item ID : ['item661'] | Remaining Capacity :7
#
# Bin type : 2 | Item ID : ['item129'] | Remaining Capacity :2
#
# Bin type : 3 | Item ID : ['item776', 'item224'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item887', 'item642'] | Remaining Capacity :13
#
# Bin type : 3 | Item ID : ['item306', 'item456'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item614', 'item123'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item593', 'item332'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item573'] | Remaining Capacity :11
#
# Bin type : 3 | Item ID : ['item422', 'item554'] | Remaining Capacity :1

# %%
def N1N4N5N6():
    x = GenerateInitialSolution()
    # print(f"Initial Bins Used {len(x.keys())}")
    # print(f"Initial Cost {Cost(x)}\n")
    # ValidateSolution(x)
    finish = False
    count = 0
    c1, c2, c3 = 0, 1, 1
    startTime = time.time()
    while not finish:
        #     # k = ChooseNeightbourhood(c1,c2,c3)
        oldX = copy.deepcopy(x)
        count += 1
        x1 = Shaking(x, 1)
        x2 = LocalSearchv2(x1)
        # print(f"Old Cost : {Cost(oldX)} New Cost : {Cost(x2)}")
        if (Cost(x2) < Cost(oldX)):
            c1 += 1
            updatedTime = time.time()
            x = x2
        else:
            x = oldX
        if (time.time() - startTime > 50):
            finish = True
    totalTime = updatedTime - startTime
    totalBins = len(x.keys())
    print(f"Total Bins Used {totalBins}")
    print(f"Final Optimised Cost {Cost(x)}")
    print(f"Last updated time : {totalTime}")
    print(c1)
    print("")
    ValidateSolution(x)

    return totalBins, Cost(x), totalTime

N1N4N5N6_BINS,N1N4N5N6_COST,N1N4N5N6_TIME = N1N4N5N6()
# Out:
# Total Bins Used 453
# Final Optimised Cost 51570
# Last updated time : 17.94641947746277
# 5
#
# Bin type : 1 | Item ID : ['item11', 'item10'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item238', 'item24'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item19', 'item18'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item39', 'item2'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item42', 'item26'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item8', 'item48'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item4', 'item66'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item68', 'item31'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item43', 'item72'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item60', 'item75'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item347', 'item175', 'item221'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item78', 'item32'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item13', 'item85'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item89', 'item36', 'item486'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item895', 'item337', 'item869', 'item176'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item93', 'item81'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item95', 'item79'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item331', 'item376'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item104', 'item21'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item105', 'item23'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item109', 'item101'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item169', 'item140'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item117', 'item14'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item125', 'item3'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item99', 'item126'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item47', 'item127'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item118', 'item130'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item392', 'item990'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item52', 'item134'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item137', 'item92'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item605', 'item403', 'item640'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item77', 'item141'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item70', 'item144'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item153'] | Remaining Capacity :0
#
# Bin type : 1 | Item ID : ['item86', 'item156'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item33', 'item158'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item159', 'item63'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item115', 'item161'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item16', 'item162'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item149', 'item173'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item160', 'item178'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item263', 'item182', 'item64', 'item25'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item184', 'item179'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item12', 'item186'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item188', 'item142'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item261', 'item94', 'item717'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item194', 'item7'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item123', 'item704', 'item58', 'item195'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item198', 'item958', 'item190'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item200', 'item111'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item203', 'item91'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item204', 'item168'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item129', 'item205'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item209', 'item396', 'item164'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item108', 'item210'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item212', 'item22'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item216', 'item311'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item229', 'item957', 'item255'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item44', 'item223'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item37', 'item226'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item45', 'item239'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item100', 'item244'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item116', 'item245'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item251', 'item211'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item270', 'item738'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item258', 'item5'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item259', 'item82'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item849', 'item192'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item336', 'item364', 'item148', 'item654', 'item497'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item264', 'item122'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item120', 'item266'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item268', 'item177'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item274', 'item147'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item106', 'item278'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item320', 'item225', 'item870'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item281', 'item256'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item282', 'item187'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item53', 'item288'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item289', 'item202'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item291', 'item284'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item293', 'item139'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item128', 'item297'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item489', 'item528', 'item675'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item303', 'item243'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item744', 'item841'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item309', 'item236'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item375', 'item231', 'item734', 'item438'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item321'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item323'] | Remaining Capacity :0
#
# Bin type : 1 | Item ID : ['
] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item976', 'item667', 'item460', 'item674'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item55', 'item411'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item227', 'item28', 'item383'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item467', 'item484'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item589', 'item87'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item193', 'item656'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item412'] | Remaining Capacity :7
#
# Bin type : 2 | Item ID : ['item504', 'item710'] | Remaining Capacity :2
#
# Bin type : 2 | Item ID : ['item201', 'item892'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item817', 'item824', 'item197'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item863', 'item764'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item102', 'item629'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item422', 'item237'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item388', 'item581'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item348', 'item247', 'item882'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item350'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item814', 'item560'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item922', 'item494'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item540', 'item530'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item529', 'item542', 'item952'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item865', 'item711'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item290', 'item310'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item415', 'item800'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item558', 'item644'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item228', 'item397'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item408', 'item275'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item548', 'item56'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item933'] | Remaining Capacity :11
#
# Bin type : 2 | Item ID : ['item773', 'item181'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item732', 'item119'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item439', 'item515'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item669', 'item41'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item930', 'item596'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item809'] | Remaining Capacity :5
#
# Bin type : 3 | Item ID : ['item829', 'item51'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item443', 'item340'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item344', 'item294'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item941'] | Remaining Capacity :6
#
# Bin type : 3 | Item ID : ['item349', 'item351'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item150', 'item230'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item946'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item359', 'item272'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item637'] | Remaining Capacity :13
#
# Bin type : 2 | Item ID : ['item404'] | Remaining Capacity :5
#
# Bin type : 2 | Item ID : ['item826', 'item302'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item621', 'item298'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item719', 'item904'] | Remaining Capacity :4
#
# Bin type : 3 | Item ID : ['item963', 'item594'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item154', 'item163'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item526'] | Remaining Capacity :7
#
# Bin type : 3 | Item ID : ['item240', 'item683', 'item431'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item877', 'item27'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item755', 'item857', 'item46'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item34', 'item487', 'item90'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item335', 'item591'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item322'] | Remaining Capacity :4
#
# Bin type : 3 | Item ID : ['item325', 'item38'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item718', 'item966'] | Remaining Capacity :13
#
# Bin type : 3 | Item ID : ['item962', 'item57'] | Remaining Capacity :2
#
# Bin type : 2 | Item ID : ['item769', 'item767'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item513', 'item103', 'item859'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item722', 'item301'] | Remaining Capacity :1

# %%
def N1N4():
    x = GenerateInitialSolution()
    # print(f"Initial Bins Used {len(x.keys())}")
    # print(f"Initial Cost {Cost(x)}\n")
    # ValidateSolution(x)
    finish = False
    count = 0
    c1, c2, c3 = 0, 1, 1
    startTime = time.time()
    while not finish:
        #     # k = ChooseNeightbourhood(c1,c2,c3)
        oldX = copy.deepcopy(x)
        count += 1
        x1 = Shaking(x, 1)
        x2 = LocalSearch(x1)
        # print(f"Old Cost : {Cost(oldX)} New Cost : {Cost(x2)}")
        if (Cost(x2) < Cost(oldX)):
            c1 += 1
            updatedTime = time.time()
            x = x2
        else:
            x = oldX
        if (time.time() - startTime > 50):
            finish = True
    totalTime = updatedTime - startTime
    totalBins = len(x.keys())
    print(f"Total Bins Used {totalBins}")
    print(f"Final Optimised Cost {Cost(x)}")
    print(f"Last updated time : {totalTime}")
    print(c1)
    print("")
    ValidateSolution(x)

    return totalBins,Cost(x),totalTime

N1N4_BINS,N1N4_COST,N1N4_TIME = N1N4()
# Out:
# Total Bins Used 445
# Final Optimised Cost 51750
# Last updated time : 24.866806268692017
# 8
#
# Bin type : 2 | Item ID : ['item13', 'item2'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item20', 'item11'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item38', 'item33'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item42', 'item899', 'item334'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item53'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item56', 'item10'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item59', 'item21', 'item295'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item888', 'item794', 'item84', 'item139'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item6', 'item281', 'item299'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item68', 'item461', 'item221'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item95', 'item79'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item97', 'item47'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item99', 'item655', 'item44'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item109'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item116', 'item101'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item648', 'item531', 'item833'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item124', 'item89'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item764', 'item199'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item638', 'item152'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item118', 'item681'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item132'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item136', 'item111'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item142', 'item49'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item145', 'item135'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item150', 'item127'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item154', 'item73'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item16', 'item305', 'item317'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item162', 'item58', 'item7'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item165', 'item67', 'item486'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item169', 'item140'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item172', 'item138'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item521', 'item680', 'item120', 'item297'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item186', 'item170'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item187', 'item158'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item190', 'item813'] | Remaining Capacity :5
#
# Bin type : 3 | Item ID : ['item70', 'item347', 'item761'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item196', 'item14'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item201', 'item194'] | Remaining Capacity :3
#
# Bin type : 2 | Item ID : ['item206', 'item200'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item251', 'item250'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item209', 'item48'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item722', 'item238', 'item254'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item216', 'item34'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item106', 'item258'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item219', 'item602'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item231', 'item181'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item233', 'item17'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item237', 'item212'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item241', 'item159'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item244', 'item40'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item433', 'item360', 'item936', 'item760'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item255', 'item191', 'item557', 'item176'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item262', 'item100'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item263', 'item228'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item264', 'item96'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item270', 'item3'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item271', 'item71'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item274', 'item242'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item277', 'item45'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item167', 'item455'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item279', 'item36'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item280', 'item268'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item594', 'item195', 'item92'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item291', 'item157'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item310', 'item91'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item987', 'item78', 'item345', 'item438'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item60', 'item819'] | Remaining Capacity :2
#
# Bin type : 2 | Item ID : ['item316', 'item266'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item324', 'item113'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item335', 'item314'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item336', 'item292'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item338', 'item35'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item340', 'item141'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item341', 'item80'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item863', 'item754'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item349', 'item217'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item355', 'item146', 'item762', 'item406'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item540', 'item400', 'item698'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item362', 'item129', 'item207', 'item164'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item211', 'item571'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item369', 'item339'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['
] | Remaining Capacity :2
#
# Bin type : 3 | Item ID : ['item725', 'item375'] | Remaining Capacity :7
#
# Bin type : 1 | Item ID : ['item276', 'item384'] | Remaining Capacity :3
#
# Bin type : 2 | Item ID : ['item392'] | Remaining Capacity :7
#
# Bin type : 3 | Item ID : ['item644', 'item541'] | Remaining Capacity :2
#
# Bin type : 3 | Item ID : ['item303', 'item550'] | Remaining Capacity :2
#
# Bin type : 3 | Item ID : ['item198', 'item131', 'item578'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item625', 'item168'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item261', 'item61'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item405', 'item285'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item834', 'item137'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item506', 'item208'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item984', 'item315'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item260'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item785', 'item924'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item650', 'item46', 'item287'] | Remaining Capacity :2
#
# Bin type : 2 | Item ID : ['item705'] | Remaining Capacity :5
#
# Bin type : 2 | Item ID : ['item770', 'item585'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item401', 'item909'] | Remaining Capacity :15
#
# Bin type : 3 | Item ID : ['item766', 'item666'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item821', 'item431', 'item123'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item306'] | Remaining Capacity :6
#
# Bin type : 2 | Item ID : ['item105', 'item23'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item548', 'item652'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item973'] | Remaining Capacity :7
#
# Bin type : 2 | Item ID : ['item930'] | Remaining Capacity :2
#
# Bin type : 3 | Item ID : ['item577', 'item22'] | Remaining Capacity :6
#
# Bin type : 3 | Item ID : ['item965', 'item757'] | Remaining Capacity :2
#
# Bin type : 2 | Item ID : ['item371'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item103', 'item75'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item809', 'item969'] | Remaining Capacity :2
#
# Bin type : 2 | Item ID : ['item350'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item835', 'item975'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item977'] | Remaining Capacity :2
#
# Bin type : 2 | Item ID : ['item443'] | Remaining Capacity :4
#
# Bin type : 3 | Item ID : ['item318', 'item104'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item769', 'item436'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item43', 'item816'] | Remaining Capacity :3
#
# Bin type : 3 | Item ID : ['item283', 'item253'] | Remaining Capacity :4
#
# Bin type : 2 | Item ID : ['item472', 'item394'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item990', 'item890'] | Remaining Capacity :2
#
# Bin type : 2 | Item ID : ['item184'] | Remaining Capacity :5
#
# Bin type : 2 | Item ID : ['item829'] | Remaining Capacity :3
#
# Bin type : 2 | Item ID : ['item272', 'item94'] | Remaining Capacity :2
#
# Bin type : 3 | Item ID : ['item715', 'item364'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item787'] | Remaining Capacity :10
#
# Bin type : 3 | Item ID : ['item629', 'item526'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item128', 'item12'] | Remaining Capacity :2
#
# Bin type : 3 | Item ID : ['item488', 'item385'] | Remaining Capacity :3
#
# Bin type : 3 | Item ID : ['item864', 'item28'] | Remaining Capacity :2
#
# Bin type : 3 | Item ID : ['item688', 'item396'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item114'] | Remaining Capacity :15
#
# Bin type : 3 | Item ID : ['item183', 'item902'] | Remaining Capacity :3
#
# Bin type : 2 | Item ID : ['item414'] | Remaining Capacity :6
#
# Bin type : 3 | Item ID : ['item546', 'item900'] | Remaining Capacity :4
#
# Bin type : 2 | Item ID : ['item737', 'item5'] | Remaining Capacity :3
#
# Bin type : 3 | Item ID : ['item925', 'item294', 'item76'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item173', 'item693'] | Remaining Capacity :2
#
# Bin type : 2 | Item ID : ['item963', 'item72'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item713', 'item147'] | Remaining Capacity :2
#
# Bin type : 3 | Item ID : ['item323', 'item844'] | Remaining Capacity :6
#
# Bin type : 3 | Item ID : ['item691', 'item702', 'item807'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item732', 'item223'] | Remaining Capacity :4
#
# Bin type : 3 | Item ID : ['item896', 'item232'] | Remaining Capacity :4
#
# Bin type : 2 | Item ID : ['item849', 'item395'] | Remaining Capacity :3
#
# Bin type : 2 | Item ID : ['item149', 'item98'] | Remaining Capacity :3
#
# Bin type : 3 | Item ID : ['item726', 'item839', 'item457'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item832', 'item672'] | Remaining Capacity :4
#
# Bin type : 2 | Item ID : ['item915'] | Remaining Capacity :2
#
# Bin type : 3 | Item ID : ['item69', 'item77'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item352', 'item236'] | Remaining Capacity :2
#
# Bin type : 3 | Item ID : ['item706', 'item419'] | Remaining Capacity :3
#
# Bin type : 3 | Item ID : ['item918', 'item538'] | Remaining Capacity :4
#
# Bin type : 3 | Item ID : ['item320', 'item27'] | Remaining Capacity :3
#
# Bin type : 2 | Item ID : ['item941'] | Remaining Capacity :6
#
# Bin type : 2 | Item ID : ['item746', 'item453'] | Remaining Capacity :3

# %%
def OnlyN1():
    # t0 = time.time()
    x = GenerateInitialSolution()
    # print(f"Initial Bins Used {len(x.keys())}")
    # print(f"Initial Cost {Cost(x)}\n")
    # ValidateSolution(x)
    
    finish = False
    count = 0
    c1,c2,c3 = 0,1,1
    startTime = time.time()
    while not finish:
    #     # k = ChooseNeightbourhood(c1,c2,c3)
        oldX = copy.deepcopy(x)
        count +=1
        x1 = Shaking(x,1)
        # print(f"Old Cost : {Cost(oldX)} New Cost : {Cost(x1)}")
        if (Cost(x1) < Cost(oldX)):
            c1+=1
            updatedTime = time.time()
            x = x1
        else :
            x = oldX
        if (time.time() - startTime > 50):
            finish = True
    totalTime = updatedTime - startTime
    totalBins = len(x.keys())
    print(f"Total Bins Used {totalBins}")
    print(f"Final Optimised Cost {Cost(x)}")
    print(f"Last updated time : {totalTime}")
    print(c1)
    print("")
    ValidateSolution(x)

    return totalBins, Cost(x), totalTime

N1_BINS,N1_COST,N1_TIME = OnlyN1()
# Out:
# Total Bins Used 520
# Final Optimised Cost 57690
# Last updated time : 45.85932540893555
# 51
#
# Bin type : 1 | Item ID : ['item606', 'item301'] | Remaining Capacity :4
#
# Bin type : 2 | Item ID : ['item146', 'item477'] | Remaining Capacity :6
#
# Bin type : 3 | Item ID : ['item849', 'item627'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item20'] | Remaining Capacity :4
#
# Bin type : 2 | Item ID : ['item760', 'item684'] | Remaining Capacity :5
#
# Bin type : 3 | Item ID : ['item26', 'item710', 'item414'] | Remaining Capacity :24
#
# Bin type : 2 | Item ID : ['item544', 'item876'] | Remaining Capacity :13
#
# Bin type : 1 | Item ID : ['item575'] | Remaining Capacity :6
#
# Bin type : 2 | Item ID : ['item117', 'item883'] | Remaining Capacity :18
#
# Bin type : 2 | Item ID : ['item56'] | Remaining Capacity :47
#
# Bin type : 2 | Item ID : ['item57', 'item926'] | Remaining Capacity :44
#
# Bin type : 2 | Item ID : ['item58', 'item474', 'item253', 'item683'] | Remaining Capacity :5
#
# Bin type : 2 | Item ID : ['item7', 'item485'] | Remaining Capacity :27
#
# Bin type : 2 | Item ID : ['item355', 'item716'] | Remaining Capacity :10
#
# Bin type : 2 | Item ID : ['item658', 'item837'] | Remaining Capacity :11
#
# Bin type : 2 | Item ID : ['item133', 'item38', 'item878'] | Remaining Capacity :26
#
# Bin type : 1 | Item ID : ['item310'] | Remaining Capacity :8
#
# Bin type : 3 | Item ID : ['item88', 'item709', 'item646', 'item748'] | Remaining Capacity :3
#
# Bin type : 2 | Item ID : ['item92', 'item247'] | Remaining Capacity :7
#
# Bin type : 3 | Item ID : ['item25', 'item432', 'item713'] | Remaining Capacity :35
#
# Bin type : 3 | Item ID : ['item502', 'item651', 'item316'] | Remaining Capacity :6
#
# Bin type : 2 | Item ID : ['item101', 'item580'] | Remaining Capacity :17
#
# Bin type : 1 | Item ID : ['item662'] | Remaining Capacity :4
#
# Bin type : 1 | Item ID : ['item955'] | Remaining Capacity :28
#
# Bin type : 3 | Item ID : ['item112', 'item652', 'item519'] | Remaining Capacity :11
#
# Bin type : 2 | Item ID : ['item113', 'item673', 'item326'] | Remaining Capacity :23
#
# Bin type : 1 | Item ID : ['item356'] | Remaining Capacity :17
#
# Bin type : 3 | Item ID : ['item936', 'item35'] | Remaining Capacity :7
#
# Bin type : 3 | Item ID : ['item123', 'item331'] | Remaining Capacity :10
#
# Bin type : 3 | Item ID : ['item125', 'item661', 'item833'] | Remaining Capacity :13
#
# Bin type : 2 | Item ID : ['item610', 'item275', 'item678'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item830'] | Remaining Capacity :0
#
# Bin type : 3 | Item ID : ['item545', 'item195', 'item351', 'item155'] | Remaining Capacity :7
#
# Bin type : 2 | Item ID : ['item139', 'item382', 'item97'] | Remaining Capacity :53
#
# Bin type : 1 | Item ID : ['item206', 'item444'] | Remaining Capacity :24
#
# Bin type : 2 | Item ID : ['item70', 'item438'] | Remaining Capacity :14
#
# Bin type : 1 | Item ID : ['item156', 'item309'] | Remaining Capacity :24
#
# Bin type : 3 | Item ID : ['item124', 'item106'] | Remaining Capacity :13
#
# Bin type : 1 | Item ID : ['item765', 'item6'] | Remaining Capacity :20
#
# Bin type : 1 | Item ID : ['item164', 'item213', 'item698', 'item171'] | Remaining Capacity :6
#
# Bin type : 2 | Item ID : ['item170', 'item487'] | Remaining Capacity :9
#
# Bin type : 2 | Item ID : ['item175', 'item852', 'item762'] | Remaining Capacity :7
#
# Bin type : 2 | Item ID : ['item177', 'item723'] | Remaining Capacity :9
#
# Bin type : 3 | Item ID : ['item985', 'item5', 'item23', 'item190'] | Remaining Capacity :17
#
# Bin type : 2 | Item ID : ['item841', 'item354'] | Remaining Capacity :6
#
# Bin type : 2 | Item ID : ['item740'] | Remaining Capacity :27
#
# Bin type : 1 | Item ID : ['item603', 'item90'] | Remaining Capacity :12
#
# Bin type : 3 | Item ID : ['item197', 'item981', 'item643', 'item409'] | Remaining Capacity :10
#
# Bin type : 1 | Item ID : ['item867'] | Remaining Capacity :8
#
# Bin type : 1 | Item ID : ['item205', 'item645'] | Remaining Capacity :18
#
# Bin type : 2 | Item ID : ['item977'] | Remaining Capacity :2
#
# Bin type : 3 | Item ID : ['item211', 'item880', 'item626'] | Remaining Capacity :12
#
# Bin type : 2 | Item ID : ['item214', 'item27'] | Remaining Capacity :13
#
# Bin type : 1 | Item ID : ['item131', 'item679', 'item562'] | Remaining Capacity :4
#
# Bin type : 3 | Item ID : ['item220', 'item972', 'item676'] | Remaining Capacity :12
#
# Bin type : 3 | Item ID : ['item221', 'item811', 'item620', 'item947', 'item248', 'item670'] | Remaining Capacity :6
#
# Bin type : 3 | Item ID : ['item222', 'item32', 'item771'] | Remaining Capacity :25
#
# Bin type : 3 | Item ID : ['item223', 'item664', 'item353', 'item420'] | Remaining Capacity :9
#
# Bin type : 2 | Item ID : ['item224', 'item734'] | Remaining Capacity :12
#
# Bin type : 2 | Item ID : ['item237', 'item126', 'item592'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item857', 'item359'] | Remaining Capacity :25
#
# Bin type : 1 | Item ID : ['item266', 'item560'] | Remaining Capacity :12
#
# Bin type : 3 | Item ID : ['item271', 'item795', 'item264'] | Remaining Capacity :24
#
# Bin type : 3 | Item ID : ['item276', 'item640', 'item114'] | Remaining Capacity :9
#
# Bin type : 2 | Item ID : ['item9', 'item121'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item417', 'item315'] | Remaining Capacity :10
#
# Bin type : 3 | Item ID : ['item288', 'item976'] | Remaining Capacity :13
#
# Bin type : 3 | Item ID : ['item667', 'item115', 'item639'] | Remaining Capacity :2
#
# Bin type : 2 | Item ID : ['item37'] | Remaining Capacity :23
#
# Bin type : 2 | Item ID : ['item533', 'item210'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item840', 'item983'] | Remaining Capacity :13
#
# Bin type : 1 | Item ID : ['item730'] | Remaining Capacity :52
#
# Bin type : 1 | Item ID : ['item300', 'item258'] | Remaining Capacity :10
#
# Bin type : 1 | Item ID : ['item312', 'item728'] | Remaining Capacity :9
#
# Bin type : 1 | Item ID : ['item391'] | Remaining Capacity :13
#
# Bin type : 3 | Item ID : ['item122', 'item550', 'item707'] | Remaining Capacity :2
#
# Bin type : 3 | Item ID : ['item340', 'item994'] | Remaining Capacity :26
#
# Bin type : 1 | Item ID : ['item690', 'item52'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item973'] | Remaining Capacity :7
#
# Bin type : 1 | Item ID : ['item166', 'item297'] | Remaining Capacity :35
#
# Bin type : 3 | Item ID : ['item361', 'item547', 'item720'] | Remaining Capacity :72
#
# Bin type : 3 | Item ID : ['item631', 'item212', 'item72'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item366', 'item945', 'item767', 'item255', 'item329'] | Remaining Capacity :19
#
# Bin type : 2 | Item ID : ['item367', 'item514', 'item252', 'item967'] | Remaining Capacity :5
#
# Bin type : 1 | Item ID : ['item369', 'item494'] | Remaining Capacity :5
#
# Bin type : 1 | Item ID : ['item374'] | Remaining Capacity :6
#
# Bin type : 2 | Item ID : ['item377', 'item158'] | Remaining Capacity :55
#
# Bin type : 3 | Item ID : ['item383', 'item929', 'item280'] | Remaining Capacity :8
#
# Bin type : 3 | Item ID : ['item384', 'item853', 'item48', 'item524', 'item466'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item385', 'item950', 'item143'] | Remaining Capacity :17
#
# Bin type : 3 | Item ID : ['item785', 'item543', 'item749'] | Remaining Capacity :18
#
# Bin type : 1 | Item ID : ['item527'] | Remaining Capacity :14
#
# Bin type : 3 | Item ID : ['item396', 'item102'] | Remaining Capacity :8
#
# Bin type : 2 | Item ID : ['item406', 'item333'] | Remaining Capacity :3
#
# Bin type : 3 | Item ID : ['item410', 'item16'] | Remaining Capacity :21
#
# Bin type : 3 | Item ID : ['item411', 'item530', 'item896', 'item820'] | Remaining Capacity :24
#
# Bin type : 1 | Item ID : ['item242', 'item403'] | Remaining Capacity :6
#
# Bin type : 1 | Item ID : ['item509'] | Remaining Capacity :7
#
# Bin type : 1 | Item ID : ['item874', 'item570'] | Remaining Capacity :10
#
# Bin type : 1 | Item ID : ['item407'] | Remaining Capacity :20
#
# Bin type : 3 | Item ID : ['item267', 'item287', 'item831', 'item176'] | Remaining Capacity :26
#
# Bin type : 3 | Item ID : ['item433', 'item984'] | Remaining Capacity :13
#
# Bin type : 1 | Item ID : ['item442', 'item73'] | Remaining Capacity :6
#
# Bin type : 1 | Item ID : ['item940', 'item62'] | Remaining Capacity :12
#
# Bin type : 1 | Item ID : ['item448'] | Remaining Capacity :10
#
# Bin type : 3 | Item ID : ['item452', 'item68', 'item902'] | Remaining Capacity :3
#
# Bin type : 2 | Item ID : ['item457', 'item822', 'item298'] | Remaining Capacity :33
#
# Bin type : 1 | Item ID : ['item24'] | Remaining Capacity :22
#
# Bin type : 3 | Item ID : ['item465', 'item184'] | Remaining Capacity :53
#
# Bin type : 2 | Item ID : ['item470', 'item145', 'item100'] | Remaining Capacity :0
#
# Bin type : 2 | Item ID : ['item471', 'item668', 'item694'] | Remaining Capacity :9
#
# Bin type : 2 | Item ID : ['item472', 'item189'] | Remaining Capacity :2
#
# Bin type : 1 | Item ID : ['item473', 'item459'] | Remaining Capacity :2
#
# Bin type : 1 | Item ID : ['item181', 'item229'] | Remaining Capacity :6
#
# Bin type : 3 | Item ID : ['item431', 'item618', 'item882', 'item834'] | Remaining Capacity :17
#
# Bin type : 3 | Item ID : ['item418', 'item884', 'item363'] | Remaining Capacity :15
#
# Bin type : 3 | Item ID : ['item480', 'item388', 'item893'] | Remaining Capacity :14
#
# Bin type : 2 | Item ID : ['item349', 'item14'] | Remaining Capacity :2
#
# Bin type : 1 | Item ID : ['item484', 'item608'] | Remaining Capacity :3
#
# Bin type : 3 | Item ID : ['item493', 'item591'] | Remaining Capacity :51
#
# Bin type : 1 | Item ID : ['item495', 'item803'] | Remaining Capacity :14
#
# Bin type : 3 | Item ID : ['item913', 'item499', 'item162'] | Remaining Capacity :11
#
# Bin type : 2 | Item ID : ['item500', 'item648'] | Remaining Capacity :29
#
# Bin type : 3 | Item ID : ['item629', 'item201'] | Remaining Capacity :6
#
# Bin type : 3 | Item ID : ['item504', 'item486', 'item60'] | Remaining Capacity :14
#
# Bin type : 2 | Item ID : ['item208'] | Remaining Capacity :29
#
# Bin type : 1 | Item ID : ['item511', 'item605'] | Remaining Capacity :13
#
# Bin type : 1 | Item ID : ['item65', 'item186'] | Remaining Capacity :17
#
# Bin type : 2 | Item ID : ['item516', 'item428', 'item503', 'item342'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item446', 'item761'] | Remaining Capacity :22
#
# Bin type : 2 | Item ID : ['item520'] | Remaining Capacity :44
#
# Bin type : 3 | Item ID : ['item969', 'item373', 'item845'] | Remaining Capacity :8
#
# Bin type : 3 | Item ID : ['item525', 'item15'] | Remaining Capacity :18
#
# Bin type : 1 | Item ID : ['item468', 'item413'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item217', 'item119'] | Remaining Capacity :28
#
# Bin type : 2 | Item ID : ['item475'] | Remaining Capacity :40
#
# Bin type : 2 | Item ID : ['item735', 'item238'] | Remaining Capacity :6
#
# Bin type : 1 | Item ID : ['item553'] | Remaining Capacity :8
#
# Bin type : 2 | Item ID : ['item63', 'item328'] | Remaining Capacity :23
#
# Bin type : 1 | Item ID : ['item566'] | Remaining Capacity :41
#
# Bin type : 1 | Item ID : ['item561'] | Remaining Capacity :19
#
# Bin type : 2 | Item ID : ['item806'] | Remaining Capacity :23
#
# Bin type : 1 | Item ID : ['item568', 'item399'] | Remaining Capacity :20
#
# Bin type : 2 | Item ID : ['item654', 'item752', 'item127'] | Remaining Capacity :40
#
# Bin type : 1 | Item ID : ['item576'] | Remaining Capacity :9
#
# Bin type : 2 | Item ID : ['item185', 'item649'] | Remaining Capacity :4
#
# Bin type : 2 | Item ID : ['item942', 'item871'] | Remaining Capacity :12
#
# Bin type : 1 | Item ID : ['item584', 'item788'] | Remaining Capacity :10
#
# Bin type : 2 | Item ID : ['item641', 'item178', 'item686'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item600', 'item751'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item179', 'item614'] | Remaining Capacity :5
#
# Bin type : 2 | Item ID : ['item611', 'item98', 'item140'] | Remaining Capacity :15
#
# Bin type : 3 | Item ID : ['item71', 'item196'] | Remaining Capacity :10
#
# Bin type : 1 | Item ID : ['item386', 'item256'] | Remaining Capacity :5
#
# Bin type : 2 | Item ID : ['item615', 'item546'] | Remaining Capacity :4
#
# Bin type : 2 | Item ID : ['item617', 'item284'] | Remaining Capacity :9
#
# Bin type : 2 | Item ID : ['item729', 'item958'] | Remaining Capacity :13
#
# Bin type : 2 | Item ID : ['item398', 'item209'] | Remaining Capacity :6
#
# Bin type : 1 | Item ID : ['item497', 'item590', 'item85'] | Remaining Capacity :2
#
# Bin type : 3 | Item ID : ['item630', 'item159', 'item671'] | Remaining Capacity :12
#
# Bin type : 1 | Item ID : ['item332', 'item96'] | Remaining Capacity :13
#
# Bin type : 1 | Item ID : ['item650', 'item111'] | Remaining Capacity :2
#
# Bin type : 1 | Item ID : ['item311', 'item79'] | Remaining Capacity :12
#
# Bin type : 3 | Item ID : ['item601', 'item551', 'item887'] | Remaining Capacity :6
#
# Bin type : 2 | Item ID : ['item387', 'item427', 'item613', 'item869'] | Remaining Capacity :9
#
# Bin type : 3 | Item ID : ['item953', 'item104', 'item828', 'item154'] | Remaining Capacity :6
#
# Bin type : 3 | Item ID : ['item674', 'item36', 'item843'] | Remaining Capacity :16
#
# Bin type : 3 | Item ID : ['item517', 'item501', 'item132', 'item949'] | Remaining Capacity :7
#
# Bin type : 3 | Item ID : ['item758', 'item302', 'item599', 'item77'] | Remaining Capacity :38
#
# Bin type : 2 | Item ID : ['item304'] | Remaining Capacity :37
#
# Bin type : 1 | Item ID : ['item696', 'item2'] | Remaining Capacity :5
#
# Bin type : 1 | Item ID : ['item858'] | Remaining Capacity :13
#
# Bin type : 3 | Item ID : ['item701', 'item726', 'item324'] | Remaining Capacity :6
#
# Bin type : 2 | Item ID : ['item704', 'item912', 'item583'] | Remaining Capacity :5
#
# Bin type : 3 | Item ID : ['item711', 'item348'] | Remaining Capacity :7
#
# Bin type : 2 | Item ID : ['item717', 'item708'] | Remaining Capacity :11
#
# Bin type : 1 | Item ID : ['item572'] | Remaining Capacity :17
#
# Bin type : 3 | Item ID : ['item727', 'item317', 'item733', 'item862'] | Remaining Capacity :26
#
# Bin type : 2 | Item ID : ['item529'] | Remaining Capacity :8
#
# Bin type : 1 | Item ID : ['item802', 'item207'] | Remaining Capacity :4
#
# Bin type : 2 | Item ID : ['item736', 'item595'] | Remaining Capacity :17
#
# Bin type : 2 | Item ID : ['item635'] | Remaining Capacity :4
#
# Bin type : 2 | Item ID : ['item160', 'item623'] | Remaining Capacity :7
#
# Bin type : 3 | Item ID : ['item357', 'item149', 'item49'] | Remaining Capacity :6
#
# Bin type : 2 | Item ID : ['item233', 'item750'] | Remaining Capacity :30
#
# Bin type : 1 | Item ID : ['item917', 'item818'] | Remaining Capacity :23
#
# Bin type : 3 | Item ID : ['item772', 'item633'] | Remaining Capacity :11
#
# Bin type : 1 | Item ID : ['item775', 'item556'] | Remaining Capacity :32
#
# Bin type : 2 | Item ID : ['item783', 'item481', 'item463'] | Remaining Capacity :4
#
# Bin type : 3 | Item ID : ['item790', 'item244', 'item61'] | Remaining Capacity :2
#
# Bin type : 3 | Item ID : ['item794', 'item246', 'item539', 'item75'] | Remaining Capacity :11
#
# Bin type : 2 | Item ID : ['item725'] | Remaining Capacity :26
#
# Bin type : 3 | Item ID : ['item859', 'item657', 'item919'] | Remaining Capacity :16
#
# Bin type : 2 | Item ID : ['item305', 'item768', 'item31'] | Remaining Capacity :2
#
# Bin type : 3 | Item ID : ['item957', 'item335', 'item483'] | Remaining Capacity :19
#
# Bin type : 2 | Item ID : ['item552'] | Remaining Capacity :2
#
# Bin type : 3 | Item ID : ['item807', 'item21', 'item741', 'item904'] | Remaining Capacity :9
#
# Bin type : 1 | Item ID : ['item823', 'item172'] | Remaining Capacity :3
#
# Bin type : 1 | Item ID : ['item293'] | Remaining Capacity :3
#
# Bin type : 3 | Item ID : ['item839', 'item877', 'item682'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item675', 'item192'] | Remaining Capacity :26
#
# Bin type : 2 | Item ID : ['item41', 'item454', 'item808'] | Remaining Capacity :5
#
# Bin type : 2 | Item ID : ['item851', 'item663'] | Remaining Capacity :29
#
# Bin type : 3 | Item ID : ['item319', 'item624', 'item464'] | Remaining Capacity :37
#
# Bin type : 2 | Item ID : ['item861', 'item848'] | Remaining Capacity :10
#
# Bin type : 3 | Item ID : ['item864', 'item743'] | Remaining Capacity :15
#
# Bin type : 3 | Item ID : ['item3', 'item531', 'item951'] | Remaining Capacity :13
#
# Bin type : 1 | Item ID : ['item872'] | Remaining Capacity :10
#
# Bin type : 2 | Item ID : ['item577'] | Remaining Capacity :26
#
# Bin type : 2 | Item ID : ['item262', 'item18'] | Remaining Capacity :29
#
# Bin type : 3 | Item ID : ['item810', 'item435', 'item895'] | Remaining Capacity :16
#
# Bin type : 3 | Item ID : ['item888', 'item393', 'item596'] | Remaining Capacity :3
#
# Bin type : 1 | Item ID : ['item889', 'item647', 'item789'] | Remaining Capacity :11
#
# Bin type : 3 | Item ID : ['item890', 'item151', 'item182'] | Remaining Capacity :3
#
# Bin type : 2 | Item ID : ['item780'] | Remaining Capacity :11
#
# Bin type : 3 | Item ID : ['item894', 'item202', 'item109'] | Remaining Capacity :5
#
# Bin type : 2 | Item ID : ['item899', 'item445'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item168', 'item892', 'item916', 'item389', 'item343'] | Remaining Capacity :20
#
# Bin type : 3 | Item ID : ['item909', 'item587'] | Remaining Capacity :23
#
# Bin type : 3 | Item ID : ['item756', 'item51', 'item153'] | Remaining Capacity :13
#
# Bin type : 1 | Item ID : ['item911', 'item250'] | Remaining Capacity :15
#
# Bin type : 1 | Item ID : ['item230'] | Remaining Capacity :2
#
# Bin type : 3 | Item ID : ['item914', 'item660', 'item585'] | Remaining Capacity :9
#
# Bin type : 3 | Item ID : ['item278', 'item964', 'item421'] | Remaining Capacity :9
#
# Bin type : 1 | Item ID : ['item243', 'item19'] | Remaining Capacity :2
#
# Bin type : 1 | Item ID : ['item924'] | Remaining Capacity :6
#
# Bin type : 1 | Item ID : ['item931', 'item80'] | Remaining Capacity :19
#
# Bin type : 1 | Item ID : ['item938', 'item510'] | Remaining Capacity :4
#
# Bin type : 2 | Item ID : ['item563'] | Remaining Capacity :8
#
# Bin type : 1 | Item ID : ['item712', 'item739'] | Remaining Capacity :4
#
# Bin type : 3 | Item ID : ['item855', 'item991', 'item996', 'item918'] | Remaining Capacity :10
#
# Bin type : 2 | Item ID : ['item970', 'item295'] | Remaining Capacity :26
#
# Bin type : 3 | Item ID : ['item971', 'item441', 'item826'] | Remaining Capacity :14
#
# Bin type : 1 | Item ID : ['item974', 'item908'] | Remaining Capacity :4
#
# Bin type : 1 | Item ID : ['item234'] | Remaining Capacity :22
#
# Bin type : 2 | Item ID : ['item338'] | Remaining Capacity :43
#
# Bin type : 1 | Item ID : ['item759'] | Remaining Capacity :17
#
# Bin type : 1 | Item ID : ['item571'] | Remaining Capacity :0
#
# Bin type : 1 | Item ID : ['item46'] | Remaining Capacity :17
#
# Bin type : 2 | Item ID : ['item167'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item732', 'item450'] | Remaining Capacity :4
#
# Bin type : 3 | Item ID : ['item415', 'item800'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item513', 'item199'] | Remaining Capacity :2
#
# Bin type : 3 | Item ID : ['item285', 'item812'] | Remaining Capacity :20
#
# Bin type : 1 | Item ID : ['item702'] | Remaining Capacity :22
#
# Bin type : 2 | Item ID : ['item372'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item265', 'item928', 'item137', 'item231'] | Remaining Capacity :4
#
# Bin type : 3 | Item ID : ['item40', 'item84'] | Remaining Capacity :18
#
# Bin type : 1 | Item ID : ['item801', 'item721'] | Remaining Capacity :8
#
# Bin type : 1 | Item ID : ['item621'] | Remaining Capacity :2
#
# Bin type : 2 | Item ID : ['item404'] | Remaining Capacity :5
#
# Bin type : 3 | Item ID : ['item719', 'item932'] | Remaining Capacity :5
#
# Bin type : 3 | Item ID : ['item423', 'item700', 'item997'] | Remaining Capacity :40
#
# Bin type : 2 | Item ID : ['item456', 'item796'] | Remaining Capacity :16
#
# Bin type : 2 | Item ID : ['item960', 'item461'] | Remaining Capacity :2
#
# Bin type : 2 | Item ID : ['item528', 'item746'] | Remaining Capacity :3
#
# Bin type : 3 | Item ID : ['item612', 'item66'] | Remaining Capacity :12
#
# Bin type : 3 | Item ID : ['item978', 'item805'] | Remaining Capacity :9
#
# Bin type : 3 | Item ID : ['item706', 'item291'] | Remaining Capacity :6
#
# Bin type : 2 | Item ID : ['item597', 'item379', 'item897', 'item956'] | Remaining Capacity :4
#
# Bin type : 1 | Item ID : ['item782', 'item163'] | Remaining Capacity :15
#
# Bin type : 2 | Item ID : ['item303'] | Remaining Capacity :10
#
# Bin type : 2 | Item ID : ['item835'] | Remaining Capacity :12
#
# Bin type : 2 | Item ID : ['item532', 'item628', 'item460'] | Remaining Capacity :22
#
# Bin type : 2 | Item ID : ['item362', 'item854', 'item793', 'item10'] | Remaining Capacity :23
#
# Bin type : 1 | Item ID : ['item952', 'item784', 'item754'] | Remaining Capacity :12
#
# Bin type : 1 | Item ID : ['item11'] | Remaining Capacity :7
#
# Bin type : 3 | Item ID : ['item846', 'item656'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item774', 'item89'] | Remaining Capacity :11
#
# Bin type : 2 | Item ID : ['item885'] | Remaining Capacity :41
#
# Bin type : 2 | Item ID : ['item279'] | Remaining Capacity :22
#
# Bin type : 1 | Item ID : ['item644'] | Remaining Capacity :3
#
# Bin type : 3 | Item ID : ['item194', 'item900'] | Remaining Capacity :16
#
# Bin type : 2 | Item ID : ['item677', 'item565'] | Remaining Capacity :9
#
# Bin type : 1 | Item ID : ['item204', 'item567'] | Remaining Capacity :2
#
# Bin type : 2 | Item ID : ['item138', 'item76'] | Remaining Capacity :7
#
# Bin type : 1 | Item ID : ['item797'] | Remaining Capacity :12
#
# Bin type : 1 | Item ID : ['item381'] | Remaining Capacity :14
#
# Bin type : 2 | Item ID : ['item17'] | Remaining Capacity :8
#
# Bin type : 3 | Item ID : ['item962', 'item692'] | Remaining Capacity :10
#
# Bin type : 2 | Item ID : ['item512', 'item82'] | Remaining Capacity :8
#
# Bin type : 1 | Item ID : ['item873'] | Remaining Capacity :5
#
# Bin type : 1 | Item ID : ['item905'] | Remaining Capacity :13
#
# Bin type : 2 | Item ID : ['item83'] | Remaining Capacity :4
#
# Bin type : 2 | Item ID : ['item604', 'item203'] | Remaining Capacity :6
#
# Bin type : 2 | Item ID : ['item921'] | Remaining Capacity :2
#
# Bin type : 2 | Item ID : ['item722'] | Remaining Capacity :17
#
# Bin type : 2 | Item ID : ['item536'] | Remaining Capacity :5
#
# Bin type : 3 | Item ID : ['item1000', 'item225'] | Remaining Capacity :7
#
# Bin type : 2 | Item ID : ['item142', 'item975'] | Remaining Capacity :22
#
# Bin type : 1 | Item ID : ['item436'] | Remaining Capacity :42
#
# Bin type : 3 | Item ID : ['item579', 'item128'] | Remaining Capacity :9
#
# Bin type : 2 | Item ID : ['item397', 'item1'] | Remaining Capacity :6
#
# Bin type : 2 | Item ID : ['item537'] | Remaining Capacity :7
#
# Bin type : 3 | Item ID : ['item345', 'item29', 'item548'] | Remaining Capacity :19
#
# Bin type : 2 | Item ID : ['item426', 'item770'] | Remaining Capacity :16
#
# Bin type : 3 | Item ID : ['item13', 'item816'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item148', 'item534', 'item868'] | Remaining Capacity :16
#
# Bin type : 3 | Item ID : ['item283', 'item622'] | Remaining Capacity :13
#
# Bin type : 1 | Item ID : ['item277', 'item791'] | Remaining Capacity :7
#
# Bin type : 2 | Item ID : ['item666'] | Remaining Capacity :19
#
# Bin type : 2 | Item ID : ['item773'] | Remaining Capacity :11
#
# Bin type : 2 | Item ID : ['item578', 'item337', 'item836'] | Remaining Capacity :3
#
# Bin type : 3 | Item ID : ['item467', 'item799'] | Remaining Capacity :3
#
# Bin type : 2 | Item ID : ['item609'] | Remaining Capacity :15
#
# Bin type : 2 | Item ID : ['item273', 'item824'] | Remaining Capacity :2
#
# Bin type : 3 | Item ID : ['item769', 'item173'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item988'] | Remaining Capacity :14
#
# Bin type : 2 | Item ID : ['item948'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item870', 'item693'] | Remaining Capacity :2
#
# Bin type : 1 | Item ID : ['item689'] | Remaining Capacity :18
#
# Bin type : 3 | Item ID : ['item449', 'item763'] | Remaining Capacity :19
#
# Bin type : 2 | Item ID : ['item59'] | Remaining Capacity :11
#
# Bin type : 2 | Item ID : ['item323'] | Remaining Capacity :0
#
# Bin type : 3 | Item ID : ['item742', 'item476'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item665', 'item187', 'item103'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item680', 'item64', 'item850'] | Remaining Capacity :21
#
# Bin type : 3 | Item ID : ['item814', 'item314'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item259', 'item33'] | Remaining Capacity :9
#
# Bin type : 2 | Item ID : ['item239', 'item216'] | Remaining Capacity :3
#
# Bin type : 2 | Item ID : ['item515', 'item986'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item703'] | Remaining Capacity :6
#
# Bin type : 2 | Item ID : ['item982'] | Remaining Capacity :3
#
# Bin type : 2 | Item ID : ['item395', 'item881'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item419', 'item402'] | Remaining Capacity :10
#
# Bin type : 2 | Item ID : ['item766', 'item334'] | Remaining Capacity :19
#
# Bin type : 3 | Item ID : ['item12', 'item939', 'item655'] | Remaining Capacity :56
#
# Bin type : 2 | Item ID : ['item261'] | Remaining Capacity :0
#
# Bin type : 3 | Item ID : ['item555', 'item685'] | Remaining Capacity :2
#
# Bin type : 3 | Item ID : ['item336', 'item157'] | Remaining Capacity :11
#
# Bin type : 3 | Item ID : ['item188', 'item430'] | Remaining Capacity :24
#
# Bin type : 2 | Item ID : ['item424'] | Remaining Capacity :8
#
# Bin type : 3 | Item ID : ['item688', 'item110'] | Remaining Capacity :26
#
# Bin type : 3 | Item ID : ['item866', 'item134', 'item74'] | Remaining Capacity :16
#
# Bin type : 3 | Item ID : ['item451', 'item757'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item582', 'item815'] | Remaining Capacity :6
#
# Bin type : 2 | Item ID : ['item581', 'item777'] | Remaining Capacity :5
#
# Bin type : 2 | Item ID : ['item526'] | Remaining Capacity :7
#
# Bin type : 2 | Item ID : ['item598'] | Remaining Capacity :17
#
# Bin type : 1 | Item ID : ['item91', 'item94'] | Remaining Capacity :22
#
# Bin type : 3 | Item ID : ['item522', 'item39'] | Remaining Capacity :11
#
# Bin type : 3 | Item ID : ['item915', 'item842'] | Remaining Capacity :10
#
# Bin type : 2 | Item ID : ['item993'] | Remaining Capacity :0
#
# Bin type : 3 | Item ID : ['item330', 'item4'] | Remaining Capacity :4
#
# Bin type : 2 | Item ID : ['item699'] | Remaining Capacity :8
#
# Bin type : 3 | Item ID : ['item274', 'item891'] | Remaining Capacity :14
#
# Bin type : 3 | Item ID : ['item390', 'item632'] | Remaining Capacity :2
#
# Bin type : 3 | Item ID : ['item99', 'item269'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item535', 'item980'] | Remaining Capacity :56
#
# Bin type : 2 | Item ID : ['item856'] | Remaining Capacity :15
#
# Bin type : 3 | Item ID : ['item946', 'item753'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item294', 'item180', 'item360'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item86'] | Remaining Capacity :6
#
# Bin type : 3 | Item ID : ['item191', 'item364'] | Remaining Capacity :3
#
# Bin type : 3 | Item ID : ['item22', 'item34'] | Remaining Capacity :11
#
# Bin type : 2 | Item ID : ['item392'] | Remaining Capacity :7
#
# Bin type : 3 | Item ID : ['item898', 'item764'] | Remaining Capacity :3
#
# Bin type : 2 | Item ID : ['item934'] | Remaining Capacity :11
#
# Bin type : 2 | Item ID : ['item67'] | Remaining Capacity :27
#
# Bin type : 1 | Item ID : ['item990'] | Remaining Capacity :4
#
# Bin type : 3 | Item ID : ['item69', 'item313'] | Remaining Capacity :18
#
# Bin type : 3 | Item ID : ['item161', 'item347'] | Remaining Capacity :16
#
# Bin type : 3 | Item ID : ['item943', 'item289'] | Remaining Capacity :26
#
# Bin type : 2 | Item ID : ['item344'] | Remaining Capacity :0
#
# Bin type : 2 | Item ID : ['item959', 'item642', 'item482'] | Remaining Capacity :7
#
# Bin type : 2 | Item ID : ['item405'] | Remaining Capacity :3
#
# Bin type : 3 | Item ID : ['item183', 'item607'] | Remaining Capacity :18
#
# Bin type : 3 | Item ID : ['item559', 'item844'] | Remaining Capacity :9
#
# Bin type : 2 | Item ID : ['item778'] | Remaining Capacity :18
#
# Bin type : 2 | Item ID : ['item325'] | Remaining Capacity :3
#
# Bin type : 2 | Item ID : ['item116', 'item292'] | Remaining Capacity :10
#
# Bin type : 3 | Item ID : ['item55', 'item490'] | Remaining Capacity :10
#
# Bin type : 3 | Item ID : ['item705', 'item542'] | Remaining Capacity :8
#
# Bin type : 2 | Item ID : ['item863'] | Remaining Capacity :12
#
# Bin type : 2 | Item ID : ['item257'] | Remaining Capacity :19
#
# Bin type : 2 | Item ID : ['item829'] | Remaining Capacity :3
#
# Bin type : 2 | Item ID : ['item263'] | Remaining Capacity :30
#
# Bin type : 3 | Item ID : ['item321', 'item358'] | Remaining Capacity :20
#
# Bin type : 2 | Item ID : ['item108'] | Remaining Capacity :15
#
# Bin type : 3 | Item ID : ['item691', 'item107', 'item440'] | Remaining Capacity :10
#
# Bin type : 3 | Item ID : ['item193', 'item236'] | Remaining Capacity :28
#
# Bin type : 2 | Item ID : ['item681', 'item745', 'item81'] | Remaining Capacity :7
#
# Bin type : 2 | Item ID : ['item43'] | Remaining Capacity :18
#
# Bin type : 2 | Item ID : ['item523', 'item538'] | Remaining Capacity :2
#
# Bin type : 3 | Item ID : ['item625', 'item245', 'item557'] | Remaining Capacity :6
#
# Bin type : 3 | Item ID : ['item307', 'item744'] | Remaining Capacity :7
#
# Bin type : 2 | Item ID : ['item408'] | Remaining Capacity :27
#
# Bin type : 3 | Item ID : ['item554', 'item999'] | Remaining Capacity :53
#
# Bin type : 2 | Item ID : ['item453', 'item634'] | Remaining Capacity :5
#
# Bin type : 1 | Item ID : ['item455'] | Remaining Capacity :10
#
# Bin type : 3 | Item ID : ['item447', 'item927'] | Remaining Capacity :22
#
# Bin type : 2 | Item ID : ['item260'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item865', 'item755'] | Remaining Capacity :2
#
# Bin type : 2 | Item ID : ['item558'] | Remaining Capacity :8
#
# Bin type : 2 | Item ID : ['item425'] | Remaining Capacity :5
#
# Bin type : 2 | Item ID : ['item118'] | Remaining Capacity :2
#
# Bin type : 2 | Item ID : ['item434'] | Remaining Capacity :6
#
# Bin type : 2 | Item ID : ['item961'] | Remaining Capacity :12
#
# Bin type : 3 | Item ID : ['item714', 'item54', 'item44'] | Remaining Capacity :9
#
# Bin type : 3 | Item ID : ['item498', 'item272', 'item695'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item832', 'item479'] | Remaining Capacity :16
#
# Bin type : 2 | Item ID : ['item966'] | Remaining Capacity :33
#
# Bin type : 2 | Item ID : ['item42'] | Remaining Capacity :10
#
# Bin type : 3 | Item ID : ['item819', 'item218'] | Remaining Capacity :21
#
# Bin type : 1 | Item ID : ['item268', 'item215'] | Remaining Capacity :6
#
# Bin type : 3 | Item ID : ['item401', 'item827'] | Remaining Capacity :15
#
# Bin type : 2 | Item ID : ['item150'] | Remaining Capacity :9
#
# Bin type : 1 | Item ID : ['item521'] | Remaining Capacity :23
#
# Bin type : 2 | Item ID : ['item352', 'item416'] | Remaining Capacity :6
#
# Bin type : 2 | Item ID : ['item776'] | Remaining Capacity :9
#
# Bin type : 2 | Item ID : ['item286', 'item825'] | Remaining Capacity :5
#
# Bin type : 2 | Item ID : ['item378', 'item380'] | Remaining Capacity :6
#
# Bin type : 3 | Item ID : ['item400', 'item228'] | Remaining Capacity :6
#
# Bin type : 3 | Item ID : ['item979', 'item574', 'item903'] | Remaining Capacity :16
#
# Bin type : 3 | Item ID : ['item541', 'item174'] | Remaining Capacity :7
#
# Bin type : 2 | Item ID : ['item540', 'item491'] | Remaining Capacity :16
#
# Bin type : 2 | Item ID : ['item346'] | Remaining Capacity :28
#
# Bin type : 2 | Item ID : ['item569'] | Remaining Capacity :29
#
# Bin type : 2 | Item ID : ['item809'] | Remaining Capacity :5
#
# Bin type : 2 | Item ID : ['item437'] | Remaining Capacity :3
#
# Bin type : 3 | Item ID : ['item935', 'item588'] | Remaining Capacity :4
#
# Bin type : 2 | Item ID : ['item308'] | Remaining Capacity :0
#
# Bin type : 2 | Item ID : ['item787'] | Remaining Capacity :10
#
# Bin type : 3 | Item ID : ['item469', 'item144'] | Remaining Capacity :2
#
# Bin type : 2 | Item ID : ['item860', 'item910'] | Remaining Capacity :3
#
# Bin type : 3 | Item ID : ['item923', 'item299'] | Remaining Capacity :59
#
# Bin type : 2 | Item ID : ['item371'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item412'] | Remaining Capacity :7
#
# Bin type : 2 | Item ID : ['item653'] | Remaining Capacity :4
#
# Bin type : 3 | Item ID : ['item995', 'item798'] | Remaining Capacity :4
#
# Bin type : 1 | Item ID : ['item254'] | Remaining Capacity :55
#
# Bin type : 3 | Item ID : ['item636', 'item944'] | Remaining Capacity :5
#
# Bin type : 2 | Item ID : ['item930'] | Remaining Capacity :2
#
# Bin type : 3 | Item ID : ['item594', 'item638'] | Remaining Capacity :5
#
# Bin type : 2 | Item ID : ['item906'] | Remaining Capacity :14
#
# Bin type : 2 | Item ID : ['item318'] | Remaining Capacity :5
#
# Bin type : 2 | Item ID : ['item506'] | Remaining Capacity :22
#
# Bin type : 3 | Item ID : ['item738', 'item672'] | Remaining Capacity :7
#
# Bin type : 3 | Item ID : ['item322', 'item130'] | Remaining Capacity :3
#
# Bin type : 2 | Item ID : ['item813'] | Remaining Capacity :22
#
# Bin type : 2 | Item ID : ['item47'] | Remaining Capacity :9
#
# Bin type : 3 | Item ID : ['item998', 'item489'] | Remaining Capacity :10
#
# Bin type : 3 | Item ID : ['item227', 'item249'] | Remaining Capacity :6
#
# Bin type : 2 | Item ID : ['item989'] | Remaining Capacity :8
#
# Bin type : 2 | Item ID : ['item226'] | Remaining Capacity :28
#
# Bin type : 3 | Item ID : ['item135', 'item45'] | Remaining Capacity :18
#
# Bin type : 2 | Item ID : ['item296'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item573'] | Remaining Capacity :11
#
# Bin type : 2 | Item ID : ['item659'] | Remaining Capacity :20
#
# Bin type : 2 | Item ID : ['item365'] | Remaining Capacity :13
#
# Bin type : 3 | Item ID : ['item198', 'item93'] | Remaining Capacity :3
#
# Bin type : 3 | Item ID : ['item152', 'item169'] | Remaining Capacity :9
#
# Bin type : 2 | Item ID : ['item963'] | Remaining Capacity :18
#
# Bin type : 3 | Item ID : ['item30', 'item339'] | Remaining Capacity :3
#
# Bin type : 3 | Item ID : ['item593', 'item78'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item492'] | Remaining Capacity :16
#
# Bin type : 2 | Item ID : ['item370'] | Remaining Capacity :8
#
# Bin type : 3 | Item ID : ['item922', 'item987'] | Remaining Capacity :29
#
# Bin type : 2 | Item ID : ['item350'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item637', 'item251'] | Remaining Capacity :3
#
# Bin type : 3 | Item ID : ['item817', 'item147'] | Remaining Capacity :7
#
# Bin type : 2 | Item ID : ['item507'] | Remaining Capacity :13
#
# Bin type : 2 | Item ID : ['item941'] | Remaining Capacity :6
#
# Bin type : 1 | Item ID : ['item282'] | Remaining Capacity :8
#
# Bin type : 2 | Item ID : ['item439'] | Remaining Capacity :25
#
# Bin type : 3 | Item ID : ['item602', 'item375'] | Remaining Capacity :22
#
# Bin type : 2 | Item ID : ['item219'] | Remaining Capacity :10
#
# Bin type : 2 | Item ID : ['item129'] | Remaining Capacity :2
#
# Bin type : 2 | Item ID : ['item232'] | Remaining Capacity :28
#
# Bin type : 3 | Item ID : ['item737', 'item458'] | Remaining Capacity :5
#
# Bin type : 2 | Item ID : ['item270'] | Remaining Capacity :19
#
# Bin type : 3 | Item ID : ['item341', 'item669'] | Remaining Capacity :5
#
# Bin type : 2 | Item ID : ['item443'] | Remaining Capacity :4
#
# Bin type : 2 | Item ID : ['item838'] | Remaining Capacity :17
#
# Bin type : 2 | Item ID : ['item165'] | Remaining Capacity :27
#
# Bin type : 2 | Item ID : ['item968'] | Remaining Capacity :11
#
# Bin type : 2 | Item ID : ['item28', 'item886'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item954'] | Remaining Capacity :8
#
# Bin type : 3 | Item ID : ['item875', 'item235'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item925'] | Remaining Capacity :10
#
# Bin type : 2 | Item ID : ['item53'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item240'] | Remaining Capacity :57
#
# Bin type : 3 | Item ID : ['item488'] | Remaining Capacity :50
#
# Bin type : 2 | Item ID : ['item779'] | Remaining Capacity :17
#
# Bin type : 3 | Item ID : ['item518', 'item394'] | Remaining Capacity :16
#
# Bin type : 3 | Item ID : ['item422', 'item136'] | Remaining Capacity :5
#
# Bin type : 2 | Item ID : ['item804'] | Remaining Capacity :5
#
# Bin type : 2 | Item ID : ['item505'] | Remaining Capacity :6
#
# Bin type : 3 | Item ID : ['item589', 'item87'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item200'] | Remaining Capacity :34
#
# Bin type : 3 | Item ID : ['item429', 'item281'] | Remaining Capacity :6
#
# Bin type : 2 | Item ID : ['item847'] | Remaining Capacity :4
#
# Bin type : 3 | Item ID : ['item821', 'item747'] | Remaining Capacity :11
#
# Bin type : 2 | Item ID : ['item95'] | Remaining Capacity :30
#
# Bin type : 2 | Item ID : ['item327', 'item687'] | Remaining Capacity :8
#
# Bin type : 2 | Item ID : ['item965'] | Remaining Capacity :4
#
# Bin type : 2 | Item ID : ['item478'] | Remaining Capacity :4
#
# Bin type : 2 | Item ID : ['item50'] | Remaining Capacity :8
#
# Bin type : 3 | Item ID : ['item241', 'item376'] | Remaining Capacity :10
#
# Bin type : 3 | Item ID : ['item715'] | Remaining Capacity :50
#
# Bin type : 3 | Item ID : ['item731', 'item781'] | Remaining Capacity :9
#
# Bin type : 2 | Item ID : ['item290'] | Remaining Capacity :3
#
# Bin type : 2 | Item ID : ['item564'] | Remaining Capacity :31
#
# Bin type : 3 | Item ID : ['item907', 'item508'] | Remaining Capacity :3
#
# Bin type : 3 | Item ID : ['item306', 'item992'] | Remaining Capacity :8
#
# Bin type : 3 | Item ID : ['item619'] | Remaining Capacity :62
#
# Bin type : 3 | Item ID : ['item879', 'item792'] | Remaining Capacity :7
#
# Bin type : 2 | Item ID : ['item586'] | Remaining Capacity :2
#
# Bin type : 3 | Item ID : ['item549', 'item141'] | Remaining Capacity :17
#
# Bin type : 3 | Item ID : ['item320', 'item937'] | Remaining Capacity :2
#
# Bin type : 3 | Item ID : ['item724', 'item616'] | Remaining Capacity :4
#
# Bin type : 2 | Item ID : ['item8'] | Remaining Capacity :21
#
# Bin type : 2 | Item ID : ['item697'] | Remaining Capacity :21
#
# Bin type : 2 | Item ID : ['item933'] | Remaining Capacity :11
#
# Bin type : 3 | Item ID : ['item920', 'item718'] | Remaining Capacity :5
#
# Bin type : 3 | Item ID : ['item120', 'item496'] | Remaining Capacity :11
#
# Bin type : 2 | Item ID : ['item105'] | Remaining Capacity :32
#
# Bin type : 2 | Item ID : ['item901'] | Remaining Capacity :16
#
# Bin type : 3 | Item ID : ['item462', 'item786'] | Remaining Capacity :6
#
# Bin type : 3 | Item ID : ['item368'] | Remaining Capacity :83

# %%
print(f"N1 | Cost = {N1_COST} | Bins = {N1_BINS} | Time = {N1_TIME}")
print(f"N1 and N4 | Cost = {N1N4_COST} | Bins = {N1N4_BINS} | Time ={N1N4_TIME}")
print(f"N1 and LS | Cost = {N1N4N5N6_COST} | Bins = {N1N4N5N6_BINS} | Time ={N1N4N5N6_TIME}")
print(f"N1,N2 and LS | Cost = {N1N2LS_COST} | Bins = {N1N2LS_BINS} | Time ={N1N2LS_TIME}")
# Out:
# N1 | Cost = 57690 | Bins = 520 | Time = 45.85932540893555
# N1 and N4 | Cost = 51750 | Bins = 445 | Time =24.866806268692017
# N1 and LS | Cost = 51570 | Bins = 453 | Time =17.94641947746277
# N1,N2 and LS | Cost = 51630 | Bins = 457 | Time =16.30456280708313

# %%
# sys.stdout = old_stdout

# log_file.close()

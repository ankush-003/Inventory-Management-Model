# %%
import random
import pprint
import time
import copy
import uuid

# %%
# import sys
# old_stdout = sys.stdout

# log_file = open("message.log", "w")

# sys.stdout = log_file

# %%
weights = [0,]
for x in range(1001):
    w = random.randint(1,100)
    weights.append(w)

# %%
itemsInfo = {}
binsInfo = {}
probabilites = [0,]
# weights = [0,78, 88, 52, 77, 17, 85, 39, 95, 37, 58, 39, 21,53, 10, 69, 81, 28, 32, 48, 56, 88, 59, 29, 97, 43]
capacitites = [0,60, 100, 150]
costs = [0, 60, 100, 150]


for x in range(1,len(capacitites)):
    probabilites.append(capacitites[x]/costs[x])

for x in range(1, 1001):
    itemsInfo[f"item{x}"] = weights[x]

for x in range(1, 4):
    binsInfo[x] = {
        "cost": capacitites[x],
        "capacity": costs[x],
        "probability":  probabilites[x]
    }

print(itemsInfo,binsInfo)
# Out:
# {'item1': 46, 'item2': 45, 'item3': 51, 'item4': 32, 'item5': 48, 'item6': 82, 'item7': 86, 'item8': 44, 'item9': 1, 'item10': 20, 'item11': 61, 'item12': 55, 'item13': 56, 'item14': 20, 'item15': 15, 'item16': 53, 'item17': 1, 'item18': 35, 'item19': 46, 'item20': 6, 'item21': 7, 'item22': 4, 'item23': 86, 'item24': 4, 'item25': 43, 'item26': 86, 'item27': 23, 'item28': 44, 'item29': 53, 'item30': 84, 'item31': 38, 'item32': 37, 'item33': 45, 'item34': 17, 'item35': 53, 'item36': 69, 'item37': 78, 'item38': 70, 'item39': 15, 'item40': 7, 'item41': 94, 'item42': 1, 'item43': 15, 'item44': 94, 'item45': 63, 'item46': 45, 'item47': 83, 'item48': 47, 'item49': 57, 'item50': 59, 'item51': 99, 'item52': 42, 'item53': 84, 'item54': 77, 'item55': 10, 'item56': 49, 'item57': 21, 'item58': 43, 'item59': 30, 'item60': 29, 'item61': 56, 'item62': 28, 'item63': 77, 'item64': 10, 'item65': 75, 'item66': 25, 'item67': 21, 'item68': 78, 'item69': 93, 'item70': 55, 'item71': 74, 'item72': 10, 'item73': 15, 'item74': 41, 'item75': 16, 'item76': 18, 'item77': 40, 'item78': 43, 'item79': 45, 'item80': 53, 'item81': 30, 'item82': 20, 'item83': 97, 'item84': 100, 'item85': 51, 'item86': 33, 'item87': 41, 'item88': 5, 'item89': 24, 'item90': 11, 'item91': 68, 'item92': 38, 'item93': 64, 'item94': 99, 'item95': 76, 'item96': 87, 'item97': 41, 'item98': 72, 'item99': 37, 'item100': 40, 'item101': 100, 'item102': 30, 'item103': 25, 'item104': 35, 'item105': 54, 'item106': 44, 'item107': 71, 'item108': 85, 'item109': 75, 'item110': 69, 'item111': 42, 'item112': 66, 'item113': 34, 'item114': 44, 'item115': 98, 'item116': 89, 'item117': 64, 'item118': 33, 'item119': 24, 'item120': 82, 'item121': 82, 'item122': 9, 'item123': 77, 'item124': 45, 'item125': 18, 'item126': 38, 'item127': 97, 'item128': 30, 'item129': 61, 'item130': 32, 'item131': 66, 'item132': 59, 'item133': 35, 'item134': 32, 'item135': 73, 'item136': 51, 'item137': 65, 'item138': 11, 'item139': 52, 'item140': 90, 'item141': 79, 'item142': 17, 'item143': 69, 'item144': 38, 'item145': 97, 'item146': 79, 'item147': 54, 'item148': 20, 'item149': 39, 'item150': 77, 'item151': 53, 'item152': 86, 'item153': 28, 'item154': 25, 'item155': 30, 'item156': 68, 'item157': 8, 'item158': 19, 'item159': 58, 'item160': 20, 'item161': 65, 'item162': 13, 'item163': 22, 'item164': 47, 'item165': 74, 'item166': 64, 'item167': 4, 'item168': 1, 'item169': 34, 'item170': 11, 'item171': 85, 'item172': 92, 'item173': 99, 'item174': 17, 'item175': 63, 'item176': 52, 'item177': 45, 'item178': 13, 'item179': 41, 'item180': 20, 'item181': 16, 'item182': 23, 'item183': 40, 'item184': 10, 'item185': 54, 'item186': 16, 'item187': 48, 'item188': 66, 'item189': 32, 'item190': 12, 'item191': 63, 'item192': 89, 'item193': 81, 'item194': 61, 'item195': 83, 'item196': 58, 'item197': 75, 'item198': 95, 'item199': 13, 'item200': 100, 'item201': 35, 'item202': 97, 'item203': 58, 'item204': 19, 'item205': 82, 'item206': 18, 'item207': 20, 'item208': 60, 'item209': 14, 'item210': 98, 'item211': 2, 'item212': 80, 'item213': 84, 'item214': 41, 'item215': 32, 'item216': 58, 'item217': 97, 'item218': 30, 'item219': 48, 'item220': 29, 'item221': 52, 'item222': 58, 'item223': 97, 'item224': 56, 'item225': 41, 'item226': 1, 'item227': 56, 'item228': 76, 'item229': 86, 'item230': 20, 'item231': 6, 'item232': 43, 'item233': 18, 'item234': 29, 'item235': 50, 'item236': 78, 'item237': 83, 'item238': 13, 'item239': 23, 'item240': 82, 'item241': 35, 'item242': 70, 'item243': 56, 'item244': 1, 'item245': 62, 'item246': 63, 'item247': 89, 'item248': 40, 'item249': 24, 'item250': 64, 'item251': 38, 'item252': 46, 'item253': 13, 'item254': 4, 'item255': 39, 'item256': 38, 'item257': 94, 'item258': 63, 'item259': 92, 'item260': 76, 'item261': 2, 'item262': 3, 'item263': 48, 'item264': 28, 'item265': 59, 'item266': 18, 'item267': 62, 'item268': 93, 'item269': 79, 'item270': 59, 'item271': 26, 'item272': 89, 'item273': 54, 'item274': 44, 'item275': 42, ...

# %%
def GenerateInitialSolution() :
    solution = {}
    s = 1
    for id,w in itemsInfo.items():
        newId = uuid.uuid4()
        validBinTypes = list(filter(lambda bin : binsInfo[bin]["capacity"] > w,binsInfo ))
        validProbabilites = tuple(map(lambda bin: binsInfo[bin]["probability"], validBinTypes))
        selectedBin = random.choices(validBinTypes,weights=validProbabilites,k=1)[0]
        remainingCapacity = binsInfo[selectedBin]["capacity"] - itemsInfo[id] 
        solution[newId] = {"bin_type": selectedBin, "item_ids": [id], "remaining_capacity": remainingCapacity}
        s+= 1
    return solution

# %%
def Cost(x : dict):
    totalCost = 0
    for info in x.values() :
        totalCost += binsInfo[info["bin_type"]]["cost"]
    return totalCost

# %%
def ChooseNeightbourhood(c1,c2) :
    k = random.choices([1,2],weights=(c1,c2),k=1)[0]
    return k

# %%
def RemainingCapacity(x,id):
    capacity = binsInfo[x[id]["bin_type"]]["capacity"]
    weight = 0
    if len(x[id]["item_ids"]) == 0 :
        return capacity
    for itemId in x[id]["item_ids"]:
        weight += itemsInfo[itemId]
    return capacity - weight

# %%
def GetWeight(id):
    return itemsInfo[id]

def UnpackRepack(x : dict,binId,newCapacity,newBinType) :
    
    cap = newCapacity
    unpackedItems = []

    #Unpacking 
    while cap < 0 :
        unpackedItem = random.choice(x[binId]["item_ids"])
        unpackedItems.append(unpackedItem)
        x[binId]["item_ids"].remove(unpackedItem)
        cap += itemsInfo[unpackedItem]
    x[binId]["remaining_capacity"] = cap

    if (len(x[binId]["item_ids"]) == 0) :
        del x[binId]

    #Repacking
    unpackedItems.sort(key=GetWeight,reverse=True)
    for id in unpackedItems:
        validBins = list(filter(lambda bin: x[bin]["remaining_capacity"] > itemsInfo[id], x.keys()))
        if (len(validBins) == 0):
            newId = uuid.uuid4()
            validBinTypes = list(filter(lambda bin: binsInfo[bin]["capacity"] > itemsInfo[id], binsInfo))
            validProbabilites = tuple(map(lambda bin: binsInfo[bin]["probability"], validBinTypes))
            selectedBin = random.choices(validBinTypes, weights=validProbabilites, k=1)[0]
            remainingCapacity = binsInfo[selectedBin]["capacity"] - itemsInfo[id]
            x[newId] = {"bin_type": selectedBin, "item_ids": [id], "remaining_capacity": remainingCapacity}
        else :
            validProbabilites = tuple(map(lambda bin: x[bin]["remaining_capacity"], validBins))
            # print(f"Item : {id} {itemsInfo[id]} | Bins : {validBins} {validProbabilites}")
            selectedBin = random.choices(validBins, weights=validProbabilites, k=1)[0]
            x[selectedBin]["item_ids"].append(id)
            x[selectedBin]["remaining_capacity"] = RemainingCapacity(x, selectedBin)
            # print(f"{selectedBin} {x[selectedBin]['remaining_capacity']} ")


    return x

# %%
def ValidateSolution(x : dict):
    for id,info in x.items():
        print(f"Bin type : {info['bin_type']} | Item ID : {info['item_ids']} | Remaining Capacity :{info['remaining_capacity']}")
        weight = 0
        for itemId in info['item_ids'] :
            weight += itemsInfo[itemId]
        capacity = binsInfo[info['bin_type']]['capacity']
        # print(f"Calculated Weight {weight} | Calculated Capacity {capacity} | Calculated Remaining Capacity : {capacity - weight}")
        print("")

# %%
def N1(x: dict):
    binIds = list(x.keys())
    selected_length = int(len(binIds)*0.15)
    bin_samples = random.sample(binIds, selected_length)
    for binId in bin_samples:
        newBinType = random.choice(
            [i for i in range(1, 4) if i != x[binId]["bin_type"]])
        oldCapacity = RemainingCapacity(x, binId)
        oldBinType = x[binId]["bin_type"]
        x[binId]["bin_type"] = newBinType
        newCapacity = RemainingCapacity(x, binId)
        x[binId]["remaining_capacity"] = newCapacity
        # print(f"{binId} | New : {newBinType} {newCapacity} | Old : {oldBinType} {oldCapacity}")

        if newCapacity < 0:
            x = UnpackRepack(x, binId, newCapacity, newBinType)
    return x

# %%
def GetBin(x,itemId):
    for id,info in x.items():
        if itemId in info["item_ids"]:
            info["bin_id"] = id
            return info

# %%
def GetCapacity(bin):
    return bin["remaining_capacity"]


def N4(x : dict):
    itemStuff = {}
    for id,info in x.items() :
        for itemId in info["item_ids"]:
            itemStuff[itemId] = {"bin_id": id, "remaining_capacity": info["remaining_capacity"]}
    for id in itemsInfo :
        binA = GetBin(x,id) 
        validBins = list(filter(lambda bin: x[bin]["remaining_capacity"] > itemsInfo[id] and x[bin]["remaining_capacity"] - itemsInfo[id] < binA["remaining_capacity"] and bin != binA["bin_id"], x.keys()))
        validBinInfo = list(map(lambda bin: {"remaining_capacity": x[bin]["remaining_capacity"], "bin_id": bin}, validBins))
        validBinInfo.sort(key=GetCapacity)
        if len(validBinInfo) == 0 :
            continue 
        binB = validBinInfo[0]
        # print(itemsInfo[id],binA, binB)

        x[binA["bin_id"]]["item_ids"].remove(id)
        x[binA["bin_id"]]["remaining_capacity"] = RemainingCapacity(x, binA["bin_id"])
        if (len(x[binA["bin_id"]]["item_ids"]) == 0):
            del x[binA["bin_id"]]

        x[binB["bin_id"]]["item_ids"].append(id)
        x[binB["bin_id"]]["remaining_capacity"] = RemainingCapacity(x, binB["bin_id"])
        
        # print("After Shift :")
        # print(x[binA["bin_id"]], x[binB["bin_id"]])
        # print()
    return x

def N5(x : dict):
    itemStuff = {}
    for id,info in x.items() :
        for itemId in info["item_ids"]:
            itemStuff[itemId] = {"bin_id": id, "remaining_capacity": info["remaining_capacity"]}
    for itemId in itemsInfo:
        binA = GetBin(x,itemId)
        
        aRemainingCApacity = binA["remaining_capacity"]
        validIds = {}
        for id,info in x.items():
            itemIds = info["item_ids"]
            bRemainingCapacity = info["remaining_capacity"]
            itemIds.sort(key=GetWeight,reverse=True)
            swappedId = ""
            for sId in itemIds:
                # print(itemsInfo[sId], bRemainingCapacity + itemsInfo[sId], itemsInfo[itemId])
                if bRemainingCapacity + itemsInfo[sId] > itemsInfo[itemId] and itemsInfo[itemId] > itemsInfo[sId] and bRemainingCapacity + itemsInfo[sId] - itemsInfo[itemId] < aRemainingCApacity:
                    swappedId = sId
            if swappedId == "" :
                continue
            # print(
            #     f"SWAP : {swappedId} {itemsInfo[swappedId]} | Item : {itemId} {itemsInfo[itemId]}   ")
            validIds[swappedId] =  bRemainingCapacity +itemsInfo[swappedId] - itemsInfo[itemId]
        # print("..................")
        finalId = ""
        for ab in validIds.keys() :
            if finalId == "":
                finalId = ab
                continue
            if validIds[finalId] > validIds[ab]:
                finalId = ab
        # print(validIds,finalId)
        if (finalId == ""):
            continue
        binB = GetBin(x,finalId)
        # print(f"Swapping {x[binA['bin_id']]} and {x[binB['bin_id']]}")
        # print(f"binA item : {itemId} {itemsInfo[itemId]} | binB item : {finalId} {itemsInfo[finalId]}")
        # print(f"binA capacity : {binA['remaining_capacity']} binB capacity : {binB['remaining_capacity']}  ")

        x[binA["bin_id"]]["item_ids"].remove(itemId)
        x[binA["bin_id"]]["item_ids"].append(finalId)
        x[binA["bin_id"]]["remaining_capacity"] = RemainingCapacity(x, binA["bin_id"])
        
        x[binB["bin_id"]]["item_ids"].remove(finalId)
        x[binB["bin_id"]]["item_ids"].append(itemId)
        x[binB["bin_id"]]["remaining_capacity"] = RemainingCapacity(x, binB["bin_id"])
        # print(f"new binA capacity : {x[binA['bin_id']]['remaining_capacity']} new binB capacity : {x[binB['bin_id']]['remaining_capacity']}")
    return x

def ChangeBinType(x):
    for id,info in x.items():
        remainingCapacity = info["remaining_capacity"]
        binSize = binsInfo[info["bin_type"]]["capacity"]
        for type,binInfo in binsInfo.items():
            if binSize - remainingCapacity < binInfo["capacity"] and binSize > binInfo["capacity"]:
                x[id]["bin_type"] = type
                x[id]["remaining_capacity"] = RemainingCapacity(x,id)
                # print(type, binInfo["capacity"], remainingCapacity, binSize, RemainingCapacity(x, id), binInfo["capacity"] - binSize + remainingCapacity)
    return x

def LocalSearch(x1):
    x3 = N4(x1)
    # x4 = N5(x3)
    # x5 = N6(x4)

    return x3

def N6(x):
    high = 0
    removeId = ""
    for id,info in x.items():
        if info["remaining_capacity"] > high:
            removeId = id
            high = info["remaining_capacity"]
    itemIds = x[removeId]["item_ids"]

    for itemId in itemIds:
        low = 9999
        addId = ""
        weight = itemsInfo[itemId]
        for id,info in x.items():
            if (info["remaining_capacity"] < low and info["remaining_capacity"] > weight):
                addId = id
                low = info["remaining_capacity"]
        
        if (addId == ""):
            continue
        # print("Doing stuff")
        x[removeId]["item_ids"].remove(itemId)
        x[removeId]["remaining_capacity"] = RemainingCapacity(x, removeId)

        x[addId]["item_ids"].append(itemId)
        x[addId]["remaining_capacity"] = RemainingCapacity(x, addId)
    
    if len(x[removeId]["item_ids"]) == 0:
        del x[removeId]

    return x
    
        


def LocalSearchv2(x1):
    x3 = N4(x1)
    x4 = N5(x3)
    x5 = N6(x4)
    x6 = ChangeBinType(x4)
    return x6

# %%
def N2(x):
    binIds = list(x.keys())
    selected_length = int(len(binIds)*0.05)
    bin_samples = random.sample(binIds, selected_length)
    for binId in bin_samples:
        itemIds = x[binId]["item_ids"]
        del x[binId]
        for id in itemIds:
            newId = uuid.uuid4()
            w = itemsInfo[id]
            validBinTypes = list(filter(lambda bin: binsInfo[bin]["capacity"] > w, binsInfo))
            validProbabilites = tuple(map(lambda bin: binsInfo[bin]["probability"], validBinTypes))
            selectedBin = random.choices(validBinTypes, weights=validProbabilites, k=1)[0]
            remainingCapacity = binsInfo[selectedBin]["capacity"] - itemsInfo[id]
            x[newId] = {"bin_type": selectedBin, "item_ids": [id], "remaining_capacity": remainingCapacity}
    return x

# %%
def Shaking(x, k):
    if (k == 1):
        shook = N1(x)
    if (k == 2):
        shook = N2(x)
    else:
        return x
    return shook

# %%
def N1N2LS():
    x = GenerateInitialSolution()
    # print(f"Initial Bins Used {len(x.keys())}")
    # print(f"Initial Cost {Cost(x)}\n")
    # ValidateSolution(x)
    finish = False
    count = 0
    c1, c2, c3 = 1, 1, 1
    c1Total, c2Total, c3Total = 1,1,1
    total = 0
    startTime = time.time()
    while not finish:
        k = ChooseNeightbourhood(c1/c1Total,c2/c2Total)
        if k == 1:
            c1Total +=1
        if k == 2:
            c2Total +=1
        oldX = copy.deepcopy(x)
        x1 = Shaking(x, 1)
        x2 = LocalSearchv2(x1)
        # print(f"Old Cost : {Cost(oldX)} New Cost : {Cost(x2)}")
        # print(f"Chosen Neighbourhood {k}")
        if (Cost(x2) < Cost(oldX)):
            if (k== 1):
                c1 += 1
            if (k == 2):
                c2 += 1
            updatedTime = time.time()
            x = x2
        else:
            x = oldX
        if (time.time() - startTime > 50):
            finish = True
    totalTime = updatedTime - startTime
    totalBins = len(x.keys())
    print(f"Total Bins Used {totalBins}")
    print(f"Final Optimised Cost {Cost(x)}")
    print(f"Last updated time : {totalTime}")
    print("")
    ValidateSolution(x)

    return totalBins, Cost(x), totalTime


N1N2LS_BINS, N1N2LS_COST, N1N2LS_TIME = N1N2LS()
# Out:
# Total Bins Used 435
# Final Optimised Cost 51430
# Last updated time : 32.80671143531799
#
# Bin type : 3 | Item ID : ['item976', 'item86', 'item876', 'item261'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item679', 'item98'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item237', 'item112'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item851', 'item50', 'item557'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item351', 'item62', 'item914'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item512', 'item723'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item752', 'item316', 'item201'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item548', 'item774'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item78', 'item667', 'item698'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item84'] | Remaining Capacity :0
#
# Bin type : 2 | Item ID : ['item36', 'item102'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item47', 'item75'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item108', 'item117'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item133', 'item119'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item761', 'item516'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item136', 'item77', 'item157'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item53', 'item161'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item109', 'item908', 'item226'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item171', 'item166'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item291', 'item176', 'item27', 'item40'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item172', 'item457', 'item481'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item762', 'item188', 'item817'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item328', 'item977', 'item566', 'item485'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item116', 'item184'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item121', 'item429'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item842', 'item467', 'item706'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item367', 'item452'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item509', 'item74', 'item206'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item99', 'item163'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item222', 'item42'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item69', 'item224'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item228', 'item111', 'item924'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item506', 'item735', 'item21'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item259', 'item5', 'item823'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item847', 'item149'] | Remaining Capacity :3
#
# Bin type : 3 | Item ID : ['item247', 'item208'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item263', 'item138'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item265', 'item100'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item54', 'item296'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item151', 'item967'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item314', 'item196'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item589', 'item782', 'item609'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item325', 'item187', 'item271', 'item320'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item327', 'item898', 'item889'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item333', 'item46', 'item255', 'item88'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item339', 'item82'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item250', 'item139', 'item961'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item345', 'item204'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item338', 'item126'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item173', 'item353'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item51'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item132'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item419', 'item179', 'item359'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item152', 'item482'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item309', 'item743'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item376', 'item135'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item392', 'item114', 'item972'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item146', 'item10'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item225', 'item387'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item390', 'item174'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item365', 'item929'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item44', 'item406'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item7', 'item538'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item300', 'item565', 'item409', 'item238'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item350', 'item415'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item205', 'item798'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item491', 'item922', 'item363'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item106', 'item423'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item131', 'item425', 'item249', 'item857'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item93', 'item18'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item801', 'item835', 'item731'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item744', 'item461', 'item153', 'item122'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item464', 'item456'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item979', 'item418'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item38', 'item479', 'item14', 'item410'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item143', 'item733', 'item167'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item141', 'item484', 'item483'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item716'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item487', 'item159'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item492', 'item472'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item496', 'item253'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item213', 'item361', 'item843'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['
] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item825', 'item216'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item101', 'item777'] | Remaining Capacity :2
#
# Bin type : 3 | Item ID : ['item927', 'item899', 'item360', 'item158'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item13', 'item568'] | Remaining Capacity :6
#
# Bin type : 2 | Item ID : ['item193', 'item76'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item35'] | Remaining Capacity :7
#
# Bin type : 2 | Item ID : ['item745'] | Remaining Capacity :11
#
# Bin type : 2 | Item ID : ['item880', 'item799'] | Remaining Capacity :2
#
# Bin type : 2 | Item ID : ['item590', 'item429'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item957', 'item582'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item811', 'item795', 'item331'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item278', 'item8'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item259', 'item21'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item981', 'item814'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item731', 'item857', 'item706'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item223', 'item920'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item421'] | Remaining Capacity :6
#
# Bin type : 3 | Item ID : ['item982', 'item973'] | Remaining Capacity :10
#
# Bin type : 3 | Item ID : ['item459', 'item194'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item956', 'item151'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item44', 'item778'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item41', 'item12'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item965', 'item322'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item861', 'item196'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item600', 'item45'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item832', 'item718'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item71', 'item154'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item931', 'item883'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item734', 'item303', 'item89'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item569', 'item74', 'item576'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item911', 'item787'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item306'] | Remaining Capacity :32
#
# Bin type : 2 | Item ID : ['item683'] | Remaining Capacity :3
#
# Bin type : 2 | Item ID : ['item112', 'item466'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item781', 'item751'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item433', 'item722'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item642'] | Remaining Capacity :11
#
# Bin type : 3 | Item ID : ['item702', 'item617', 'item888'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item458', 'item960'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item675', 'item901'] | Remaining Capacity :2
#
# Bin type : 2 | Item ID : ['item995'] | Remaining Capacity :5
#
# Bin type : 1 | Item ID : ['item59', 'item556', 'item157'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item798', 'item835', 'item453'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item358', 'item748'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item286', 'item86'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item563'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item793', 'item669'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item437', 'item586'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item776', 'item612'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item525', 'item149', 'item677'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item838', 'item516'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item438', 'item730'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item340', 'item480', 'item659', 'item186'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item63', 'item335'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item398'] | Remaining Capacity :2
#
# Bin type : 3 | Item ID : ['item419', 'item392'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item489', 'item950', 'item60'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item755', 'item685'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item297', 'item803', 'item134'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item54', 'item921', 'item614'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item334', 'item958'] | Remaining Capacity :5
#
# Bin type : 3 | Item ID : ['item851', 'item175'] | Remaining Capacity :2
#
# Bin type : 2 | Item ID : ['item143', 'item81'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item571'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item471', 'item649'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item84', 'item720'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item992'] | Remaining Capacity :11
#
# Bin type : 1 | Item ID : ['item106'] | Remaining Capacity :16
#
# Bin type : 2 | Item ID : ['item773'] | Remaining Capacity :17
#
# Bin type : 3 | Item ID : ['item374', 'item853', 'item621'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item352'] | Remaining Capacity :12

# %%
def N1N4():
    x = GenerateInitialSolution()
    # print(f"Initial Bins Used {len(x.keys())}")
    # print(f"Initial Cost {Cost(x)}\n")
    # ValidateSolution(x)
    finish = False
    count = 0
    c1, c2, c3 = 0, 1, 1
    startTime = time.time()
    while not finish:
        #     # k = ChooseNeightbourhood(c1,c2,c3)
        oldX = copy.deepcopy(x)
        count += 1
        x1 = Shaking(x, 1)
        x2 = LocalSearch(x1)
        # print(f"Old Cost : {Cost(oldX)} New Cost : {Cost(x2)}")
        if (Cost(x2) < Cost(oldX)):
            c1 += 1
            updatedTime = time.time()
            x = x2
        else:
            x = oldX
        if (time.time() - startTime > 50):
            finish = True
    totalTime = updatedTime - startTime
    totalBins = len(x.keys())
    print(f"Total Bins Used {totalBins}")
    print(f"Final Optimised Cost {Cost(x)}")
    print(f"Last updated time : {totalTime}")
    print(c1)
    print("")
    ValidateSolution(x)

    return totalBins,Cost(x),totalTime

N1N4_BINS,N1N4_COST,N1N4_TIME = N1N4()
# Out:
# Total Bins Used 452
# Final Optimised Cost 51790
# Last updated time : 15.175729990005493
# 7
#
# Bin type : 1 | Item ID : ['item24', 'item12'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item28', 'item15'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item407', 'item320', 'item33', 'item258'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item35', 'item19'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item45', 'item7'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item53', 'item43'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item32', 'item163'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item945', 'item146', 'item420', 'item723'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item76', 'item74'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item50'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item371', 'item868'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item520', 'item156'] | Remaining Capacity :2
#
# Bin type : 3 | Item ID : ['item98', 'item54'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item105', 'item88'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item107', 'item68'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item113', 'item103'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item116'] | Remaining Capacity :11
#
# Bin type : 3 | Item ID : ['item121', 'item845', 'item335'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item542', 'item171', 'item513'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item36', 'item269', 'item550'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item131', 'item86'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item139', 'item83'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item143', 'item2', 'item133'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item159', 'item97'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item63', 'item450', 'item218'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item166', 'item108'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item173', 'item916', 'item66', 'item226'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item174', 'item6'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item175', 'item23'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item907', 'item129', 'item278', 'item262'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item186', 'item38', 'item178'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item187', 'item90', 'item77'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item188', 'item883', 'item854'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item190', 'item164'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item191', 'item26'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item193', 'item91'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item195', 'item75'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item198', 'item185'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item206', 'item179'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item207', 'item141'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item210', 'item136'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item220', 'item81'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item222', 'item9'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item250', 'item843'] | Remaining Capacity :4
#
# Bin type : 2 | Item ID : ['item69', 'item20'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item227', 'item58'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item228', 'item27'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item1', 'item710'] | Remaining Capacity :2
#
# Bin type : 3 | Item ID : ['item231', 'item165', 'item110'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item234', 'item102'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item94'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item241', 'item93'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item196', 'item966', 'item576', 'item244'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item47', 'item537', 'item874'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item246', 'item152'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item247', 'item64'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item248', 'item158'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item777', 'item666', 'item275'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item252', 'item151'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item208', 'item78', 'item399', 'item818'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item256', 'item194'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item926', 'item412', 'item700'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item266', 'item214'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item243', 'item25'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item251', 'item287', 'item21'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item272', 'item184'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item277', 'item138'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item279', 'item40'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item280'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item457', 'item380'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item291', 'item625'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item288', 'item955', 'item225'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item838', 'item338'] | Remaining Capacity :2
#
# Bin type : 3 | Item ID : ['item293', 'item471', 'item239'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item299', 'item286'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item128', 'item305'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item303', 'item144'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item375', 'item177', 'item343', 'item168'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item313', 'item211'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item314', 'item612', 'item301', 'item715'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item304', 'item379', 'item481'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item197', 'item979'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item318', 'item150'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item323', 'item652', 'item14'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item328', 'item396', 'item204'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item330', 'item155'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item333', 'item776', 'item82'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item545', 'item237', 'item532', 'item157'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item336', 'item169'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item707', 'item716', 'item890'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item341', 'item249', 'item888', 'item18'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item344', 'item170'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item265', 'item92'] | Remaining Capacity :3
#
# Bin type : 3 | Item ID : ['item349', 'item96'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item298'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item963', 'item414'] | Remaining Capacity :6
#
# Bin type : 3 | Item ID : ['item367', 'item306'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item106', 'item765'] | Remaining Capacity :2
#
# Bin type : 3 | Item ID : ['item274', 'item504', 'item604'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item389', 'item356', 'item229', 'item167'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item391', 'item142'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item402', 'item307'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item408', 'item255'] | Remaining Capacity :2
#
# Bin type : 3 | Item ID : ['item409', 'item374', 'item385'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item368', 'item570'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item415', 'item172'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item416'] | Remaining Capacity :3
#
# Bin type : 3 | Item ID : ['item419', 'item392'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item588', 'item347'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item421', 'item395'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item422', 'item140'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item423', 'item114', 'item699', 'item99'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item430', 'item48', 'item501'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item432', 'item428'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item433', 'item369'] | Remaining Capacity :2
#
# Bin type : 3 | Item ID : ['item436', 'item61'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item127'] | Remaining Capacity :3
#
# Bin type : 3 | Item ID : ['item448', 'item398'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item393', 'item290', 'item665'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item451'] | Remaining Capacity :13
#
# Bin type : 2 | Item ID : ['item805', 'item499'] | Remaining Capacity :4
#
# Bin type : 3 | Item ID : ['item465', 'item737', 'item260'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item467', 'item352'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item468', 'item394', 'item574', 'item212', 'item55'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item470', 'item456'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item473', 'item281'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item474', 'item17'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item126', 'item618'] | Remaining Capacity :6
#
# Bin type : 3 | Item ID : ['item479', 'item326'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item431', 'item538', 'item698'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item483', 'item425'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item486', 'item355'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item487', 'item216'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item458', 'item219', 'item701'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item496', 'item424'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item506', 'item434'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item426', 'item935', 'item261'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item476', 'item632'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item516', 'item135', 'item386', 'item493'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item67', 'item568'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item664', 'item819'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item512'] | Remaining Capacity :2
#
# Bin type : 2 | Item ID : ['item334'] | Remaining Capacity :0
#
# Bin type : 3 | Item ID : ['item534', 'item283'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item510', 'item60'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item720', 'item464', 'item517'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item549', 'item410', 'item95', 'item209'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item551', 'item524'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item556', 'item302'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item564', 'item295'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item565', 'item364', 'item703'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item566', 'item377', 'item674', 'item124'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item567', 'item490', 'item183'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item569', 'item263', 'item726'] | Remaining Capacity :2
#
# Bin type : 2 | Item ID : ['item571'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item573', 'item46'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item579', 'item440'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item729', 'item485'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item582', 'item308', 'item617', 'item100'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item161', 'item629', 'item804'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item584', 'item276'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item938', 'item543'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item586', 'item577', 'item271'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item591', 'item511'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item595', 'item539'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item599', 'item405'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item602', 'item300'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item608', 'item528'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item361', 'item733'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item610', 'item120'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item615', 'item192'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item616', 'item339'] | Remaining Capacity :2
#
# Bin type : 2 | Item ID : ['item563'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item619', 'item376'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item621', 'item498'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item808', 'item711'] | Remaining Capacity :42
#
# Bin type : 1 | Item ID : ['item624', 'item461'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item633', 'item622'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item634', 'item515'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item636', 'item853', 'item441'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item637', 'item327'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item638', 'item397'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item639', 'item447'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item640', 'item360'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item643', 'item388'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item644', 'item145'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item645', 'item366'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item887', 'item10'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item649'] | Remaining Capacity :3
#
# Bin type : 2 | Item ID : ['item205', 'item34'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item592', 'item747', 'item685', 'item201'] | Remaining Capacity :2
#
# Bin type : 1 | Item ID : ['item659', 'item348'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item658', 'item997'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item656', 'item782'] | Remaining Capacity :3
#
# Bin type : 2 | Item ID : ['item669', 'item514'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item671', 'item488'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item679', 'item296'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item660'] | Remaining Capacity :0
#
# Bin type : 2 | Item ID : ['item682', 'item484', 'item345'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item683', 'item603'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item79', 'item884'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item687', 'item42'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item688', 'item233'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item691', 'item620'] | Remaining Capacity :4
#
# Bin type : 2 | Item ID : ['item525', 'item519'] | Remaining Capacity :2
#
# Bin type : 3 | Item ID : ['item694', 'item130', 'item56'] | Remaining Capacity :2
#
# Bin type : 2 | Item ID : ['item709'] | Remaining Capacity :20
#
# Bin type : 2 | Item ID : ['item552', 'item406'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item459', 'item852'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item718', 'item454'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item704'] | Remaining Capacity :3
#
# Bin type : 3 | Item ID : ['item724', 'item734'] | Remaining Capacity :3
#
# Bin type : 3 | Item ID : ['item553', 'item321', 'item284'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item731', 'item329', 'item831'] | Remaining Capacity :2
#
# Bin type : 2 | Item ID : ['
] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item546', 'item242'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item949', 'item770'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item495', 'item147'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item358'] | Remaining Capacity :5
#
# Bin type : 3 | Item ID : ['item775', 'item802', 'item858'] | Remaining Capacity :6
#
# Bin type : 2 | Item ID : ['item507', 'item821'] | Remaining Capacity :7
#
# Bin type : 2 | Item ID : ['item892', 'item215'] | Remaining Capacity :2
#
# Bin type : 3 | Item ID : ['item449', 'item900', 'item417'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item940'] | Remaining Capacity :11
#
# Bin type : 3 | Item ID : ['item801', 'item870', 'item104'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item84', 'item964', 'item833'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item200', 'item400'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item994', 'item5', 'item822'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item236', 'item439'] | Remaining Capacity :2
#
# Bin type : 3 | Item ID : ['item437', 'item351'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item842', 'item160'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item51', 'item735'] | Remaining Capacity :6
#
# Bin type : 2 | Item ID : ['item382'] | Remaining Capacity :3
#
# Bin type : 3 | Item ID : ['item44', 'item878', 'item354'] | Remaining Capacity :2
#
# Bin type : 2 | Item ID : ['item518', 'item931'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item727', 'item555', 'item672'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item137', 'item4'] | Remaining Capacity :3
#
# Bin type : 3 | Item ID : ['item606', 'item693'] | Remaining Capacity :2
#
# Bin type : 2 | Item ID : ['item680', 'item531'] | Remaining Capacity :2
#
# Bin type : 2 | Item ID : ['item489', 'item57'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item494', 'item332'] | Remaining Capacity :2
#
# Bin type : 1 | Item ID : ['item788'] | Remaining Capacity :5
#
# Bin type : 3 | Item ID : ['item630', 'item491'] | Remaining Capacity :3
#
# Bin type : 2 | Item ID : ['item696', 'item651'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item109', 'item119'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item316', 'item554', 'item466'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item259', 'item49'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item418', 'item834'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item851', 'item748', 'item72'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item547', 'item213'] | Remaining Capacity :2
#
# Bin type : 2 | Item ID : ['item830'] | Remaining Capacity :2
#
# Bin type : 2 | Item ID : ['item832', 'item180'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item992', 'item322'] | Remaining Capacity :5
#
# Bin type : 2 | Item ID : ['item742'] | Remaining Capacity :3
#
# Bin type : 3 | Item ID : ['item297', 'item891'] | Remaining Capacity :2
#
# Bin type : 3 | Item ID : ['item962', 'item942', 'item87'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item530'] | Remaining Capacity :6
#
# Bin type : 1 | Item ID : ['item785'] | Remaining Capacity :5
#
# Bin type : 3 | Item ID : ['item948', 'item292'] | Remaining Capacity :2
#
# Bin type : 3 | Item ID : ['item310', 'item16'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item115', 'item3'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item895', 'item30'] | Remaining Capacity :4
#
# Bin type : 3 | Item ID : ['item642', 'item317'] | Remaining Capacity :2
#
# Bin type : 2 | Item ID : ['item11', 'item31'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item881', 'item601'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item312'] | Remaining Capacity :13
#
# Bin type : 2 | Item ID : ['item849'] | Remaining Capacity :2
#
# Bin type : 3 | Item ID : ['item217', 'item580'] | Remaining Capacity :2
#
# Bin type : 2 | Item ID : ['item41'] | Remaining Capacity :6
#
# Bin type : 3 | Item ID : ['item71', 'item561'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item445'] | Remaining Capacity :6
#
# Bin type : 3 | Item ID : ['item861', 'item974'] | Remaining Capacity :11
#
# Bin type : 2 | Item ID : ['item435', 'item363'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item223', 'item176'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item502'] | Remaining Capacity :8
#
# Bin type : 3 | Item ID : ['item925', 'item221'] | Remaining Capacity :4
#
# Bin type : 3 | Item ID : ['item65', 'item647', 'item181'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item522'] | Remaining Capacity :13
#
# Bin type : 2 | Item ID : ['item257'] | Remaining Capacity :6
#
# Bin type : 3 | Item ID : ['item357', 'item29'] | Remaining Capacity :2
#
# Bin type : 3 | Item ID : ['item668', 'item80'] | Remaining Capacity :2
#
# Bin type : 3 | Item ID : ['item657', 'item85'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item232', 'item224'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item373'] | Remaining Capacity :9
#
# Bin type : 3 | Item ID : ['item365', 'item381'] | Remaining Capacity :2
#
# Bin type : 2 | Item ID : ['item675'] | Remaining Capacity :8
#
# Bin type : 2 | Item ID : ['item811', 'item182'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item826'] | Remaining Capacity :68
#
# Bin type : 2 | Item ID : ['item340', 'item732'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item719'] | Remaining Capacity :12
#
# Bin type : 3 | Item ID : ['item792', 'item384'] | Remaining Capacity :4
#
# Bin type : 3 | Item ID : ['item37', 'item929'] | Remaining Capacity :2
#
# Bin type : 2 | Item ID : ['item779'] | Remaining Capacity :7
#
# Bin type : 2 | Item ID : ['item750'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item325', 'item863'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item311', 'item462'] | Remaining Capacity :2
#
# Bin type : 3 | Item ID : ['item880', 'item378'] | Remaining Capacity :8
#
# Bin type : 3 | Item ID : ['item541', 'item526'] | Remaining Capacity :3
#
# Bin type : 3 | Item ID : ['item500', 'item427'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item535', 'item59'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item123', 'item730'] | Remaining Capacity :2
#
# Bin type : 3 | Item ID : ['item562', 'item661'] | Remaining Capacity :2
#
# Bin type : 3 | Item ID : ['item702', 'item505'] | Remaining Capacity :8
#
# Bin type : 2 | Item ID : ['item202'] | Remaining Capacity :3
#
# Bin type : 2 | Item ID : ['item678', 'item800'] | Remaining Capacity :3
#
# Bin type : 3 | Item ID : ['item540', 'item13'] | Remaining Capacity :3
#
# Bin type : 2 | Item ID : ['item589', 'item230'] | Remaining Capacity :4
#
# Bin type : 3 | Item ID : ['item684', 'item203'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item721', 'item117'] | Remaining Capacity :1

# %%
def OnlyN1():
    # t0 = time.time()
    x = GenerateInitialSolution()
    # print(f"Initial Bins Used {len(x.keys())}")
    # print(f"Initial Cost {Cost(x)}\n")
    # ValidateSolution(x)
    
    finish = False
    count = 0
    c1,c2,c3 = 0,1,1
    startTime = time.time()
    while not finish:
    #     # k = ChooseNeightbourhood(c1,c2,c3)
        oldX = copy.deepcopy(x)
        count +=1
        x1 = Shaking(x,1)
        # print(f"Old Cost : {Cost(oldX)} New Cost : {Cost(x1)}")
        if (Cost(x1) < Cost(oldX)):
            c1+=1
            updatedTime = time.time()
            x = x1
        else :
            x = oldX
        if (time.time() - startTime > 50):
            finish = True
    totalTime = updatedTime - startTime
    totalBins = len(x.keys())
    print(f"Total Bins Used {totalBins}")
    print(f"Final Optimised Cost {Cost(x)}")
    print(f"Last updated time : {totalTime}")
    print(c1)
    print("")
    ValidateSolution(x)

    return totalBins, Cost(x), totalTime

N1_BINS,N1_COST,N1_TIME = OnlyN1()
# Out:
# Total Bins Used 519
# Final Optimised Cost 57390
# Last updated time : 45.12509775161743
# 52
#
# Bin type : 2 | Item ID : ['item2', 'item380'] | Remaining Capacity :12
#
# Bin type : 2 | Item ID : ['item408', 'item189'] | Remaining Capacity :9
#
# Bin type : 2 | Item ID : ['item856', 'item119'] | Remaining Capacity :23
#
# Bin type : 2 | Item ID : ['item896'] | Remaining Capacity :13
#
# Bin type : 2 | Item ID : ['item10', 'item795', 'item700', 'item331'] | Remaining Capacity :2
#
# Bin type : 2 | Item ID : ['item572', 'item243'] | Remaining Capacity :2
#
# Bin type : 2 | Item ID : ['item15', 'item226', 'item717', 'item362'] | Remaining Capacity :6
#
# Bin type : 3 | Item ID : ['item138', 'item446', 'item849'] | Remaining Capacity :7
#
# Bin type : 1 | Item ID : ['item17', 'item884'] | Remaining Capacity :5
#
# Bin type : 3 | Item ID : ['item20', 'item855', 'item468', 'item186', 'item608'] | Remaining Capacity :14
#
# Bin type : 1 | Item ID : ['item24', 'item79'] | Remaining Capacity :11
#
# Bin type : 1 | Item ID : ['item25'] | Remaining Capacity :17
#
# Bin type : 3 | Item ID : ['item948', 'item153'] | Remaining Capacity :30
#
# Bin type : 3 | Item ID : ['item684', 'item618'] | Remaining Capacity :3
#
# Bin type : 3 | Item ID : ['item712', 'item583'] | Remaining Capacity :3
#
# Bin type : 2 | Item ID : ['item4', 'item895'] | Remaining Capacity :6
#
# Bin type : 3 | Item ID : ['item577', 'item570'] | Remaining Capacity :5
#
# Bin type : 2 | Item ID : ['item417', 'item870', 'item663'] | Remaining Capacity :4
#
# Bin type : 1 | Item ID : ['item42', 'item649'] | Remaining Capacity :2
#
# Bin type : 2 | Item ID : ['item43', 'item321', 'item320', 'item805'] | Remaining Capacity :7
#
# Bin type : 3 | Item ID : ['item301', 'item393', 'item112', 'item765'] | Remaining Capacity :16
#
# Bin type : 1 | Item ID : ['item897', 'item844'] | Remaining Capacity :4
#
# Bin type : 3 | Item ID : ['item930', 'item154', 'item75'] | Remaining Capacity :38
#
# Bin type : 3 | Item ID : ['item58', 'item571'] | Remaining Capacity :8
#
# Bin type : 1 | Item ID : ['item214'] | Remaining Capacity :19
#
# Bin type : 3 | Item ID : ['item383', 'item782'] | Remaining Capacity :2
#
# Bin type : 1 | Item ID : ['item66', 'item130'] | Remaining Capacity :3
#
# Bin type : 3 | Item ID : ['item67', 'item658', 'item881'] | Remaining Capacity :8
#
# Bin type : 1 | Item ID : ['item758'] | Remaining Capacity :23
#
# Bin type : 2 | Item ID : ['item78', 'item183'] | Remaining Capacity :17
#
# Bin type : 3 | Item ID : ['item409', 'item45', 'item11'] | Remaining Capacity :5
#
# Bin type : 3 | Item ID : ['item85', 'item913', 'item303'] | Remaining Capacity :32
#
# Bin type : 2 | Item ID : ['item87', 'item756'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item88', 'item680'] | Remaining Capacity :8
#
# Bin type : 1 | Item ID : ['item97'] | Remaining Capacity :19
#
# Bin type : 3 | Item ID : ['item963', 'item99', 'item70', 'item34', 'item654'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item174', 'item401', 'item508'] | Remaining Capacity :2
#
# Bin type : 3 | Item ID : ['item256', 'item104', 'item703'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item125', 'item692', 'item991'] | Remaining Capacity :5
#
# Bin type : 2 | Item ID : ['item128', 'item900'] | Remaining Capacity :3
#
# Bin type : 2 | Item ID : ['item132', 'item873'] | Remaining Capacity :2
#
# Bin type : 1 | Item ID : ['item964'] | Remaining Capacity :18
#
# Bin type : 1 | Item ID : ['item962'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item946'] | Remaining Capacity :13
#
# Bin type : 1 | Item ID : ['item149'] | Remaining Capacity :21
#
# Bin type : 3 | Item ID : ['item213', 'item422'] | Remaining Capacity :7
#
# Bin type : 2 | Item ID : ['item890', 'item471'] | Remaining Capacity :0
#
# Bin type : 3 | Item ID : ['item155', 'item220', 'item379'] | Remaining Capacity :6
#
# Bin type : 1 | Item ID : ['item201', 'item481', 'item511'] | Remaining Capacity :13
#
# Bin type : 2 | Item ID : ['item31', 'item196'] | Remaining Capacity :4
#
# Bin type : 3 | Item ID : ['item167', 'item763', 'item253', 'item356', 'item561'] | Remaining Capacity :16
#
# Bin type : 2 | Item ID : ['item210'] | Remaining Capacity :2
#
# Bin type : 2 | Item ID : ['item516', 'item289', 'item290'] | Remaining Capacity :5
#
# Bin type : 3 | Item ID : ['item180', 'item476', 'item919', 'item255'] | Remaining Capacity :9
#
# Bin type : 2 | Item ID : ['item956'] | Remaining Capacity :4
#
# Bin type : 2 | Item ID : ['item381'] | Remaining Capacity :31
#
# Bin type : 1 | Item ID : ['item981'] | Remaining Capacity :13
#
# Bin type : 2 | Item ID : ['item223'] | Remaining Capacity :3
#
# Bin type : 3 | Item ID : ['item202', 'item768'] | Remaining Capacity :35
#
# Bin type : 3 | Item ID : ['item142', 'item631', 'item999', 'item448'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item207', 'item144', 'item302', 'item836', 'item945'] | Remaining Capacity :8
#
# Bin type : 2 | Item ID : ['item208', 'item271'] | Remaining Capacity :14
#
# Bin type : 2 | Item ID : ['item488', 'item837', 'item906', 'item182'] | Remaining Capacity :2
#
# Bin type : 2 | Item ID : ['item216', 'item518'] | Remaining Capacity :11
#
# Bin type : 2 | Item ID : ['item219', 'item177'] | Remaining Capacity :7
#
# Bin type : 1 | Item ID : ['item959'] | Remaining Capacity :14
#
# Bin type : 1 | Item ID : ['item560'] | Remaining Capacity :10
#
# Bin type : 1 | Item ID : ['item225', 'item462'] | Remaining Capacity :6
#
# Bin type : 1 | Item ID : ['item636'] | Remaining Capacity :5
#
# Bin type : 1 | Item ID : ['item673', 'item335'] | Remaining Capacity :22
#
# Bin type : 3 | Item ID : ['item241', 'item742'] | Remaining Capacity :18
#
# Bin type : 2 | Item ID : ['item248', 'item804', 'item442'] | Remaining Capacity :2
#
# Bin type : 3 | Item ID : ['item747', 'item774', 'item80'] | Remaining Capacity :4
#
# Bin type : 3 | Item ID : ['item961', 'item630', 'item545'] | Remaining Capacity :15
#
# Bin type : 1 | Item ID : ['item599'] | Remaining Capacity :10
#
# Bin type : 1 | Item ID : ['item725'] | Remaining Capacity :20
#
# Bin type : 3 | Item ID : ['item266', 'item116', 'item461'] | Remaining Capacity :12
#
# Bin type : 1 | Item ID : ['item275'] | Remaining Capacity :18
#
# Bin type : 2 | Item ID : ['item597', 'item50'] | Remaining Capacity :12
#
# Bin type : 1 | Item ID : ['item584'] | Remaining Capacity :29
#
# Bin type : 2 | Item ID : ['item280'] | Remaining Capacity :41
#
# Bin type : 1 | Item ID : ['item305', 'item641'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item287', 'item162', 'item869'] | Remaining Capacity :51
#
# Bin type : 1 | Item ID : ['item288', 'item822'] | Remaining Capacity :14
#
# Bin type : 3 | Item ID : ['item319', 'item894', 'item676'] | Remaining Capacity :4
#
# Bin type : 3 | Item ID : ['item254', 'item74', 'item974', 'item133'] | Remaining Capacity :22
#
# Bin type : 3 | Item ID : ['item785', 'item635'] | Remaining Capacity :11
#
# Bin type : 2 | Item ID : ['item310'] | Remaining Capacity :4
#
# Bin type : 3 | Item ID : ['item103', 'item726', 'item94'] | Remaining Capacity :4
#
# Bin type : 3 | Item ID : ['item818', 'item917', 'item907', 'item861'] | Remaining Capacity :3
#
# Bin type : 3 | Item ID : ['item616', 'item161'] | Remaining Capacity :26
#
# Bin type : 3 | Item ID : ['item607', 'item120', 'item513'] | Remaining Capacity :20
#
# Bin type : 2 | Item ID : ['item475', 'item735', 'item690'] | Remaining Capacity :5
#
# Bin type : 2 | Item ID : ['item748', 'item234', 'item977'] | Remaining Capacity :10
#
# Bin type : 1 | Item ID : ['item477', 'item64'] | Remaining Capacity :8
#
# Bin type : 2 | Item ID : ['item357'] | Remaining Capacity :5
#
# Bin type : 1 | Item ID : ['item353'] | Remaining Capacity :10
#
# Bin type : 3 | Item ID : ['item355', 'item689', 'item218', 'item332', 'item59'] | Remaining Capacity :30
#
# Bin type : 1 | Item ID : ['item159'] | Remaining Capacity :2
#
# Bin type : 3 | Item ID : ['item166', 'item707'] | Remaining Capacity :4
#
# Bin type : 3 | Item ID : ['item546', 'item542'] | Remaining Capacity :8
#
# Bin type : 2 | Item ID : ['item722', 'item989'] | Remaining Capacity :46
#
# Bin type : 2 | Item ID : ['item405'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item385', 'item883', 'item375'] | Remaining Capacity :10
#
# Bin type : 3 | Item ID : ['item388', 'item309'] | Remaining Capacity :10
#
# Bin type : 1 | Item ID : ['item73', 'item492'] | Remaining Capacity :12
#
# Bin type : 3 | Item ID : ['item394', 'item816', 'item222'] | Remaining Capacity :51
#
# Bin type : 1 | Item ID : ['item251'] | Remaining Capacity :22
#
# Bin type : 2 | Item ID : ['item421'] | Remaining Capacity :6
#
# Bin type : 2 | Item ID : ['item410', 'item524', 'item968', 'item100'] | Remaining Capacity :3
#
# Bin type : 2 | Item ID : ['item562', 'item852'] | Remaining Capacity :11
#
# Bin type : 1 | Item ID : ['item316'] | Remaining Capacity :15
#
# Bin type : 2 | Item ID : ['item942', 'item90'] | Remaining Capacity :40
#
# Bin type : 3 | Item ID : ['item427', 'item406', 'item751'] | Remaining Capacity :20
#
# Bin type : 1 | Item ID : ['item428'] | Remaining Capacity :13
#
# Bin type : 1 | Item ID : ['item646', 'item190', 'item528'] | Remaining Capacity :7
#
# Bin type : 1 | Item ID : ['item244', 'item648'] | Remaining Capacity :13
#
# Bin type : 2 | Item ID : ['item389', 'item35'] | Remaining Capacity :13
#
# Bin type : 3 | Item ID : ['item444', 'item633'] | Remaining Capacity :9
#
# Bin type : 1 | Item ID : ['item846'] | Remaining Capacity :7
#
# Bin type : 1 | Item ID : ['item118'] | Remaining Capacity :27
#
# Bin type : 1 | Item ID : ['item651'] | Remaining Capacity :38
#
# Bin type : 1 | Item ID : ['item958'] | Remaining Capacity :15
#
# Bin type : 1 | Item ID : ['item466', 'item857'] | Remaining Capacity :3
#
# Bin type : 1 | Item ID : ['item470'] | Remaining Capacity :17
#
# Bin type : 3 | Item ID : ['item479', 'item285', 'item36'] | Remaining Capacity :3
#
# Bin type : 1 | Item ID : ['item643', 'item997'] | Remaining Capacity :23
#
# Bin type : 1 | Item ID : ['item532', 'item211'] | Remaining Capacity :25
#
# Bin type : 3 | Item ID : ['item509', 'item363', 'item344'] | Remaining Capacity :3
#
# Bin type : 1 | Item ID : ['item674'] | Remaining Capacity :15
#
# Bin type : 3 | Item ID : ['item329', 'item147', 'item399'] | Remaining Capacity :25
#
# Bin type : 3 | Item ID : ['item527', 'item346', 'item40', 'item724'] | Remaining Capacity :14
#
# Bin type : 3 | Item ID : ['item626', 'item535'] | Remaining Capacity :4
#
# Bin type : 1 | Item ID : ['item716'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item543', 'item52'] | Remaining Capacity :13
#
# Bin type : 3 | Item ID : ['item547', 'item146'] | Remaining Capacity :7
#
# Bin type : 1 | Item ID : ['item708', 'item343'] | Remaining Capacity :12
#
# Bin type : 3 | Item ID : ['item760', 'item82', 'item773'] | Remaining Capacity :11
#
# Bin type : 2 | Item ID : ['item564', 'item418', 'item587'] | Remaining Capacity :3
#
# Bin type : 2 | Item ID : ['item565', 'item204', 'item667', 'item14'] | Remaining Capacity :9
#
# Bin type : 3 | Item ID : ['item567', 'item530'] | Remaining Capacity :27
#
# Bin type : 3 | Item ID : ['item440', 'item529'] | Remaining Capacity :2
#
# Bin type : 2 | Item ID : ['item3', 'item354'] | Remaining Capacity :19
#
# Bin type : 1 | Item ID : ['item638'] | Remaining Capacity :0
#
# Bin type : 3 | Item ID : ['item86', 'item269', 'item480'] | Remaining Capacity :10
#
# Bin type : 1 | Item ID : ['item939'] | Remaining Capacity :20
#
# Bin type : 2 | Item ID : ['item798'] | Remaining Capacity :33
#
# Bin type : 2 | Item ID : ['item586', 'item453', 'item794'] | Remaining Capacity :3
#
# Bin type : 1 | Item ID : ['item592', 'item786'] | Remaining Capacity :11
#
# Bin type : 3 | Item ID : ['item835', 'item296'] | Remaining Capacity :28
#
# Bin type : 1 | Item ID : ['item605', 'item777'] | Remaining Capacity :3
#
# Bin type : 2 | Item ID : ['item611', 'item235'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item612', 'item517', 'item790'] | Remaining Capacity :3
#
# Bin type : 1 | Item ID : ['item614', 'item969', 'item581'] | Remaining Capacity :21
#
# Bin type : 1 | Item ID : ['item617'] | Remaining Capacity :10
#
# Bin type : 2 | Item ID : ['item733', 'item424'] | Remaining Capacity :11
#
# Bin type : 1 | Item ID : ['item621', 'item113'] | Remaining Capacity :3
#
# Bin type : 1 | Item ID : ['item622'] | Remaining Capacity :0
#
# Bin type : 3 | Item ID : ['item457', 'item715', 'item247'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item627', 'item485'] | Remaining Capacity :18
#
# Bin type : 2 | Item ID : ['item780', 'item194'] | Remaining Capacity :9
#
# Bin type : 3 | Item ID : ['item555', 'item295', 'item686'] | Remaining Capacity :25
#
# Bin type : 3 | Item ID : ['item859', 'item872'] | Remaining Capacity :13
#
# Bin type : 2 | Item ID : ['item284', 'item374'] | Remaining Capacity :2
#
# Bin type : 1 | Item ID : ['item519', 'item368', 'item215'] | Remaining Capacity :4
#
# Bin type : 3 | Item ID : ['item825', 'item273'] | Remaining Capacity :5
#
# Bin type : 2 | Item ID : ['item853', 'item770'] | Remaining Capacity :3
#
# Bin type : 2 | Item ID : ['item661', 'item677'] | Remaining Capacity :2
#
# Bin type : 3 | Item ID : ['item908', 'item47', 'item951'] | Remaining Capacity :25
#
# Bin type : 2 | Item ID : ['item593', 'item420'] | Remaining Capacity :22
#
# Bin type : 2 | Item ID : ['item696'] | Remaining Capacity :23
#
# Bin type : 1 | Item ID : ['item339', 'item456'] | Remaining Capacity :5
#
# Bin type : 1 | Item ID : ['item484'] | Remaining Capacity :14
#
# Bin type : 1 | Item ID : ['item662', 'item933'] | Remaining Capacity :13
#
# Bin type : 2 | Item ID : ['item874', 'item342', 'item191'] | Remaining Capacity :5
#
# Bin type : 2 | Item ID : ['item995'] | Remaining Capacity :5
#
# Bin type : 2 | Item ID : ['item541'] | Remaining Capacity :21
#
# Bin type : 2 | Item ID : ['item698', 'item435'] | Remaining Capacity :9
#
# Bin type : 2 | Item ID : ['item779'] | Remaining Capacity :7
#
# Bin type : 3 | Item ID : ['item706', 'item165', 'item129'] | Remaining Capacity :6
#
# Bin type : 1 | Item ID : ['item944'] | Remaining Capacity :21
#
# Bin type : 2 | Item ID : ['item731', 'item143'] | Remaining Capacity :5
#
# Bin type : 3 | Item ID : ['item721', 'item639'] | Remaining Capacity :3
#
# Bin type : 1 | Item ID : ['item18', 'item659'] | Remaining Capacity :4
#
# Bin type : 2 | Item ID : ['item732', 'item799', 'item148', 'item554'] | Remaining Capacity :26
#
# Bin type : 1 | Item ID : ['item573'] | Remaining Capacity :6
#
# Bin type : 3 | Item ID : ['item738', 'item160', 'item515'] | Remaining Capacity :23
#
# Bin type : 1 | Item ID : ['item754', 'item282', 'item544'] | Remaining Capacity :6
#
# Bin type : 2 | Item ID : ['item727', 'item465'] | Remaining Capacity :10
#
# Bin type : 3 | Item ID : ['item757', 'item185', 'item531'] | Remaining Capacity :2
#
# Bin type : 2 | Item ID : ['item759', 'item666', 'item730'] | Remaining Capacity :2
#
# Bin type : 1 | Item ID : ['item761'] | Remaining Capacity :13
#
# Bin type : 2 | Item ID : ['item743', 'item77'] | Remaining Capacity :4
#
# Bin type : 1 | Item ID : ['item766', 'item823'] | Remaining Capacity :4
#
# Bin type : 3 | Item ID : ['item184', 'item464', 'item604', 'item679'] | Remaining Capacity :2
#
# Bin type : 1 | Item ID : ['item769', 'item336'] | Remaining Capacity :9
#
# Bin type : 2 | Item ID : ['item429', 'item924', 'item364', 'item889'] | Remaining Capacity :4
#
# Bin type : 2 | Item ID : ['item5'] | Remaining Capacity :52
#
# Bin type : 3 | Item ID : ['item8', 'item55', 'item314'] | Remaining Capacity :5
#
# Bin type : 2 | Item ID : ['item551', 'item450'] | Remaining Capacity :7
#
# Bin type : 1 | Item ID : ['item576', 'item239'] | Remaining Capacity :7
#
# Bin type : 2 | Item ID : ['item791', 'item952', 'item122', 'item854'] | Remaining Capacity :50
#
# Bin type : 2 | Item ID : ['item463', 'item163'] | Remaining Capacity :36
#
# Bin type : 2 | Item ID : ['item800', 'item38'] | Remaining Capacity :17
#
# Bin type : 1 | Item ID : ['item556'] | Remaining Capacity :39
#
# Bin type : 1 | Item ID : ['item264', 'item615'] | Remaining Capacity :22
#
# Bin type : 3 | Item ID : ['item808', 'item426'] | Remaining Capacity :13
#
# Bin type : 2 | Item ID : ['item752', 'item764'] | Remaining Capacity :19
#
# Bin type : 1 | Item ID : ['item549'] | Remaining Capacity :4
#
# Bin type : 1 | Item ID : ['item814', 'item714', 'item483'] | Remaining Capacity :4
#
# Bin type : 1 | Item ID : ['item815', 'item739'] | Remaining Capacity :6
#
# Bin type : 3 | Item ID : ['item817', 'item575', 'item1000'] | Remaining Capacity :34
#
# Bin type : 3 | Item ID : ['item57', 'item833', 'item242'] | Remaining Capacity :52
#
# Bin type : 3 | Item ID : ['item157', 'item536', 'item741'] | Remaining Capacity :27
#
# Bin type : 3 | Item ID : ['item578', 'item395', 'item68'] | Remaining Capacity :17
#
# Bin type : 1 | Item ID : ['item829'] | Remaining Capacity :13
#
# Bin type : 1 | Item ID : ['item812'] | Remaining Capacity :7
#
# Bin type : 2 | Item ID : ['item246', 'item579'] | Remaining Capacity :6
#
# Bin type : 3 | Item ID : ['item839', 'item231', 'item514'] | Remaining Capacity :17
#
# Bin type : 3 | Item ID : ['item62', 'item505', 'item338'] | Remaining Capacity :3
#
# Bin type : 3 | Item ID : ['item843', 'item916', 'item140'] | Remaining Capacity :4
#
# Bin type : 2 | Item ID : ['item728', 'item811', 'item170'] | Remaining Capacity :5
#
# Bin type : 3 | Item ID : ['item847', 'item600'] | Remaining Capacity :6
#
# Bin type : 3 | Item ID : ['item566', 'item669', 'item249', 'item494'] | Remaining Capacity :18
#
# Bin type : 2 | Item ID : ['item965'] | Remaining Capacity :7
#
# Bin type : 2 | Item ID : ['item778', 'item158'] | Remaining Capacity :26
#
# Bin type : 1 | Item ID : ['item973', 'item620'] | Remaining Capacity :4
#
# Bin type : 2 | Item ID : ['item864', 'item803'] | Remaining Capacity :17
#
# Bin type : 1 | Item ID : ['item866'] | Remaining Capacity :15
#
# Bin type : 1 | Item ID : ['item867', 'item681'] | Remaining Capacity :13
#
# Bin type : 2 | Item ID : ['item753', 'item360'] | Remaining Capacity :18
#
# Bin type : 2 | Item ID : ['item876', 'item109'] | Remaining Capacity :5
#
# Bin type : 3 | Item ID : ['item723', 'item455', 'item877', 'item1'] | Remaining Capacity :13
#
# Bin type : 2 | Item ID : ['item821', 'item868', 'item425'] | Remaining Capacity :3
#
# Bin type : 3 | Item ID : ['item887', 'item238', 'item311'] | Remaining Capacity :13
#
# Bin type : 1 | Item ID : ['item921'] | Remaining Capacity :0
#
# Bin type : 1 | Item ID : ['item179', 'item493'] | Remaining Capacity :11
#
# Bin type : 1 | Item ID : ['item533'] | Remaining Capacity :16
#
# Bin type : 3 | Item ID : ['item996', 'item858', 'item123'] | Remaining Capacity :19
#
# Bin type : 3 | Item ID : ['item901', 'item781'] | Remaining Capacity :12
#
# Bin type : 3 | Item ID : ['item490', 'item539', 'item762'] | Remaining Capacity :26
#
# Bin type : 1 | Item ID : ['item580'] | Remaining Capacity :9
#
# Bin type : 3 | Item ID : ['item841', 'item902', 'item522'] | Remaining Capacity :9
#
# Bin type : 3 | Item ID : ['item126', 'item372'] | Remaining Capacity :12
#
# Bin type : 2 | Item ID : ['item473', 'item931'] | Remaining Capacity :7
#
# Bin type : 3 | Item ID : ['item918', 'item893', 'item936'] | Remaining Capacity :4
#
# Bin type : 2 | Item ID : ['item510'] | Remaining Capacity :30
#
# Bin type : 3 | Item ID : ['item983', 'item199'] | Remaining Capacity :51
#
# Bin type : 1 | Item ID : ['item29'] | Remaining Capacity :7
#
# Bin type : 1 | Item ID : ['item603', 'item32'] | Remaining Capacity :21
#
# Bin type : 3 | Item ID : ['item124', 'item318'] | Remaining Capacity :33
#
# Bin type : 2 | Item ID : ['item93', 'item423'] | Remaining Capacity :21
#
# Bin type : 1 | Item ID : ['item623', 'item990'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item954', 'item736', 'item330'] | Remaining Capacity :24
#
# Bin type : 2 | Item ID : ['item970', 'item111'] | Remaining Capacity :2
#
# Bin type : 3 | Item ID : ['item972', 'item691', 'item39'] | Remaining Capacity :20
#
# Bin type : 2 | Item ID : ['item407', 'item840', 'item187'] | Remaining Capacity :5
#
# Bin type : 1 | Item ID : ['item978', 'item971'] | Remaining Capacity :7
#
# Bin type : 2 | Item ID : ['item441', 'item26'] | Remaining Capacity :6
#
# Bin type : 1 | Item ID : ['item984', 'item582'] | Remaining Capacity :10
#
# Bin type : 2 | Item ID : ['item988', 'item46', 'item671'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item606'] | Remaining Capacity :0
#
# Bin type : 3 | Item ID : ['item371', 'item278'] | Remaining Capacity :2
#
# Bin type : 1 | Item ID : ['item899'] | Remaining Capacity :31
#
# Bin type : 2 | Item ID : ['item102', 'item609'] | Remaining Capacity :45
#
# Bin type : 3 | Item ID : ['item13', 'item746', 'item106'] | Remaining Capacity :7
#
# Bin type : 1 | Item ID : ['item682', 'item348'] | Remaining Capacity :9
#
# Bin type : 1 | Item ID : ['item598', 'item860'] | Remaining Capacity :4
#
# Bin type : 2 | Item ID : ['item693', 'item164'] | Remaining Capacity :5
#
# Bin type : 2 | Item ID : ['item101'] | Remaining Capacity :0
#
# Bin type : 2 | Item ID : ['item559', 'item203'] | Remaining Capacity :3
#
# Bin type : 3 | Item ID : ['item300', 'item882'] | Remaining Capacity :3
#
# Bin type : 2 | Item ID : ['item340', 'item294'] | Remaining Capacity :9
#
# Bin type : 3 | Item ID : ['item276', 'item501', 'item892', 'item507'] | Remaining Capacity :11
#
# Bin type : 3 | Item ID : ['item632', 'item291'] | Remaining Capacity :7
#
# Bin type : 3 | Item ID : ['item209', 'item776', 'item261', 'item349'] | Remaining Capacity :3
#
# Bin type : 1 | Item ID : ['item497', 'item865'] | Remaining Capacity :5
#
# Bin type : 3 | Item ID : ['item591', 'item523'] | Remaining Capacity :3
#
# Bin type : 3 | Item ID : ['item19', 'item675'] | Remaining Capacity :12
#
# Bin type : 2 | Item ID : ['item48', 'item699', 'item390'] | Remaining Capacity :8
#
# Bin type : 2 | Item ID : ['item436'] | Remaining Capacity :7
#
# Bin type : 2 | Item ID : ['item27', 'item486'] | Remaining Capacity :20
#
# Bin type : 3 | Item ID : ['item272', 'item595'] | Remaining Capacity :16
#
# Bin type : 2 | Item ID : ['item297', 'item574'] | Remaining Capacity :15
#
# Bin type : 3 | Item ID : ['item744', 'item117'] | Remaining Capacity :5
#
# Bin type : 3 | Item ID : ['item557', 'item169', 'item168', 'item217'] | Remaining Capacity :13
#
# Bin type : 2 | Item ID : ['item206', 'item72', 'item22', 'item960'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item51'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item982'] | Remaining Capacity :0
#
# Bin type : 3 | Item ID : ['item192', 'item333'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item81', 'item451'] | Remaining Capacity :33
#
# Bin type : 2 | Item ID : ['item98'] | Remaining Capacity :28
#
# Bin type : 3 | Item ID : ['item292', 'item664'] | Remaining Capacity :18
#
# Bin type : 1 | Item ID : ['item105'] | Remaining Capacity :6
#
# Bin type : 2 | Item ID : ['item171'] | Remaining Capacity :15
#
# Bin type : 2 | Item ID : ['item478'] | Remaining Capacity :46
#
# Bin type : 3 | Item ID : ['item512', 'item56'] | Remaining Capacity :3
#
# Bin type : 2 | Item ID : ['item820', 'item850'] | Remaining Capacity :6
#
# Bin type : 3 | Item ID : ['item459', 'item293'] | Remaining Capacity :28
#
# Bin type : 2 | Item ID : ['item257'] | Remaining Capacity :6
#
# Bin type : 3 | Item ID : ['item637', 'item957'] | Remaining Capacity :6
#
# Bin type : 3 | Item ID : ['item193', 'item91'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item827'] | Remaining Capacity :16
#
# Bin type : 2 | Item ID : ['item452', 'item447', 'item688'] | Remaining Capacity :4
#
# Bin type : 3 | Item ID : ['item84', 'item672'] | Remaining Capacity :9
#
# Bin type : 2 | Item ID : ['item28'] | Remaining Capacity :56
#
# Bin type : 1 | Item ID : ['item377'] | Remaining Capacity :7
#
# Bin type : 3 | Item ID : ['item993', 'item443'] | Remaining Capacity :10
#
# Bin type : 2 | Item ID : ['item229'] | Remaining Capacity :14
#
# Bin type : 3 | Item ID : ['item114', 'item941', 'item107'] | Remaining Capacity :15
#
# Bin type : 3 | Item ID : ['item911', 'item16'] | Remaining Capacity :10
#
# Bin type : 1 | Item ID : ['item224'] | Remaining Capacity :4
#
# Bin type : 2 | Item ID : ['item729', 'item414'] | Remaining Capacity :11
#
# Bin type : 2 | Item ID : ['item594'] | Remaining Capacity :21
#
# Bin type : 3 | Item ID : ['item832', 'item718'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item489', 'item387'] | Remaining Capacity :4
#
# Bin type : 3 | Item ID : ['item283', 'item905', 'item263'] | Remaining Capacity :16
#
# Bin type : 2 | Item ID : ['item6'] | Remaining Capacity :18
#
# Bin type : 1 | Item ID : ['item645', 'item89'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item378'] | Remaining Capacity :38
#
# Bin type : 3 | Item ID : ['item127', 'item434'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item792', 'item787'] | Remaining Capacity :3
#
# Bin type : 1 | Item ID : ['item915'] | Remaining Capacity :37
#
# Bin type : 2 | Item ID : ['item454', 'item740'] | Remaining Capacity :6
#
# Bin type : 3 | Item ID : ['item975', 'item824'] | Remaining Capacity :4
#
# Bin type : 3 | Item ID : ['item838', 'item807'] | Remaining Capacity :7
#
# Bin type : 2 | Item ID : ['item710', 'item134'] | Remaining Capacity :16
#
# Bin type : 3 | Item ID : ['item65', 'item737'] | Remaining Capacity :6
#
# Bin type : 3 | Item ID : ['item382', 'item771'] | Remaining Capacity :2
#
# Bin type : 2 | Item ID : ['item657'] | Remaining Capacity :2
#
# Bin type : 3 | Item ID : ['item259', 'item862', 'item888'] | Remaining Capacity :4
#
# Bin type : 2 | Item ID : ['item932'] | Remaining Capacity :23
#
# Bin type : 1 | Item ID : ['item308'] | Remaining Capacity :16
#
# Bin type : 2 | Item ID : ['item398'] | Remaining Capacity :2
#
# Bin type : 2 | Item ID : ['item525', 'item233'] | Remaining Capacity :0
#
# Bin type : 3 | Item ID : ['item327', 'item966'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item613'] | Remaining Capacity :56
#
# Bin type : 2 | Item ID : ['item115'] | Remaining Capacity :2
#
# Bin type : 3 | Item ID : ['item312', 'item687'] | Remaining Capacity :5
#
# Bin type : 2 | Item ID : ['item628'] | Remaining Capacity :25
#
# Bin type : 3 | Item ID : ['item828', 'item400'] | Remaining Capacity :16
#
# Bin type : 1 | Item ID : ['item914', 'item886', 'item262'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item596'] | Remaining Capacity :16
#
# Bin type : 2 | Item ID : ['item139', 'item695'] | Remaining Capacity :17
#
# Bin type : 2 | Item ID : ['item469'] | Remaining Capacity :13
#
# Bin type : 2 | Item ID : ['item949', 'item810', 'item550'] | Remaining Capacity :2
#
# Bin type : 3 | Item ID : ['item150', 'item156'] | Remaining Capacity :5
#
# Bin type : 3 | Item ID : ['item370', 'item910'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item195', 'item985'] | Remaining Capacity :13
#
# Bin type : 3 | Item ID : ['item23', 'item151'] | Remaining Capacity :11
#
# Bin type : 2 | Item ID : ['item953'] | Remaining Capacity :3
#
# Bin type : 1 | Item ID : ['item987', 'item304'] | Remaining Capacity :8
#
# Bin type : 3 | Item ID : ['item801', 'item325'] | Remaining Capacity :4
#
# Bin type : 2 | Item ID : ['item49', 'item361'] | Remaining Capacity :10
#
# Bin type : 3 | Item ID : ['item928', 'item221'] | Remaining Capacity :4
#
# Bin type : 2 | Item ID : ['item634'] | Remaining Capacity :24
#
# Bin type : 1 | Item ID : ['item403'] | Remaining Capacity :16
#
# Bin type : 3 | Item ID : ['item496', 'item322'] | Remaining Capacity :8
#
# Bin type : 3 | Item ID : ['item935', 'item9', 'item694'] | Remaining Capacity :13
#
# Bin type : 3 | Item ID : ['item929', 'item558', 'item267'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item705'] | Remaining Capacity :6
#
# Bin type : 3 | Item ID : ['item135', 'item644', 'item601'] | Remaining Capacity :13
#
# Bin type : 2 | Item ID : ['item520'] | Remaining Capacity :20
#
# Bin type : 3 | Item ID : ['item173', 'item878'] | Remaining Capacity :27
#
# Bin type : 2 | Item ID : ['item141'] | Remaining Capacity :21
#
# Bin type : 3 | Item ID : ['item279', 'item819', 'item281'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item37', 'item647'] | Remaining Capacity :14
#
# Bin type : 3 | Item ID : ['item110', 'item419'] | Remaining Capacity :2
#
# Bin type : 3 | Item ID : ['item831', 'item232'] | Remaining Capacity :18
#
# Bin type : 3 | Item ID : ['item439', 'item871'] | Remaining Capacity :2
#
# Bin type : 3 | Item ID : ['item474', 'item789'] | Remaining Capacity :5
#
# Bin type : 3 | Item ID : ['item750'] | Remaining Capacity :51
#
# Bin type : 3 | Item ID : ['item806', 'item548'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item537', 'item909', 'item250'] | Remaining Capacity :11
#
# Bin type : 3 | Item ID : ['item619', 'item845'] | Remaining Capacity :32
#
# Bin type : 1 | Item ID : ['item432'] | Remaining Capacity :8
#
# Bin type : 2 | Item ID : ['item826'] | Remaining Capacity :18
#
# Bin type : 2 | Item ID : ['item610'] | Remaining Capacity :33
#
# Bin type : 3 | Item ID : ['item71', 'item670'] | Remaining Capacity :20
#
# Bin type : 2 | Item ID : ['item397'] | Remaining Capacity :11
#
# Bin type : 2 | Item ID : ['item788'] | Remaining Capacity :45
#
# Bin type : 2 | Item ID : ['item341'] | Remaining Capacity :25
#
# Bin type : 2 | Item ID : ['item665'] | Remaining Capacity :28
#
# Bin type : 2 | Item ID : ['item976'] | Remaining Capacity :6
#
# Bin type : 1 | Item ID : ['item345'] | Remaining Capacity :20
#
# Bin type : 3 | Item ID : ['item228', 'item923'] | Remaining Capacity :11
#
# Bin type : 3 | Item ID : ['item460', 'item33'] | Remaining Capacity :13
#
# Bin type : 2 | Item ID : ['item268'] | Remaining Capacity :7
#
# Bin type : 3 | Item ID : ['item903', 'item61'] | Remaining Capacity :3
#
# Bin type : 3 | Item ID : ['item879', 'item366', 'item60'] | Remaining Capacity :7
#
# Bin type : 3 | Item ID : ['item498', 'item534'] | Remaining Capacity :2
#
# Bin type : 2 | Item ID : ['item324'] | Remaining Capacity :19
#
# Bin type : 3 | Item ID : ['item955', 'item274', 'item21'] | Remaining Capacity :13
#
# Bin type : 1 | Item ID : ['item720'] | Remaining Capacity :11
#
# Bin type : 3 | Item ID : ['item41', 'item588'] | Remaining Capacity :8
#
# Bin type : 3 | Item ID : ['item668', 'item685'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item313', 'item898'] | Remaining Capacity :5
#
# Bin type : 1 | Item ID : ['item950'] | Remaining Capacity :18
#
# Bin type : 3 | Item ID : ['item979', 'item526'] | Remaining Capacity :8
#
# Bin type : 2 | Item ID : ['item30'] | Remaining Capacity :16
#
# Bin type : 3 | Item ID : ['item589', 'item813'] | Remaining Capacity :6
#
# Bin type : 2 | Item ID : ['item352'] | Remaining Capacity :12
#
# Bin type : 3 | Item ID : ['item12', 'item53'] | Remaining Capacity :11
#
# Bin type : 3 | Item ID : ['item678', 'item386'] | Remaining Capacity :10
#
# Bin type : 2 | Item ID : ['item367'] | Remaining Capacity :19
#
# Bin type : 1 | Item ID : ['item270'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item252', 'item472'] | Remaining Capacity :28
#
# Bin type : 3 | Item ID : ['item298', 'item92'] | Remaining Capacity :13
#
# Bin type : 2 | Item ID : ['item487'] | Remaining Capacity :9
#
# Bin type : 2 | Item ID : ['item797'] | Remaining Capacity :11
#
# Bin type : 3 | Item ID : ['item880', 'item416'] | Remaining Capacity :13
#
# Bin type : 2 | Item ID : ['item365'] | Remaining Capacity :21
#
# Bin type : 2 | Item ID : ['item172'] | Remaining Capacity :8
#
# Bin type : 3 | Item ID : ['item237', 'item131'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item568', 'item986'] | Remaining Capacity :4
#
# Bin type : 2 | Item ID : ['item96'] | Remaining Capacity :13
#
# Bin type : 3 | Item ID : ['item834', 'item323', 'item734'] | Remaining Capacity :7
#
# Bin type : 3 | Item ID : ['item431', 'item227'] | Remaining Capacity :9
#
# Bin type : 2 | Item ID : ['item784'] | Remaining Capacity :14
#
# Bin type : 3 | Item ID : ['item830', 'item701'] | Remaining Capacity :33
#
# Bin type : 3 | Item ID : ['item373', 'item136'] | Remaining Capacity :8
#
# Bin type : 3 | Item ID : ['item499', 'item934'] | Remaining Capacity :14
#
# Bin type : 1 | Item ID : ['item76', 'item299'] | Remaining Capacity :9
#
# Bin type : 3 | Item ID : ['item503', 'item347'] | Remaining Capacity :15
#
# Bin type : 2 | Item ID : ['item236', 'item178'] | Remaining Capacity :9
#
# Bin type : 1 | Item ID : ['item176'] | Remaining Capacity :8
#
# Bin type : 3 | Item ID : ['item683', 'item980'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item809'] | Remaining Capacity :3
#
# Bin type : 2 | Item ID : ['item430'] | Remaining Capacity :6
#
# Bin type : 3 | Item ID : ['item796', 'item922'] | Remaining Capacity :3
#
# Bin type : 3 | Item ID : ['item875', 'item912'] | Remaining Capacity :9
#
# Bin type : 3 | Item ID : ['item412', 'item265'] | Remaining Capacity :3
#
# Bin type : 2 | Item ID : ['item927'] | Remaining Capacity :24
#
# Bin type : 1 | Item ID : ['item402'] | Remaining Capacity :9
#
# Bin type : 2 | Item ID : ['item83'] | Remaining Capacity :3
#
# Bin type : 2 | Item ID : ['item863'] | Remaining Capacity :24
#
# Bin type : 2 | Item ID : ['item704'] | Remaining Capacity :3
#
# Bin type : 2 | Item ID : ['item656'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item491'] | Remaining Capacity :30
#
# Bin type : 2 | Item ID : ['item198'] | Remaining Capacity :5
#
# Bin type : 3 | Item ID : ['item152', 'item359'] | Remaining Capacity :35
#
# Bin type : 2 | Item ID : ['item709'] | Remaining Capacity :20
#
# Bin type : 3 | Item ID : ['item391', 'item920'] | Remaining Capacity :16
#
# Bin type : 3 | Item ID : ['item392', 'item188'] | Remaining Capacity :14
#
# Bin type : 3 | Item ID : ['item660', 'item904'] | Remaining Capacity :4
#
# Bin type : 2 | Item ID : ['item411'] | Remaining Capacity :11
#
# Bin type : 2 | Item ID : ['item404'] | Remaining Capacity :2
#
# Bin type : 3 | Item ID : ['item69', 'item749'] | Remaining Capacity :14
#
# Bin type : 2 | Item ID : ['item653'] | Remaining Capacity :15
#
# Bin type : 1 | Item ID : ['item926'] | Remaining Capacity :4
#
# Bin type : 3 | Item ID : ['item458', 'item384'] | Remaining Capacity :7
#
# Bin type : 3 | Item ID : ['item200', 'item181'] | Remaining Capacity :34
#
# Bin type : 2 | Item ID : ['item500'] | Remaining Capacity :9
#
# Bin type : 2 | Item ID : ['item197'] | Remaining Capacity :25
#
# Bin type : 3 | Item ID : ['item145', 'item328'] | Remaining Capacity :9
#
# Bin type : 3 | Item ID : ['item44', 'item521'] | Remaining Capacity :20
#
# Bin type : 2 | Item ID : ['item994'] | Remaining Capacity :23
#
# Bin type : 3 | Item ID : ['item376', 'item585'] | Remaining Capacity :8
#
# Bin type : 3 | Item ID : ['item569', 'item306'] | Remaining Capacity :4
#
# Bin type : 1 | Item ID : ['item415'] | Remaining Capacity :3
#
# Bin type : 3 | Item ID : ['item438', 'item482'] | Remaining Capacity :9
#
# Bin type : 3 | Item ID : ['item121', 'item891'] | Remaining Capacity :4
#
# Bin type : 2 | Item ID : ['item502'] | Remaining Capacity :8
#
# Bin type : 2 | Item ID : ['item449'] | Remaining Capacity :31
#
# Bin type : 2 | Item ID : ['item350'] | Remaining Capacity :8
#
# Bin type : 2 | Item ID : ['item212'] | Remaining Capacity :20
#
# Bin type : 2 | Item ID : ['item848', 'item624', 'item967'] | Remaining Capacity :5
#
# Bin type : 1 | Item ID : ['item713'] | Remaining Capacity :54
#
# Bin type : 3 | Item ID : ['item495', 'item938'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item63', 'item286'] | Remaining Capacity :7
#
# Bin type : 3 | Item ID : ['item702', 'item245'] | Remaining Capacity :4
#
# Bin type : 2 | Item ID : ['item553'] | Remaining Capacity :22
#
# Bin type : 2 | Item ID : ['item793'] | Remaining Capacity :18
#
# Bin type : 3 | Item ID : ['item277', 'item697'] | Remaining Capacity :19
#
# Bin type : 2 | Item ID : ['item851'] | Remaining Capacity :15
#
# Bin type : 2 | Item ID : ['item755'] | Remaining Capacity :5
#
# Bin type : 2 | Item ID : ['item351'] | Remaining Capacity :31
#
# Bin type : 2 | Item ID : ['item992'] | Remaining Capacity :11
#
# Bin type : 1 | Item ID : ['item711'] | Remaining Capacity :11
#
# Bin type : 2 | Item ID : ['item7'] | Remaining Capacity :14
#
# Bin type : 2 | Item ID : ['item506'] | Remaining Capacity :3
#
# Bin type : 2 | Item ID : ['item137'] | Remaining Capacity :35
#
# Bin type : 2 | Item ID : ['item437'] | Remaining Capacity :20
#
# Bin type : 3 | Item ID : ['item260', 'item629'] | Remaining Capacity :2
#
# Bin type : 3 | Item ID : ['item95', 'item337'] | Remaining Capacity :15
#
# Bin type : 3 | Item ID : ['item334', 'item940'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item358', 'item413'] | Remaining Capacity :2
#
# Bin type : 3 | Item ID : ['item240'] | Remaining Capacity :68
#
# Bin type : 3 | Item ID : ['item652', 'item998'] | Remaining Capacity :13
#
# Bin type : 2 | Item ID : ['item396'] | Remaining Capacity :14
#
# Bin type : 2 | Item ID : ['item947'] | Remaining Capacity :19
#
# Bin type : 3 | Item ID : ['item602', 'item640'] | Remaining Capacity :5
#
# Bin type : 2 | Item ID : ['item943'] | Remaining Capacity :22
#
# Bin type : 3 | Item ID : ['item745', 'item317'] | Remaining Capacity :2
#
# Bin type : 2 | Item ID : ['item563'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item767'] | Remaining Capacity :6
#
# Bin type : 3 | Item ID : ['item590', 'item258'] | Remaining Capacity :5
#
# Bin type : 2 | Item ID : ['item108'] | Remaining Capacity :15
#
# Bin type : 2 | Item ID : ['item775'] | Remaining Capacity :4
#
# Bin type : 1 | Item ID : ['item937'] | Remaining Capacity :13
#
# Bin type : 2 | Item ID : ['item467'] | Remaining Capacity :39
#
# Bin type : 2 | Item ID : ['item540'] | Remaining Capacity :9
#
# Bin type : 3 | Item ID : ['item175', 'item369'] | Remaining Capacity :2
#
# Bin type : 2 | Item ID : ['item642'] | Remaining Capacity :11
#
# Bin type : 3 | Item ID : ['item719', 'item650', 'item802'] | Remaining Capacity :28
#
# Bin type : 2 | Item ID : ['item783'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item315', 'item433'] | Remaining Capacity :2
#
# Bin type : 3 | Item ID : ['item445', 'item655'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item504'] | Remaining Capacity :13
#
# Bin type : 3 | Item ID : ['item552'] | Remaining Capacity :56
#
# Bin type : 2 | Item ID : ['item842', 'item230'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item538', 'item885'] | Remaining Capacity :5
#
# Bin type : 2 | Item ID : ['item205'] | Remaining Capacity :18
#
# Bin type : 2 | Item ID : ['item326'] | Remaining Capacity :7
#
# Bin type : 2 | Item ID : ['item54'] | Remaining Capacity :23
#
# Bin type : 3 | Item ID : ['item772'] | Remaining Capacity :74
#
# Bin type : 2 | Item ID : ['item625'] | Remaining Capacity :18
#
# Bin type : 2 | Item ID : ['item307'] | Remaining Capacity :2
#
# Bin type : 2 | Item ID : ['item925'] | Remaining Capacity :6

# %%
print(f"N1 | Cost = {N1_COST} | Bins = {N1_BINS} | Time = {N1_TIME}")
print(f"N1 and N4 | Cost = {N1N4_COST} | Bins = {N1N4_BINS} | Time ={N1N4_TIME}")
print(f"N1 and LS | Cost = {N1N4N5N6_COST} | Bins = {N1N4N5N6_BINS} | Time ={N1N4N5N6_TIME}")
print(f"N1,N2 and LS | Cost = {N1N2LS_COST} | Bins = {N1N2LS_BINS} | Time ={N1N2LS_TIME}")
# Out:
# N1 | Cost = 57390 | Bins = 519 | Time = 45.12509775161743
# N1 and N4 | Cost = 51790 | Bins = 452 | Time =15.175729990005493
# N1 and LS | Cost = 51450 | Bins = 436 | Time =50.38856077194214
# N1,N2 and LS | Cost = 51430 | Bins = 435 | Time =32.80671143531799

# %%
# sys.stdout = old_stdout

# log_file.close()

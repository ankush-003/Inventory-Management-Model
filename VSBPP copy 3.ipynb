# %%
import random
import pprint
import time
import copy
import uuid

# %%
# import sys
# old_stdout = sys.stdout

# log_file = open("message.log", "w")

# sys.stdout = log_file

# %%
weights = [0,]
for x in range(1001):
    w = random.randint(1,100)
    weights.append(w)

# %%
itemsInfo = {}
binsInfo = {}
probabilites = [0,]
# weights = [0,78, 88, 52, 77, 17, 85, 39, 95, 37, 58, 39, 21,53, 10, 69, 81, 28, 32, 48, 56, 88, 59, 29, 97, 43]
capacitites = [0,60, 100, 150]
costs = [0, 60, 100, 150]


for x in range(1,len(capacitites)):
    probabilites.append(capacitites[x]/costs[x])

for x in range(1, 1001):
    itemsInfo[f"item{x}"] = weights[x]

for x in range(1, 4):
    binsInfo[x] = {
        "cost": capacitites[x],
        "capacity": costs[x],
        "probability":  probabilites[x]
    }

print(itemsInfo,binsInfo)
# Out:
# {'item1': 47, 'item2': 65, 'item3': 3, 'item4': 74, 'item5': 6, 'item6': 55, 'item7': 91, 'item8': 70, 'item9': 60, 'item10': 2, 'item11': 11, 'item12': 98, 'item13': 62, 'item14': 75, 'item15': 96, 'item16': 11, 'item17': 74, 'item18': 39, 'item19': 92, 'item20': 77, 'item21': 30, 'item22': 69, 'item23': 14, 'item24': 57, 'item25': 13, 'item26': 54, 'item27': 58, 'item28': 93, 'item29': 57, 'item30': 16, 'item31': 81, 'item32': 56, 'item33': 46, 'item34': 68, 'item35': 39, 'item36': 64, 'item37': 21, 'item38': 37, 'item39': 90, 'item40': 49, 'item41': 87, 'item42': 77, 'item43': 34, 'item44': 17, 'item45': 38, 'item46': 91, 'item47': 84, 'item48': 83, 'item49': 96, 'item50': 31, 'item51': 21, 'item52': 46, 'item53': 27, 'item54': 95, 'item55': 41, 'item56': 62, 'item57': 22, 'item58': 29, 'item59': 55, 'item60': 33, 'item61': 62, 'item62': 73, 'item63': 42, 'item64': 1, 'item65': 9, 'item66': 9, 'item67': 13, 'item68': 58, 'item69': 36, 'item70': 25, 'item71': 9, 'item72': 63, 'item73': 90, 'item74': 46, 'item75': 20, 'item76': 11, 'item77': 78, 'item78': 41, 'item79': 38, 'item80': 93, 'item81': 60, 'item82': 60, 'item83': 63, 'item84': 19, 'item85': 19, 'item86': 93, 'item87': 41, 'item88': 41, 'item89': 52, 'item90': 95, 'item91': 24, 'item92': 34, 'item93': 55, 'item94': 94, 'item95': 12, 'item96': 98, 'item97': 56, 'item98': 27, 'item99': 56, 'item100': 1, 'item101': 86, 'item102': 80, 'item103': 70, 'item104': 50, 'item105': 32, 'item106': 13, 'item107': 87, 'item108': 6, 'item109': 10, 'item110': 94, 'item111': 84, 'item112': 43, 'item113': 30, 'item114': 73, 'item115': 16, 'item116': 61, 'item117': 99, 'item118': 89, 'item119': 82, 'item120': 88, 'item121': 63, 'item122': 43, 'item123': 91, 'item124': 65, 'item125': 5, 'item126': 45, 'item127': 40, 'item128': 76, 'item129': 12, 'item130': 19, 'item131': 58, 'item132': 92, 'item133': 83, 'item134': 64, 'item135': 91, 'item136': 30, 'item137': 77, 'item138': 32, 'item139': 17, 'item140': 10, 'item141': 76, 'item142': 36, 'item143': 74, 'item144': 97, 'item145': 60, 'item146': 81, 'item147': 62, 'item148': 12, 'item149': 81, 'item150': 3, 'item151': 78, 'item152': 78, 'item153': 52, 'item154': 24, 'item155': 38, 'item156': 72, 'item157': 60, 'item158': 94, 'item159': 36, 'item160': 11, 'item161': 12, 'item162': 26, 'item163': 97, 'item164': 9, 'item165': 66, 'item166': 58, 'item167': 65, 'item168': 9, 'item169': 40, 'item170': 4, 'item171': 32, 'item172': 22, 'item173': 48, 'item174': 69, 'item175': 3, 'item176': 10, 'item177': 47, 'item178': 7, 'item179': 70, 'item180': 80, 'item181': 2, 'item182': 78, 'item183': 96, 'item184': 100, 'item185': 74, 'item186': 63, 'item187': 78, 'item188': 83, 'item189': 1, 'item190': 63, 'item191': 44, 'item192': 10, 'item193': 42, 'item194': 45, 'item195': 64, 'item196': 19, 'item197': 5, 'item198': 7, 'item199': 59, 'item200': 80, 'item201': 79, 'item202': 22, 'item203': 54, 'item204': 24, 'item205': 36, 'item206': 44, 'item207': 44, 'item208': 81, 'item209': 22, 'item210': 43, 'item211': 56, 'item212': 74, 'item213': 62, 'item214': 42, 'item215': 28, 'item216': 25, 'item217': 80, 'item218': 2, 'item219': 52, 'item220': 53, 'item221': 28, 'item222': 87, 'item223': 64, 'item224': 84, 'item225': 35, 'item226': 89, 'item227': 82, 'item228': 37, 'item229': 50, 'item230': 97, 'item231': 25, 'item232': 47, 'item233': 59, 'item234': 4, 'item235': 21, 'item236': 16, 'item237': 45, 'item238': 8, 'item239': 36, 'item240': 60, 'item241': 64, 'item242': 81, 'item243': 30, 'item244': 62, 'item245': 45, 'item246': 14, 'item247': 65, 'item248': 52, 'item249': 25, 'item250': 89, 'item251': 30, 'item252': 57, 'item253': 32, 'item254': 24, 'item255': 65, 'item256': 71, 'item257': 5, 'item258': 15, 'item259': 99, 'item260': 42, 'item261': 1, 'item262': 66, 'item263': 97, 'item264': 95, 'item265': 24, 'item266': 54, 'item267': 33, 'item268': 87, 'item269': 74, 'item270': 61, 'item271': 89, 'item272': 12, 'item273': 11, 'item274': 4, 'item275': 92, 'item27 ...

# %%
def GenerateInitialSolution() :
    solution = {}
    s = 1
    for id,w in itemsInfo.items():
        newId = uuid.uuid4()
        validBinTypes = list(filter(lambda bin : binsInfo[bin]["capacity"] > w,binsInfo ))
        validProbabilites = tuple(map(lambda bin: binsInfo[bin]["probability"], validBinTypes))
        selectedBin = random.choices(validBinTypes,weights=validProbabilites,k=1)[0]
        remainingCapacity = binsInfo[selectedBin]["capacity"] - itemsInfo[id] 
        solution[newId] = {"bin_type": selectedBin, "item_ids": [id], "remaining_capacity": remainingCapacity}
        s+= 1
    return solution

# %%
def Cost(x : dict):
    totalCost = 0
    for info in x.values() :
        totalCost += binsInfo[info["bin_type"]]["cost"]
    return totalCost

# %%
def ChooseNeightbourhood(c1,c2) :
    k = random.choices([1,2],weights=(c1,c2),k=1)[0]
    return k

# %%
def RemainingCapacity(x,id):
    capacity = binsInfo[x[id]["bin_type"]]["capacity"]
    weight = 0
    if len(x[id]["item_ids"]) == 0 :
        return capacity
    for itemId in x[id]["item_ids"]:
        weight += itemsInfo[itemId]
    return capacity - weight

# %%
def GetWeight(id):
    return itemsInfo[id]

def UnpackRepack(x : dict,binId,newCapacity,newBinType) :
    
    cap = newCapacity
    unpackedItems = []

    #Unpacking 
    while cap < 0 :
        unpackedItem = random.choice(x[binId]["item_ids"])
        unpackedItems.append(unpackedItem)
        x[binId]["item_ids"].remove(unpackedItem)
        cap += itemsInfo[unpackedItem]
    x[binId]["remaining_capacity"] = cap

    if (len(x[binId]["item_ids"]) == 0) :
        del x[binId]

    #Repacking
    unpackedItems.sort(key=GetWeight,reverse=True)
    for id in unpackedItems:
        validBins = list(filter(lambda bin: x[bin]["remaining_capacity"] > itemsInfo[id], x.keys()))
        if (len(validBins) == 0):
            newId = uuid.uuid4()
            validBinTypes = list(filter(lambda bin: binsInfo[bin]["capacity"] > itemsInfo[id], binsInfo))
            validProbabilites = tuple(map(lambda bin: binsInfo[bin]["probability"], validBinTypes))
            selectedBin = random.choices(validBinTypes, weights=validProbabilites, k=1)[0]
            remainingCapacity = binsInfo[selectedBin]["capacity"] - itemsInfo[id]
            x[newId] = {"bin_type": selectedBin, "item_ids": [id], "remaining_capacity": remainingCapacity}
        else :
            validProbabilites = tuple(map(lambda bin: x[bin]["remaining_capacity"], validBins))
            # print(f"Item : {id} {itemsInfo[id]} | Bins : {validBins} {validProbabilites}")
            selectedBin = random.choices(validBins, weights=validProbabilites, k=1)[0]
            x[selectedBin]["item_ids"].append(id)
            x[selectedBin]["remaining_capacity"] = RemainingCapacity(x, selectedBin)
            # print(f"{selectedBin} {x[selectedBin]['remaining_capacity']} ")


    return x

# %%
def ValidateSolution(x : dict):
    for id,info in x.items():
        print(f"Bin type : {info['bin_type']} | Item ID : {info['item_ids']} | Remaining Capacity :{info['remaining_capacity']}")
        weight = 0
        for itemId in info['item_ids'] :
            weight += itemsInfo[itemId]
        capacity = binsInfo[info['bin_type']]['capacity']
        # print(f"Calculated Weight {weight} | Calculated Capacity {capacity} | Calculated Remaining Capacity : {capacity - weight}")
        print("")

# %%
def N1(x: dict):
    binIds = list(x.keys())
    selected_length = int(len(binIds)*0.15)
    bin_samples = random.sample(binIds, selected_length)
    for binId in bin_samples:
        newBinType = random.choice(
            [i for i in range(1, 4) if i != x[binId]["bin_type"]])
        oldCapacity = RemainingCapacity(x, binId)
        oldBinType = x[binId]["bin_type"]
        x[binId]["bin_type"] = newBinType
        newCapacity = RemainingCapacity(x, binId)
        x[binId]["remaining_capacity"] = newCapacity
        # print(f"{binId} | New : {newBinType} {newCapacity} | Old : {oldBinType} {oldCapacity}")

        if newCapacity < 0:
            x = UnpackRepack(x, binId, newCapacity, newBinType)
    return x

# %%
def GetBin(x,itemId):
    for id,info in x.items():
        if itemId in info["item_ids"]:
            info["bin_id"] = id
            return info

# %%
def GetCapacity(bin):
    return bin["remaining_capacity"]


def N4(x : dict):
    itemStuff = {}
    for id,info in x.items() :
        for itemId in info["item_ids"]:
            itemStuff[itemId] = {"bin_id": id, "remaining_capacity": info["remaining_capacity"]}
    for id in itemsInfo :
        binA = GetBin(x,id) 
        validBins = list(filter(lambda bin: x[bin]["remaining_capacity"] > itemsInfo[id] and x[bin]["remaining_capacity"] - itemsInfo[id] < binA["remaining_capacity"] and bin != binA["bin_id"], x.keys()))
        validBinInfo = list(map(lambda bin: {"remaining_capacity": x[bin]["remaining_capacity"], "bin_id": bin}, validBins))
        validBinInfo.sort(key=GetCapacity)
        if len(validBinInfo) == 0 :
            continue 
        binB = validBinInfo[0]
        # print(itemsInfo[id],binA, binB)

        x[binA["bin_id"]]["item_ids"].remove(id)
        x[binA["bin_id"]]["remaining_capacity"] = RemainingCapacity(x, binA["bin_id"])
        if (len(x[binA["bin_id"]]["item_ids"]) == 0):
            del x[binA["bin_id"]]

        x[binB["bin_id"]]["item_ids"].append(id)
        x[binB["bin_id"]]["remaining_capacity"] = RemainingCapacity(x, binB["bin_id"])
        
        # print("After Shift :")
        # print(x[binA["bin_id"]], x[binB["bin_id"]])
        # print()
    return x

def N5(x : dict):
    itemStuff = {}
    for id,info in x.items() :
        for itemId in info["item_ids"]:
            itemStuff[itemId] = {"bin_id": id, "remaining_capacity": info["remaining_capacity"]}
    for itemId in itemsInfo:
        binA = GetBin(x,itemId)
        
        aRemainingCApacity = binA["remaining_capacity"]
        validIds = {}
        for id,info in x.items():
            itemIds = info["item_ids"]
            bRemainingCapacity = info["remaining_capacity"]
            itemIds.sort(key=GetWeight,reverse=True)
            swappedId = ""
            for sId in itemIds:
                # print(itemsInfo[sId], bRemainingCapacity + itemsInfo[sId], itemsInfo[itemId])
                if bRemainingCapacity + itemsInfo[sId] > itemsInfo[itemId] and itemsInfo[itemId] > itemsInfo[sId] and bRemainingCapacity + itemsInfo[sId] - itemsInfo[itemId] < aRemainingCApacity:
                    swappedId = sId
            if swappedId == "" :
                continue
            # print(
            #     f"SWAP : {swappedId} {itemsInfo[swappedId]} | Item : {itemId} {itemsInfo[itemId]}   ")
            validIds[swappedId] =  bRemainingCapacity +itemsInfo[swappedId] - itemsInfo[itemId]
        # print("..................")
        finalId = ""
        for ab in validIds.keys() :
            if finalId == "":
                finalId = ab
                continue
            if validIds[finalId] > validIds[ab]:
                finalId = ab
        # print(validIds,finalId)
        if (finalId == ""):
            continue
        binB = GetBin(x,finalId)
        # print(f"Swapping {x[binA['bin_id']]} and {x[binB['bin_id']]}")
        # print(f"binA item : {itemId} {itemsInfo[itemId]} | binB item : {finalId} {itemsInfo[finalId]}")
        # print(f"binA capacity : {binA['remaining_capacity']} binB capacity : {binB['remaining_capacity']}  ")

        x[binA["bin_id"]]["item_ids"].remove(itemId)
        x[binA["bin_id"]]["item_ids"].append(finalId)
        x[binA["bin_id"]]["remaining_capacity"] = RemainingCapacity(x, binA["bin_id"])
        
        x[binB["bin_id"]]["item_ids"].remove(finalId)
        x[binB["bin_id"]]["item_ids"].append(itemId)
        x[binB["bin_id"]]["remaining_capacity"] = RemainingCapacity(x, binB["bin_id"])
        # print(f"new binA capacity : {x[binA['bin_id']]['remaining_capacity']} new binB capacity : {x[binB['bin_id']]['remaining_capacity']}")
    return x

def ChangeBinType(x):
    for id,info in x.items():
        remainingCapacity = info["remaining_capacity"]
        binSize = binsInfo[info["bin_type"]]["capacity"]
        for type,binInfo in binsInfo.items():
            if binSize - remainingCapacity < binInfo["capacity"] and binSize > binInfo["capacity"]:
                x[id]["bin_type"] = type
                x[id]["remaining_capacity"] = RemainingCapacity(x,id)
                # print(type, binInfo["capacity"], remainingCapacity, binSize, RemainingCapacity(x, id), binInfo["capacity"] - binSize + remainingCapacity)
    return x

def LocalSearch(x1):
    x3 = N4(x1)
    # x4 = N5(x3)
    # x5 = N6(x4)

    return x3

def N6(x):
    high = 0
    removeId = ""
    for id,info in x.items():
        if info["remaining_capacity"] > high:
            removeId = id
            high = info["remaining_capacity"]
    itemIds = x[removeId]["item_ids"]

    for itemId in itemIds:
        low = 9999
        addId = ""
        weight = itemsInfo[itemId]
        for id,info in x.items():
            if (info["remaining_capacity"] < low and info["remaining_capacity"] > weight):
                addId = id
                low = info["remaining_capacity"]
        
        if (addId == ""):
            continue
        # print("Doing stuff")
        x[removeId]["item_ids"].remove(itemId)
        x[removeId]["remaining_capacity"] = RemainingCapacity(x, removeId)

        x[addId]["item_ids"].append(itemId)
        x[addId]["remaining_capacity"] = RemainingCapacity(x, addId)
    
    if len(x[removeId]["item_ids"]) == 0:
        del x[removeId]

    return x
    
        


def LocalSearchv2(x1):
    x3 = N4(x1)
    x4 = N5(x3)
    x5 = N6(x4)
    x6 = ChangeBinType(x4)
    return x6

# %%
def N2(x):
    binIds = list(x.keys())
    selected_length = int(len(binIds)*0.05)
    bin_samples = random.sample(binIds, selected_length)
    for binId in bin_samples:
        itemIds = x[binId]["item_ids"]
        del x[binId]
        for id in itemIds:
            newId = uuid.uuid4()
            w = itemsInfo[id]
            validBinTypes = list(filter(lambda bin: binsInfo[bin]["capacity"] > w, binsInfo))
            validProbabilites = tuple(map(lambda bin: binsInfo[bin]["probability"], validBinTypes))
            selectedBin = random.choices(validBinTypes, weights=validProbabilites, k=1)[0]
            remainingCapacity = binsInfo[selectedBin]["capacity"] - itemsInfo[id]
            x[newId] = {"bin_type": selectedBin, "item_ids": [id], "remaining_capacity": remainingCapacity}
    return x

# %%
def Shaking(x, k):
    if (k == 1):
        shook = N1(x)
    if (k == 2):
        shook = N2(x)
    else:
        return x
    return shook

# %%
def N1N2LS():
    x = GenerateInitialSolution()
    # print(f"Initial Bins Used {len(x.keys())}")
    # print(f"Initial Cost {Cost(x)}\n")
    # ValidateSolution(x)
    finish = False
    count = 0
    c1, c2, c3 = 1, 1, 1
    c1Total, c2Total, c3Total = 1,1,1
    total = 0
    startTime = time.time()
    while not finish:
        k = ChooseNeightbourhood(c1/c1Total,c2/c2Total)
        if k == 1:
            c1Total +=1
        if k == 2:
            c2Total +=1
        oldX = copy.deepcopy(x)
        x1 = Shaking(x, 1)
        x2 = LocalSearchv2(x1)
        # print(f"Old Cost : {Cost(oldX)} New Cost : {Cost(x2)}")
        # print(f"Chosen Neighbourhood {k}")
        if (Cost(x2) < Cost(oldX)):
            if (k== 1):
                c1 += 1
            if (k == 2):
                c2 += 1
            updatedTime = time.time()
            x = x2
        else:
            x = oldX
        if (time.time() - startTime > 50):
            finish = True
    totalTime = updatedTime - startTime
    totalBins = len(x.keys())
    print(f"Total Bins Used {totalBins}")
    print(f"Final Optimised Cost {Cost(x)}")
    print(f"Last updated time : {totalTime}")
    print("")
    ValidateSolution(x)

    return totalBins, Cost(x), totalTime


N1N2LS_BINS, N1N2LS_COST, N1N2LS_TIME = N1N2LS()
# Out:
# Total Bins Used 466
# Final Optimised Cost 52170
# Last updated time : 47.69585180282593
#
# Bin type : 2 | Item ID : ['item460', 'item992', 'item218'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item14', 'item254'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item19', 'item24'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item28', 'item5'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item72', 'item726'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item41', 'item13'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item54', 'item26'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item82', 'item701', 'item175'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item20', 'item167', 'item353'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item187', 'item8', 'item417'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item61', 'item38'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item29', 'item63'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item496', 'item861'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item7', 'item441'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item81', 'item18'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item508', 'item45', 'item92'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item96', 'item64'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item101', 'item25'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item146', 'item34'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item86', 'item33', 'item192'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item117', 'item40', 'item798'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item119', 'item44'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item356', 'item126', 'item91'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item128', 'item62'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item127', 'item130'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item123', 'item131'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item133', 'item30'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item138', 'item98'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item685', 'item147'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item141', 'item114'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item144', 'item89'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item928', 'item413'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item151', 'item37'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item155', 'item51'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item163', 'item153'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item165', 'item60'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item405', 'item788', 'item464'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item169', 'item84'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item59', 'item170'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item174', 'item21'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item118', 'item176'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item132', 'item178'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item183', 'item150'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item73', 'item199'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item201', 'item103'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item351', 'item293'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item137', 'item209'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item36', 'item225'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item97', 'item260', 'item904'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item217', 'item196'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item219', 'item1'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['
] | Remaining Capacity :2
#
# Bin type : 3 | Item ID : ['item669', 'item936'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item635', 'item967'] | Remaining Capacity :4
#
# Bin type : 2 | Item ID : ['item983', 'item687', 'item658'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item971', 'item108'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item976', 'item400'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item876', 'item760'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item230', 'item991'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item785', 'item984', 'item856'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item48', 'item552'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item818', 'item997'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item988', 'item792'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item883', 'item966', 'item901'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item211', 'item837', 'item683'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item655', 'item889'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item804', 'item389'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item995', 'item968', 'item485'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item990', 'item239', 'item814'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item998', 'item721'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item727'] | Remaining Capacity :2
#
# Bin type : 1 | Item ID : ['item459', 'item53'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item648', 'item649'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item328', 'item290'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item584', 'item215'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item612', 'item203'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item275', 'item875'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item350'] | Remaining Capacity :2
#
# Bin type : 2 | Item ID : ['item827'] | Remaining Capacity :2
#
# Bin type : 2 | Item ID : ['item435', 'item231'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item761', 'item207'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item902'] | Remaining Capacity :2
#
# Bin type : 3 | Item ID : ['item263', 'item339'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item503', 'item418'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item969', 'item934'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item851', 'item739', 'item65'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item970', 'item882'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item77', 'item982', 'item1000'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item412'] | Remaining Capacity :5
#
# Bin type : 3 | Item ID : ['item518', 'item919'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item767', 'item334'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item940'] | Remaining Capacity :3
#
# Bin type : 2 | Item ID : ['item402', 'item520', 'item550'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item725', 'item640', 'item540'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item911', 'item67'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item950', 'item57'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item817', 'item614'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item242', 'item581'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item280', 'item85'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item102', 'item463'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item679', 'item115'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item857', 'item979'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item111', 'item527'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item753', 'item887', 'item243'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item46', 'item27'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item924', 'item659'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item200', 'item22'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item638', 'item959'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item898'] | Remaining Capacity :4
#
# Bin type : 1 | Item ID : ['item414', 'item246'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item645', 'item9'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item443', 'item68'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item379', 'item815'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item906', 'item411'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item158', 'item125'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item770', 'item644'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item367', 'item434'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item179', 'item941'] | Remaining Capacity :11
#
# Bin type : 1 | Item ID : ['item627'] | Remaining Capacity :3
#
# Bin type : 2 | Item ID : ['item544'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item358', 'item346'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item465', 'item43'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item996', 'item194', 'item375'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item499', 'item948'] | Remaining Capacity :4
#
# Bin type : 3 | Item ID : ['item558', 'item828'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item39', 'item790'] | Remaining Capacity :14
#
# Bin type : 3 | Item ID : ['item384', 'item740'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item965', 'item539'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item370', 'item304'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item586', 'item427'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item769'] | Remaining Capacity :4
#
# Bin type : 3 | Item ID : ['item871', 'item410'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item292', 'item986', 'item428'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item297', 'item186'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item542', 'item636'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item305', 'item622'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item758'] | Remaining Capacity :3
#
# Bin type : 3 | Item ID : ['item993', 'item746'] | Remaining Capacity :4
#
# Bin type : 2 | Item ID : ['item566', 'item656'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item472', 'item956', 'item238'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item298'] | Remaining Capacity :3
#
# Bin type : 2 | Item ID : ['item535', 'item323'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item780'] | Remaining Capacity :4
#
# Bin type : 2 | Item ID : ['item587', 'item572'] | Remaining Capacity :2
#
# Bin type : 3 | Item ID : ['item795', 'item468'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item974'] | Remaining Capacity :6
#
# Bin type : 2 | Item ID : ['item942', 'item385', 'item713'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item335', 'item858', 'item839'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item440', 'item156'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item222', 'item129'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item404', 'item526'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item565', 'item32'] | Remaining Capacity :5
#
# Bin type : 3 | Item ID : ['item31', 'item629'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item134', 'item320'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item692', 'item605'] | Remaining Capacity :2

# %%
def N1N4N5N6():
    x = GenerateInitialSolution()
    # print(f"Initial Bins Used {len(x.keys())}")
    # print(f"Initial Cost {Cost(x)}\n")
    # ValidateSolution(x)
    finish = False
    count = 0
    c1, c2, c3 = 0, 1, 1
    startTime = time.time()
    while not finish:
        #     # k = ChooseNeightbourhood(c1,c2,c3)
        oldX = copy.deepcopy(x)
        count += 1
        x1 = Shaking(x, 1)
        x2 = LocalSearchv2(x1)
        # print(f"Old Cost : {Cost(oldX)} New Cost : {Cost(x2)}")
        if (Cost(x2) < Cost(oldX)):
            c1 += 1
            updatedTime = time.time()
            x = x2
        else:
            x = oldX
        if (time.time() - startTime > 50):
            finish = True
    totalTime = updatedTime - startTime
    totalBins = len(x.keys())
    print(f"Total Bins Used {totalBins}")
    print(f"Final Optimised Cost {Cost(x)}")
    print(f"Last updated time : {totalTime}")
    print(c1)
    print("")
    ValidateSolution(x)

    return totalBins, Cost(x), totalTime

N1N4N5N6_BINS,N1N4N5N6_COST,N1N4N5N6_TIME = N1N4N5N6()
# Out:
# Total Bins Used 461
# Final Optimised Cost 52190
# Last updated time : 31.428625106811523
# 5
#
# Bin type : 3 | Item ID : ['item14', 'item4'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item19', 'item178'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item28', 'item32'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item52', 'item25'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item54', 'item26'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item41', 'item56'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item805', 'item134', 'item218'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item62', 'item323', 'item533'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item63', 'item44'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item31', 'item646', 'item375'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item47', 'item40', 'item665', 'item64'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item7', 'item644'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item87', 'item598', 'item189'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item77', 'item51'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item81', 'item18'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item82', 'item35'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item83', 'item69'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item49', 'item219', 'item417'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item80', 'item99'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item623', 'item121'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item105', 'item53'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item101', 'item67'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item107', 'item13'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item86', 'item108'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item143', 'item589', 'item326'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item116', 'item79'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item117', 'item960'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item141', 'item622', 'item154'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item124', 'item43'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item126', 'item23'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item642', 'item290'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item131', 'item55'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item133', 'item30'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item22', 'item136'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item138', 'item98'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item119', 'item139'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item149', 'item72', 'item303'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item360', 'item512'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item158', 'item125'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item151', 'item256'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item167', 'item92'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item450'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item674', 'item428'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item180', 'item174'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item186', 'item142'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item608', 'item921'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['
] | Remaining Capacity :5
#
# Bin type : 2 | Item ID : ['item640', 'item951'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item122', 'item446'] | Remaining Capacity :2
#
# Bin type : 3 | Item ID : ['item374', 'item890', 'item975', 'item781'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item990', 'item680'] | Remaining Capacity :7
#
# Bin type : 3 | Item ID : ['item766', 'item908', 'item944'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item492', 'item438', 'item681'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item914', 'item657'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item971', 'item790'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item973', 'item89', 'item829'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item974', 'item879'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item977', 'item464'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item978', 'item528'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item910', 'item668'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item424', 'item355'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item725', 'item37'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item988', 'item810'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item123', 'item989'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item262', 'item545'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item363', 'item992', 'item658'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item753', 'item6', 'item385'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item860', 'item749'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item995', 'item459'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item432', 'item913'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item980', 'item997'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item39', 'item821', 'item568'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item754', 'item728'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item367'] | Remaining Capacity :4
#
# Bin type : 2 | Item ID : ['item224', 'item690'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item950', 'item157', 'item637'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item388', 'item156'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item532', 'item369'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item102', 'item84'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item793', 'item841', 'item576'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item24', 'item260'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item773', 'item236'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item90', 'item266'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item775'] | Remaining Capacity :4
#
# Bin type : 2 | Item ID : ['item684'] | Remaining Capacity :2
#
# Bin type : 2 | Item ID : ['item996'] | Remaining Capacity :4
#
# Bin type : 3 | Item ID : ['item565', 'item403'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item350', 'item917'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item641', 'item97', 'item401'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item949', 'item60'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item740', 'item332'] | Remaining Capacity :3
#
# Bin type : 2 | Item ID : ['item629', 'item837'] | Remaining Capacity :2
#
# Bin type : 2 | Item ID : ['item933'] | Remaining Capacity :4
#
# Bin type : 2 | Item ID : ['item534', 'item415'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item524', 'item71'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item188', 'item946'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item308', 'item991'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item135', 'item27'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item269', 'item346'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item496', 'item861'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item780', 'item594'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item727', 'item306'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item709', 'item717'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item703', 'item381'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item184', 'item112', 'item550'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item110', 'item59'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item969', 'item244', 'item317'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item738', 'item205'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item599', 'item68'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item822', 'item835', 'item652', 'item896'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item201', 'item575', 'item500'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item840', 'item849'] | Remaining Capacity :2
#
# Bin type : 3 | Item ID : ['item454', 'item559', 'item865'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item73', 'item556'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item898', 'item823'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item686'] | Remaining Capacity :4
#
# Bin type : 2 | Item ID : ['item17', 'item926'] | Remaining Capacity :3
#
# Bin type : 2 | Item ID : ['item817', 'item426'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item356', 'item130'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item558', 'item934'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item724', 'item636'] | Remaining Capacity :2
#
# Bin type : 3 | Item ID : ['item325', 'item502'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item938', 'item581'] | Remaining Capacity :2
#
# Bin type : 3 | Item ID : ['item359', 'item497'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item361', 'item456'] | Remaining Capacity :30
#
# Bin type : 2 | Item ID : ['item431', 'item364'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item909', 'item963'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item706', 'item893'] | Remaining Capacity :2
#
# Bin type : 2 | Item ID : ['item745', 'item852'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item12', 'item723'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item772', 'item1000'] | Remaining Capacity :2
#
# Bin type : 3 | Item ID : ['item663', 'item862', 'item939'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item443', 'item166'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item884', 'item741'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item857', 'item140'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item970', 'item878', 'item489'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item370', 'item195'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item392', 'item982'] | Remaining Capacity :10
#
# Bin type : 3 | Item ID : ['item435', 'item241'] | Remaining Capacity :12
#
# Bin type : 3 | Item ID : ['item612', 'item203'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item163', 'item339'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item549', 'item254'] | Remaining Capacity :2
#
# Bin type : 3 | Item ID : ['item384', 'item925'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item278', 'item115'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item439', 'item525', 'item562'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item542', 'item526'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item648', 'item29'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item96'] | Remaining Capacity :2
#
# Bin type : 2 | Item ID : ['item965'] | Remaining Capacity :4
#
# Bin type : 2 | Item ID : ['item286'] | Remaining Capacity :11

# %%
def N1N4():
    x = GenerateInitialSolution()
    # print(f"Initial Bins Used {len(x.keys())}")
    # print(f"Initial Cost {Cost(x)}\n")
    # ValidateSolution(x)
    finish = False
    count = 0
    c1, c2, c3 = 0, 1, 1
    startTime = time.time()
    while not finish:
        #     # k = ChooseNeightbourhood(c1,c2,c3)
        oldX = copy.deepcopy(x)
        count += 1
        x1 = Shaking(x, 1)
        x2 = LocalSearch(x1)
        # print(f"Old Cost : {Cost(oldX)} New Cost : {Cost(x2)}")
        if (Cost(x2) < Cost(oldX)):
            c1 += 1
            updatedTime = time.time()
            x = x2
        else:
            x = oldX
        if (time.time() - startTime > 50):
            finish = True
    totalTime = updatedTime - startTime
    totalBins = len(x.keys())
    print(f"Total Bins Used {totalBins}")
    print(f"Final Optimised Cost {Cost(x)}")
    print(f"Last updated time : {totalTime}")
    print(c1)
    print("")
    ValidateSolution(x)

    return totalBins,Cost(x),totalTime

N1N4_BINS,N1N4_COST,N1N4_TIME = N1N4()
# Out:
# Total Bins Used 448
# Final Optimised Cost 52360
# Last updated time : 42.11266231536865
# 9
#
# Bin type : 3 | Item ID : ['item15', 'item294'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item18', 'item9'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item980', 'item694'] | Remaining Capacity :2
#
# Bin type : 2 | Item ID : ['item27', 'item87'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item58', 'item677', 'item45'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item61', 'item41'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item29', 'item478'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item66', 'item111', 'item32'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item68', 'item962'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item82', 'item56', 'item901', 'item434'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item95', 'item925', 'item44'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item101', 'item551'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item102', 'item84', 'item40', 'item100'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item35', 'item166', 'item455'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item83', 'item142'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item7', 'item375'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item112', 'item99'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item22', 'item821', 'item251', 'item3'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item482', 'item130', 'item854'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item117', 'item104'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item653', 'item184', 'item444'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item124', 'item43'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['
] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item443', 'item758'] | Remaining Capacity :2
#
# Bin type : 3 | Item ID : ['item667', 'item527'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item633', 'item623'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item402', 'item772'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item665', 'item928', 'item199'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item280', 'item531'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item281', 'item807'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item770', 'item989'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item905'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item457', 'item849'] | Remaining Capacity :2
#
# Bin type : 3 | Item ID : ['item648', 'item427'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item719', 'item307'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item110'] | Remaining Capacity :6
#
# Bin type : 2 | Item ID : ['item565', 'item953'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item552', 'item329', 'item272', 'item414'] | Remaining Capacity :2
#
# Bin type : 2 | Item ID : ['item785'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item31', 'item310'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item912', 'item224', 'item852'] | Remaining Capacity :2
#
# Bin type : 3 | Item ID : ['item843', 'item360'] | Remaining Capacity :3
#
# Bin type : 2 | Item ID : ['item775'] | Remaining Capacity :4
#
# Bin type : 3 | Item ID : ['item963', 'item302', 'item520'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item825', 'item460'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item410', 'item372'] | Remaining Capacity :4
#
# Bin type : 3 | Item ID : ['item512', 'item715', 'item253'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item282', 'item6'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item990', 'item835', 'item675'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item454'] | Remaining Capacity :0
#
# Bin type : 2 | Item ID : ['item756'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item39', 'item889', 'item74'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item685', 'item468'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item522', 'item81', 'item65'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item804', 'item383'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item614', 'item418', 'item689'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item796', 'item295'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item305', 'item908'] | Remaining Capacity :4
#
# Bin type : 2 | Item ID : ['item28', 'item562'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item957', 'item70'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item709'] | Remaining Capacity :6
#
# Bin type : 2 | Item ID : ['item19', 'item178'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item285', 'item877'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item180', 'item789'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item641', 'item313'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item983', 'item215'] | Remaining Capacity :2
#
# Bin type : 2 | Item ID : ['item367'] | Remaining Capacity :4
#
# Bin type : 2 | Item ID : ['item887', 'item636'] | Remaining Capacity :3
#
# Bin type : 2 | Item ID : ['item724'] | Remaining Capacity :6
#
# Bin type : 3 | Item ID : ['item435', 'item121', 'item637'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item499', 'item927', 'item728'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item390'] | Remaining Capacity :2
#
# Bin type : 2 | Item ID : ['item292'] | Remaining Capacity :4
#
# Bin type : 3 | Item ID : ['item451', 'item365', 'item273'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item842', 'item540', 'item433'] | Remaining Capacity :2
#
# Bin type : 3 | Item ID : ['item635', 'item622'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item710', 'item621'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item902'] | Remaining Capacity :2
#
# Bin type : 3 | Item ID : ['item753', 'item956', 'item196'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item408'] | Remaining Capacity :6
#
# Bin type : 3 | Item ID : ['item949', 'item805'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item903', 'item135'] | Remaining Capacity :3
#
# Bin type : 3 | Item ID : ['item12', 'item967'] | Remaining Capacity :6
#
# Bin type : 2 | Item ID : ['item850', 'item51'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item123', 'item800', 'item170'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item952', 'item258'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item638', 'item604', 'item57'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item488', 'item936', 'item464'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item14', 'item269'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item242', 'item385'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item208', 'item810'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item276'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item645', 'item750', 'item138'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item483', 'item517'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item909', 'item822'] | Remaining Capacity :2
#
# Bin type : 3 | Item ID : ['item851', 'item316', 'item644'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item486', 'item838'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item463', 'item113'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item674', 'item378'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item213', 'item17', 'item106'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item943', 'item399', 'item487'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item714', 'item718', 'item588'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item374', 'item38'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item301', 'item265'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item871'] | Remaining Capacity :5
#
# Bin type : 3 | Item ID : ['item132', 'item564'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item496', 'item252'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item672', 'item416'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item578', 'item133'] | Remaining Capacity :4
#
# Bin type : 3 | Item ID : ['item263', 'item873'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item666', 'item629'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item137', 'item892'] | Remaining Capacity :4
#
# Bin type : 2 | Item ID : ['item158'] | Remaining Capacity :6
#
# Bin type : 2 | Item ID : ['item350'] | Remaining Capacity :2
#
# Bin type : 3 | Item ID : ['item309', 'item36'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item354'] | Remaining Capacity :2
#
# Bin type : 3 | Item ID : ['item538', 'item119'] | Remaining Capacity :3
#
# Bin type : 3 | Item ID : ['item141', 'item973'] | Remaining Capacity :4
#
# Bin type : 2 | Item ID : ['item359'] | Remaining Capacity :3
#
# Bin type : 3 | Item ID : ['item188', 'item97', 'item192'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item766'] | Remaining Capacity :3
#
# Bin type : 3 | Item ID : ['item786', 'item919'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item182', 'item602'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item906'] | Remaining Capacity :11
#
# Bin type : 2 | Item ID : ['item844', 'item498'] | Remaining Capacity :2
#
# Bin type : 2 | Item ID : ['item974'] | Remaining Capacity :6
#
# Bin type : 3 | Item ID : ['item583', 'item190'] | Remaining Capacity :3
#
# Bin type : 3 | Item ID : ['item899', 'item412'] | Remaining Capacity :11
#
# Bin type : 3 | Item ID : ['item183', 'item228', 'item30'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item542', 'item26'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item554', 'item223'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item769'] | Remaining Capacity :4
#
# Bin type : 2 | Item ID : ['item49'] | Remaining Capacity :4
#
# Bin type : 3 | Item ID : ['item376', 'item777'] | Remaining Capacity :6
#
# Bin type : 3 | Item ID : ['item735', 'item233'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item250', 'item863'] | Remaining Capacity :2
#
# Bin type : 3 | Item ID : ['item47', 'item2'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item430', 'item741'] | Remaining Capacity :3
#
# Bin type : 3 | Item ID : ['item787', 'item556'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item436'] | Remaining Capacity :6
#
# Bin type : 3 | Item ID : ['item612', 'item203'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item86'] | Remaining Capacity :7
#
# Bin type : 3 | Item ID : ['item366', 'item72'] | Remaining Capacity :3
#
# Bin type : 3 | Item ID : ['item793', 'item89'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item335', 'item290'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item573', 'item668', 'item155'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item595', 'item723', 'item407'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item996', 'item823'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item751', 'item154', 'item33'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item54'] | Remaining Capacity :5
#
# Bin type : 3 | Item ID : ['item120', 'item932'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item868', 'item692'] | Remaining Capacity :5
#
# Bin type : 2 | Item ID : ['item529', 'item606'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item4', 'item581'] | Remaining Capacity :8
#
# Bin type : 2 | Item ID : ['item472', 'item129'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item663', 'item811'] | Remaining Capacity :6
#
# Bin type : 3 | Item ID : ['item494', 'item559', 'item357'] | Remaining Capacity :2
#
# Bin type : 2 | Item ID : ['item450'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item227', 'item972'] | Remaining Capacity :24
#
# Bin type : 3 | Item ID : ['item80', 'item473'] | Remaining Capacity :2
#
# Bin type : 3 | Item ID : ['item495', 'item646'] | Remaining Capacity :2
#
# Bin type : 2 | Item ID : ['item298'] | Remaining Capacity :3
#
# Bin type : 3 | Item ID : ['item795', 'item13'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item312', 'item204'] | Remaining Capacity :2
#
# Bin type : 3 | Item ID : ['item686', 'item569'] | Remaining Capacity :6
#
# Bin type : 2 | Item ID : ['item200'] | Remaining Capacity :20

# %%
def OnlyN1():
    # t0 = time.time()
    x = GenerateInitialSolution()
    # print(f"Initial Bins Used {len(x.keys())}")
    # print(f"Initial Cost {Cost(x)}\n")
    # ValidateSolution(x)
    
    finish = False
    count = 0
    c1,c2,c3 = 0,1,1
    startTime = time.time()
    while not finish:
    #     # k = ChooseNeightbourhood(c1,c2,c3)
        oldX = copy.deepcopy(x)
        count +=1
        x1 = Shaking(x,1)
        # print(f"Old Cost : {Cost(oldX)} New Cost : {Cost(x1)}")
        if (Cost(x1) < Cost(oldX)):
            c1+=1
            updatedTime = time.time()
            x = x1
        else :
            x = oldX
        if (time.time() - startTime > 50):
            finish = True
    totalTime = updatedTime - startTime
    totalBins = len(x.keys())
    print(f"Total Bins Used {totalBins}")
    print(f"Final Optimised Cost {Cost(x)}")
    print(f"Last updated time : {totalTime}")
    print(c1)
    print("")
    ValidateSolution(x)

    return totalBins, Cost(x), totalTime

N1_BINS,N1_COST,N1_TIME = OnlyN1()
# Out:
# Total Bins Used 530
# Final Optimised Cost 58170
# Last updated time : 23.004274368286133
# 51
#
# Bin type : 1 | Item ID : ['item849'] | Remaining Capacity :12
#
# Bin type : 1 | Item ID : ['item3', 'item1'] | Remaining Capacity :10
#
# Bin type : 3 | Item ID : ['item16', 'item476', 'item469', 'item853', 'item154'] | Remaining Capacity :33
#
# Bin type : 2 | Item ID : ['item21', 'item592', 'item982'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item104'] | Remaining Capacity :10
#
# Bin type : 1 | Item ID : ['item24'] | Remaining Capacity :3
#
# Bin type : 2 | Item ID : ['item571', 'item150', 'item225'] | Remaining Capacity :43
#
# Bin type : 1 | Item ID : ['item27'] | Remaining Capacity :2
#
# Bin type : 2 | Item ID : ['item30', 'item43', 'item87'] | Remaining Capacity :9
#
# Bin type : 1 | Item ID : ['item728', 'item260'] | Remaining Capacity :3
#
# Bin type : 1 | Item ID : ['item741', 'item628'] | Remaining Capacity :7
#
# Bin type : 1 | Item ID : ['item545', 'item272'] | Remaining Capacity :15
#
# Bin type : 2 | Item ID : ['item904', 'item400', 'item61', 'item25'] | Remaining Capacity :13
#
# Bin type : 2 | Item ID : ['item835', 'item296'] | Remaining Capacity :13
#
# Bin type : 2 | Item ID : ['item50', 'item434', 'item429'] | Remaining Capacity :3
#
# Bin type : 3 | Item ID : ['item58', 'item880', 'item876'] | Remaining Capacity :10
#
# Bin type : 1 | Item ID : ['item601'] | Remaining Capacity :26
#
# Bin type : 1 | Item ID : ['item63'] | Remaining Capacity :18
#
# Bin type : 2 | Item ID : ['item64', 'item505'] | Remaining Capacity :23
#
# Bin type : 3 | Item ID : ['item656', 'item924'] | Remaining Capacity :46
#
# Bin type : 3 | Item ID : ['item977', 'item805'] | Remaining Capacity :12
#
# Bin type : 1 | Item ID : ['item866'] | Remaining Capacity :27
#
# Bin type : 2 | Item ID : ['item70', 'item121'] | Remaining Capacity :12
#
# Bin type : 1 | Item ID : ['item71', 'item546'] | Remaining Capacity :4
#
# Bin type : 1 | Item ID : ['item620'] | Remaining Capacity :26
#
# Bin type : 1 | Item ID : ['item79', 'item658'] | Remaining Capacity :17
#
# Bin type : 3 | Item ID : ['item117', 'item976'] | Remaining Capacity :3
#
# Bin type : 2 | Item ID : ['item97', 'item582'] | Remaining Capacity :6
#
# Bin type : 1 | Item ID : ['item511'] | Remaining Capacity :7
#
# Bin type : 1 | Item ID : ['item746'] | Remaining Capacity :14
#
# Bin type : 2 | Item ID : ['item903', 'item88'] | Remaining Capacity :3
#
# Bin type : 3 | Item ID : ['item115', 'item18', 'item667'] | Remaining Capacity :11
#
# Bin type : 1 | Item ID : ['item126'] | Remaining Capacity :15
#
# Bin type : 1 | Item ID : ['item131'] | Remaining Capacity :2
#
# Bin type : 1 | Item ID : ['item945', 'item673'] | Remaining Capacity :15
#
# Bin type : 3 | Item ID : ['item875', 'item55'] | Remaining Capacity :52
#
# Bin type : 3 | Item ID : ['item591', 'item630', 'item492'] | Remaining Capacity :28
#
# Bin type : 1 | Item ID : ['item521', 'item557'] | Remaining Capacity :41
#
# Bin type : 2 | Item ID : ['item139', 'item397', 'item53'] | Remaining Capacity :16
#
# Bin type : 3 | Item ID : ['item788', 'item324', 'item180'] | Remaining Capacity :21
#
# Bin type : 3 | Item ID : ['item145', 'item62'] | Remaining Capacity :17
#
# Bin type : 1 | Item ID : ['item666', 'item744'] | Remaining Capacity :13
#
# Bin type : 3 | Item ID : ['item888', 'item759', 'item23'] | Remaining Capacity :24
#
# Bin type : 2 | Item ID : ['item155', 'item891', 'item939', 'item303', 'item76'] | Remaining Capacity :27
#
# Bin type : 3 | Item ID : ['item157', 'item137'] | Remaining Capacity :13
#
# Bin type : 2 | Item ID : ['item159', 'item381'] | Remaining Capacity :3
#
# Bin type : 2 | Item ID : ['item407', 'item100', 'item299', 'item879'] | Remaining Capacity :18
#
# Bin type : 2 | Item ID : ['item169', 'item919'] | Remaining Capacity :11
#
# Bin type : 1 | Item ID : ['item173'] | Remaining Capacity :12
#
# Bin type : 2 | Item ID : ['item175', 'item770'] | Remaining Capacity :6
#
# Bin type : 3 | Item ID : ['item125', 'item882', 'item722', 'item162', 'item964'] | Remaining Capacity :2
#
# Bin type : 1 | Item ID : ['item779', 'item75'] | Remaining Capacity :4
#
# Bin type : 1 | Item ID : ['item193', 'item181'] | Remaining Capacity :16
#
# Bin type : 2 | Item ID : ['item194', 'item818', 'item813'] | Remaining Capacity :17
#
# Bin type : 3 | Item ID : ['item196', 'item201', 'item693'] | Remaining Capacity :13
#
# Bin type : 3 | Item ID : ['item564', 'item388'] | Remaining Capacity :16
#
# Bin type : 2 | Item ID : ['item844', 'item217'] | Remaining Capacity :4
#
# Bin type : 1 | Item ID : ['item207'] | Remaining Capacity :16
#
# Bin type : 1 | Item ID : ['item210'] | Remaining Capacity :17
#
# Bin type : 1 | Item ID : ['item214', 'item387', 'item839'] | Remaining Capacity :0
#
# Bin type : 3 | Item ID : ['item215', 'item251', 'item869'] | Remaining Capacity :55
#
# Bin type : 2 | Item ID : ['item41'] | Remaining Capacity :13
#
# Bin type : 3 | Item ID : ['item218', 'item715', 'item703'] | Remaining Capacity :4
#
# Bin type : 3 | Item ID : ['item580', 'item772'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item221', 'item925'] | Remaining Capacity :2
#
# Bin type : 1 | Item ID : ['item626'] | Remaining Capacity :20
#
# Bin type : 3 | Item ID : ['item228', 'item422', 'item293'] | Remaining Capacity :19
#
# Bin type : 3 | Item ID : ['item622', 'item262', 'item894'] | Remaining Capacity :2
#
# Bin type : 1 | Item ID : ['item233'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item823'] | Remaining Capacity :7
#
# Bin type : 2 | Item ID : ['item577', 'item829'] | Remaining Capacity :9
#
# Bin type : 1 | Item ID : ['item239'] | Remaining Capacity :24
#
# Bin type : 3 | Item ID : ['item240', 'item285'] | Remaining Capacity :18
#
# Bin type : 3 | Item ID : ['item243', 'item948', 'item166'] | Remaining Capacity :16
#
# Bin type : 2 | Item ID : ['item246', 'item935', 'item378'] | Remaining Capacity :4
#
# Bin type : 3 | Item ID : ['item65', 'item698', 'item710'] | Remaining Capacity :25
#
# Bin type : 3 | Item ID : ['item252', 'item472'] | Remaining Capacity :6
#
# Bin type : 1 | Item ID : ['item258', 'item197', 'item647', 'item717'] | Remaining Capacity :18
#
# Bin type : 1 | Item ID : ['item848'] | Remaining Capacity :36
#
# Bin type : 1 | Item ID : ['item273', 'item318'] | Remaining Capacity :5
#
# Bin type : 1 | Item ID : ['item819'] | Remaining Capacity :24
#
# Bin type : 1 | Item ID : ['item277', 'item164'] | Remaining Capacity :10
#
# Bin type : 2 | Item ID : ['item281', 'item830'] | Remaining Capacity :30
#
# Bin type : 2 | Item ID : ['item726', 'item921'] | Remaining Capacity :6
#
# Bin type : 2 | Item ID : ['item360', 'item782'] | Remaining Capacity :9
#
# Bin type : 1 | Item ID : ['item362', 'item737'] | Remaining Capacity :13
#
# Bin type : 2 | Item ID : ['item317', 'item704', 'item195'] | Remaining Capacity :11
#
# Bin type : 3 | Item ID : ['item326', 'item335', 'item932'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item209', 'item947'] | Remaining Capacity :13
#
# Bin type : 2 | Item ID : ['item859'] | Remaining Capacity :46
#
# Bin type : 3 | Item ID : ['item339', 'item766'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item341', 'item984'] | Remaining Capacity :6
#
# Bin type : 2 | Item ID : ['item707', 'item692'] | Remaining Capacity :24
#
# Bin type : 3 | Item ID : ['item345', 'item579'] | Remaining Capacity :18
#
# Bin type : 2 | Item ID : ['item448'] | Remaining Capacity :18
#
# Bin type : 1 | Item ID : ['item369', 'item720'] | Remaining Capacity :16
#
# Bin type : 2 | Item ID : ['item438', 'item223'] | Remaining Capacity :3
#
# Bin type : 2 | Item ID : ['item144'] | Remaining Capacity :3
#
# Bin type : 2 | Item ID : ['item403', 'item802'] | Remaining Capacity :4
#
# Bin type : 3 | Item ID : ['item406', 'item401', 'item831'] | Remaining Capacity :10
#
# Bin type : 3 | Item ID : ['item408', 'item353', 'item954'] | Remaining Capacity :10
#
# Bin type : 1 | Item ID : ['item261', 'item711'] | Remaining Capacity :4
#
# Bin type : 1 | Item ID : ['item419', 'item852'] | Remaining Capacity :21
#
# Bin type : 1 | Item ID : ['item93'] | Remaining Capacity :5
#
# Bin type : 3 | Item ID : ['item938', 'item153'] | Remaining Capacity :18
#
# Bin type : 2 | Item ID : ['item424', 'item946', 'item687'] | Remaining Capacity :6
#
# Bin type : 2 | Item ID : ['item845'] | Remaining Capacity :15
#
# Bin type : 3 | Item ID : ['item431', 'item694', 'item527'] | Remaining Capacity :2
#
# Bin type : 2 | Item ID : ['item96'] | Remaining Capacity :2
#
# Bin type : 2 | Item ID : ['item441', 'item573'] | Remaining Capacity :4
#
# Bin type : 1 | Item ID : ['item442', 'item348'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item128', 'item691'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item111', 'item337', 'item846'] | Remaining Capacity :18
#
# Bin type : 2 | Item ID : ['item295'] | Remaining Capacity :23
#
# Bin type : 3 | Item ID : ['item456', 'item635'] | Remaining Capacity :18
#
# Bin type : 3 | Item ID : ['item951', 'item874', 'item185'] | Remaining Capacity :21
#
# Bin type : 1 | Item ID : ['item459', 'item810'] | Remaining Capacity :10
#
# Bin type : 1 | Item ID : ['item464', 'item279'] | Remaining Capacity :6
#
# Bin type : 1 | Item ID : ['item466', 'item349'] | Remaining Capacity :4
#
# Bin type : 2 | Item ID : ['item563'] | Remaining Capacity :41
#
# Bin type : 2 | Item ID : ['item806'] | Remaining Capacity :13
#
# Bin type : 2 | Item ID : ['item636', 'item92'] | Remaining Capacity :12
#
# Bin type : 2 | Item ID : ['item236', 'item509'] | Remaining Capacity :12
#
# Bin type : 2 | Item ID : ['item276'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item478', 'item533', 'item36', 'item2'] | Remaining Capacity :11
#
# Bin type : 1 | Item ID : ['item734'] | Remaining Capacity :13
#
# Bin type : 3 | Item ID : ['item481', 'item662', 'item82', 'item528'] | Remaining Capacity :5
#
# Bin type : 2 | Item ID : ['item487', 'item572'] | Remaining Capacity :12
#
# Bin type : 1 | Item ID : ['item51', 'item138'] | Remaining Capacity :7
#
# Bin type : 3 | Item ID : ['item494', 'item877'] | Remaining Capacity :13
#
# Bin type : 3 | Item ID : ['item834', 'item361'] | Remaining Capacity :20
#
# Bin type : 2 | Item ID : ['item507', 'item235', 'item901'] | Remaining Capacity :27
#
# Bin type : 3 | Item ID : ['item313', 'item485', 'item366'] | Remaining Capacity :13
#
# Bin type : 1 | Item ID : ['item519'] | Remaining Capacity :15
#
# Bin type : 2 | Item ID : ['item732', 'item957', 'item206'] | Remaining Capacity :2
#
# Bin type : 1 | Item ID : ['item526'] | Remaining Capacity :6
#
# Bin type : 2 | Item ID : ['item425', 'item323', 'item342'] | Remaining Capacity :3
#
# Bin type : 2 | Item ID : ['item540', 'item952'] | Remaining Capacity :2
#
# Bin type : 1 | Item ID : ['item541', 'item1000'] | Remaining Capacity :6
#
# Bin type : 1 | Item ID : ['item525'] | Remaining Capacity :4
#
# Bin type : 3 | Item ID : ['item428', 'item136', 'item513'] | Remaining Capacity :14
#
# Bin type : 1 | Item ID : ['item547', 'item997'] | Remaining Capacity :16
#
# Bin type : 1 | Item ID : ['item809'] | Remaining Capacity :8
#
# Bin type : 1 | Item ID : ['item550', 'item847', 'item420'] | Remaining Capacity :21
#
# Bin type : 1 | Item ID : ['item552', 'item794'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item160', 'item712', 'item483'] | Remaining Capacity :12
#
# Bin type : 1 | Item ID : ['item559', 'item480'] | Remaining Capacity :5
#
# Bin type : 1 | Item ID : ['item561', 'item265', 'item254'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item310', 'item395'] | Remaining Capacity :8
#
# Bin type : 2 | Item ID : ['item81', 'item142'] | Remaining Capacity :4
#
# Bin type : 1 | Item ID : ['item99'] | Remaining Capacity :4
#
# Bin type : 3 | Item ID : ['item575', 'item445'] | Remaining Capacity :37
#
# Bin type : 2 | Item ID : ['item556', 'item610'] | Remaining Capacity :4
#
# Bin type : 1 | Item ID : ['item52'] | Remaining Capacity :14
#
# Bin type : 1 | Item ID : ['item593', 'item357'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item172', 'item500'] | Remaining Capacity :18
#
# Bin type : 3 | Item ID : ['item597', 'item84', 'item474'] | Remaining Capacity :6
#
# Bin type : 2 | Item ID : ['item684'] | Remaining Capacity :2
#
# Bin type : 2 | Item ID : ['item768', 'item57', 'item639'] | Remaining Capacity :2
#
# Bin type : 1 | Item ID : ['item632'] | Remaining Capacity :7
#
# Bin type : 2 | Item ID : ['item651'] | Remaining Capacity :45
#
# Bin type : 1 | Item ID : ['item700', 'item248'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item562', 'item680'] | Remaining Capacity :0
#
# Bin type : 2 | Item ID : ['item613'] | Remaining Capacity :43
#
# Bin type : 1 | Item ID : ['item618', 'item85'] | Remaining Capacity :8
#
# Bin type : 1 | Item ID : ['item798', 'item699'] | Remaining Capacity :24
#
# Bin type : 2 | Item ID : ['item267', 'item801'] | Remaining Capacity :5
#
# Bin type : 3 | Item ID : ['item646', 'item742', 'item617'] | Remaining Capacity :14
#
# Bin type : 3 | Item ID : ['item203', 'item321'] | Remaining Capacity :6
#
# Bin type : 2 | Item ID : ['item192', 'item35', 'item747'] | Remaining Capacity :15
#
# Bin type : 1 | Item ID : ['item520', 'item966'] | Remaining Capacity :18
#
# Bin type : 2 | Item ID : ['item204', 'item718', 'item761'] | Remaining Capacity :4
#
# Bin type : 2 | Item ID : ['item653', 'item708'] | Remaining Capacity :3
#
# Bin type : 1 | Item ID : ['item130', 'item332', 'item189'] | Remaining Capacity :13
#
# Bin type : 3 | Item ID : ['item621', 'item969'] | Remaining Capacity :12
#
# Bin type : 3 | Item ID : ['item915', 'item868', 'item596'] | Remaining Capacity :5
#
# Bin type : 2 | Item ID : ['item664', 'item432'] | Remaining Capacity :0
#
# Bin type : 2 | Item ID : ['item665', 'item415', 'item147'] | Remaining Capacity :6
#
# Bin type : 3 | Item ID : ['item916', 'item270'] | Remaining Capacity :8
#
# Bin type : 1 | Item ID : ['item678', 'item515'] | Remaining Capacity :4
#
# Bin type : 1 | Item ID : ['item679', 'item889'] | Remaining Capacity :4
#
# Bin type : 3 | Item ID : ['item790', 'item599'] | Remaining Capacity :13
#
# Bin type : 3 | Item ID : ['item862', 'item188'] | Remaining Capacity :6
#
# Bin type : 2 | Item ID : ['item696', 'item95', 'item37'] | Remaining Capacity :29
#
# Bin type : 2 | Item ID : ['item697', 'item861'] | Remaining Capacity :4
#
# Bin type : 3 | Item ID : ['item992', 'item668', 'item356'] | Remaining Capacity :15
#
# Bin type : 2 | Item ID : ['item534', 'item129'] | Remaining Capacity :6
#
# Bin type : 1 | Item ID : ['item328', 'item760'] | Remaining Capacity :11
#
# Bin type : 2 | Item ID : ['item586', 'item989'] | Remaining Capacity :0
#
# Bin type : 1 | Item ID : ['item414'] | Remaining Capacity :15
#
# Bin type : 3 | Item ID : ['item60', 'item535', 'item567'] | Remaining Capacity :9
#
# Bin type : 2 | Item ID : ['item553', 'item873'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item730', 'item385', 'item551'] | Remaining Capacity :54
#
# Bin type : 2 | Item ID : ['item731', 'item191'] | Remaining Capacity :2
#
# Bin type : 2 | Item ID : ['item671', 'item956'] | Remaining Capacity :7
#
# Bin type : 3 | Item ID : ['item633', 'item314'] | Remaining Capacity :7
#
# Bin type : 1 | Item ID : ['item112'] | Remaining Capacity :17
#
# Bin type : 2 | Item ID : ['item750', 'item66', 'item941', 'item842'] | Remaining Capacity :3
#
# Bin type : 2 | Item ID : ['item755', 'item234', 'item495'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item146'] | Remaining Capacity :19
#
# Bin type : 3 | Item ID : ['item232', 'item190'] | Remaining Capacity :40
#
# Bin type : 3 | Item ID : ['item771', 'item177', 'item463', 'item799'] | Remaining Capacity :6
#
# Bin type : 3 | Item ID : ['item22', 'item113', 'item776', 'item922'] | Remaining Capacity :23
#
# Bin type : 3 | Item ID : ['item800', 'item675', 'item256'] | Remaining Capacity :13
#
# Bin type : 3 | Item ID : ['item812', 'item663'] | Remaining Capacity :12
#
# Bin type : 1 | Item ID : ['item517', 'item660'] | Remaining Capacity :4
#
# Bin type : 1 | Item ID : ['item820'] | Remaining Capacity :33
#
# Bin type : 2 | Item ID : ['item824', 'item389', 'item988'] | Remaining Capacity :11
#
# Bin type : 3 | Item ID : ['item826', 'item864', 'item171', 'item649', 'item973'] | Remaining Capacity :29
#
# Bin type : 3 | Item ID : ['item15', 'item650'] | Remaining Capacity :2
#
# Bin type : 3 | Item ID : ['item841', 'item382', 'item384'] | Remaining Capacity :15
#
# Bin type : 1 | Item ID : ['item29'] | Remaining Capacity :3
#
# Bin type : 3 | Item ID : ['item843', 'item624', 'item470'] | Remaining Capacity :19
#
# Bin type : 2 | Item ID : ['item451'] | Remaining Capacity :28
#
# Bin type : 1 | Item ID : ['item855', 'item484', 'item814'] | Remaining Capacity :17
#
# Bin type : 2 | Item ID : ['item975', 'item72'] | Remaining Capacity :9
#
# Bin type : 1 | Item ID : ['item860'] | Remaining Capacity :3
#
# Bin type : 1 | Item ID : ['item364'] | Remaining Capacity :18
#
# Bin type : 2 | Item ID : ['item713', 'item490', 'item640'] | Remaining Capacity :18
#
# Bin type : 3 | Item ID : ['item795', 'item363'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item355', 'item920', 'item612'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item536'] | Remaining Capacity :16
#
# Bin type : 3 | Item ID : ['item887', 'item585', 'item594'] | Remaining Capacity :8
#
# Bin type : 1 | Item ID : ['item555', 'item689', 'item607'] | Remaining Capacity :10
#
# Bin type : 2 | Item ID : ['item896', 'item430', 'item979', 'item749'] | Remaining Capacity :4
#
# Bin type : 1 | Item ID : ['item89'] | Remaining Capacity :8
#
# Bin type : 1 | Item ID : ['item908'] | Remaining Capacity :14
#
# Bin type : 2 | Item ID : ['item12'] | Remaining Capacity :2
#
# Bin type : 2 | Item ID : ['item135'] | Remaining Capacity :9
#
# Bin type : 1 | Item ID : ['item872'] | Remaining Capacity :25
#
# Bin type : 1 | Item ID : ['item923'] | Remaining Capacity :5
#
# Bin type : 2 | Item ID : ['item825', 'item67'] | Remaining Capacity :3
#
# Bin type : 2 | Item ID : ['item379'] | Remaining Capacity :31
#
# Bin type : 3 | Item ID : ['item418', 'item642'] | Remaining Capacity :7
#
# Bin type : 3 | Item ID : ['item955', 'item625', 'item280'] | Remaining Capacity :16
#
# Bin type : 1 | Item ID : ['item198', 'item311', 'item489'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item74', 'item404'] | Remaining Capacity :9
#
# Bin type : 1 | Item ID : ['item739', 'item784'] | Remaining Capacity :19
#
# Bin type : 1 | Item ID : ['item616'] | Remaining Capacity :12
#
# Bin type : 2 | Item ID : ['item967', 'item38', 'item109'] | Remaining Capacity :7
#
# Bin type : 3 | Item ID : ['item972', 'item821', 'item497'] | Remaining Capacity :7
#
# Bin type : 1 | Item ID : ['item437', 'item598'] | Remaining Capacity :25
#
# Bin type : 3 | Item ID : ['item985', 'item435', 'item897'] | Remaining Capacity :5
#
# Bin type : 2 | Item ID : ['item376'] | Remaining Capacity :11
#
# Bin type : 1 | Item ID : ['item986'] | Remaining Capacity :27
#
# Bin type : 3 | Item ID : ['item900', 'item133'] | Remaining Capacity :10
#
# Bin type : 2 | Item ID : ['item961', 'item231', 'item743'] | Remaining Capacity :17
#
# Bin type : 1 | Item ID : ['item991'] | Remaining Capacity :8
#
# Bin type : 2 | Item ID : ['item803'] | Remaining Capacity :16
#
# Bin type : 3 | Item ID : ['item994', 'item101'] | Remaining Capacity :16
#
# Bin type : 3 | Item ID : ['item709', 'item26'] | Remaining Capacity :2
#
# Bin type : 1 | Item ID : ['item987'] | Remaining Capacity :26
#
# Bin type : 1 | Item ID : ['item458'] | Remaining Capacity :16
#
# Bin type : 2 | Item ID : ['item965'] | Remaining Capacity :4
#
# Bin type : 3 | Item ID : ['item676', 'item558', 'item468'] | Remaining Capacity :3
#
# Bin type : 3 | Item ID : ['item373', 'item477'] | Remaining Capacity :1
#
# Bin type : 1 | Item ID : ['item393'] | Remaining Capacity :26
#
# Bin type : 1 | Item ID : ['item783'] | Remaining Capacity :24
#
# Bin type : 1 | Item ID : ['item410'] | Remaining Capacity :6
#
# Bin type : 3 | Item ID : ['item754', 'item444', 'item380', 'item970'] | Remaining Capacity :4
#
# Bin type : 1 | Item ID : ['item959'] | Remaining Capacity :8
#
# Bin type : 2 | Item ID : ['item510'] | Remaining Capacity :14
#
# Bin type : 3 | Item ID : ['item140', 'item200', 'item863'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item269', 'item619', 'item998'] | Remaining Capacity :10
#
# Bin type : 3 | Item ID : ['item103', 'item644', 'item116'] | Remaining Capacity :11
#
# Bin type : 2 | Item ID : ['item245', 'item958'] | Remaining Capacity :2
#
# Bin type : 3 | Item ID : ['item42', 'item213', 'item865'] | Remaining Capacity :6
#
# Bin type : 3 | Item ID : ['item787'] | Remaining Capacity :60
#
# Bin type : 2 | Item ID : ['item302'] | Remaining Capacity :30
#
# Bin type : 2 | Item ID : ['item368', 'item763'] | Remaining Capacity :8
#
# Bin type : 2 | Item ID : ['item465', 'item202'] | Remaining Capacity :13
#
# Bin type : 3 | Item ID : ['item878', 'item706'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item48', 'item56'] | Remaining Capacity :5
#
# Bin type : 3 | Item ID : ['item854', 'item427', 'item329'] | Remaining Capacity :16
#
# Bin type : 1 | Item ID : ['item858'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item837', 'item167'] | Remaining Capacity :5
#
# Bin type : 3 | Item ID : ['item359', 'item475'] | Remaining Capacity :5
#
# Bin type : 2 | Item ID : ['item940'] | Remaining Capacity :3
#
# Bin type : 3 | Item ID : ['item669', 'item257', 'item327'] | Remaining Capacity :19
#
# Bin type : 3 | Item ID : ['item723', 'item899'] | Remaining Capacity :15
#
# Bin type : 1 | Item ID : ['item69', 'item781'] | Remaining Capacity :7
#
# Bin type : 2 | Item ID : ['item506'] | Remaining Capacity :7
#
# Bin type : 2 | Item ID : ['item230'] | Remaining Capacity :3
#
# Bin type : 3 | Item ID : ['item560', 'item615', 'item352', 'item44', 'item40'] | Remaining Capacity :8
#
# Bin type : 2 | Item ID : ['item522', 'item981'] | Remaining Capacity :11
#
# Bin type : 2 | Item ID : ['item603'] | Remaining Capacity :41
#
# Bin type : 3 | Item ID : ['item14', 'item838'] | Remaining Capacity :2
#
# Bin type : 3 | Item ID : ['item344', 'item578'] | Remaining Capacity :30
#
# Bin type : 2 | Item ID : ['item371', 'item735'] | Remaining Capacity :7
#
# Bin type : 2 | Item ID : ['item455', 'item398', 'item652'] | Remaining Capacity :24
#
# Bin type : 2 | Item ID : ['item399'] | Remaining Capacity :17
#
# Bin type : 3 | Item ID : ['item184', 'item291', 'item5'] | Remaining Capacity :8
#
# Bin type : 1 | Item ID : ['item719', 'item377'] | Remaining Capacity :11
#
# Bin type : 2 | Item ID : ['item374', 'item570'] | Remaining Capacity :11
#
# Bin type : 3 | Item ID : ['item685', 'item778'] | Remaining Capacity :2
#
# Bin type : 2 | Item ID : ['item681', 'item716'] | Remaining Capacity :41
#
# Bin type : 3 | Item ID : ['item516', 'item148', 'item340', 'item161'] | Remaining Capacity :14
#
# Bin type : 3 | Item ID : ['item331', 'item199'] | Remaining Capacity :2
#
# Bin type : 2 | Item ID : ['item548'] | Remaining Capacity :24
#
# Bin type : 2 | Item ID : ['item152', 'item643'] | Remaining Capacity :11
#
# Bin type : 2 | Item ID : ['item762'] | Remaining Capacity :7
#
# Bin type : 2 | Item ID : ['item47'] | Remaining Capacity :16
#
# Bin type : 3 | Item ID : ['item365', 'item971', 'item290'] | Remaining Capacity :8
#
# Bin type : 2 | Item ID : ['item883'] | Remaining Capacity :3
#
# Bin type : 2 | Item ID : ['item917', 'item661'] | Remaining Capacity :9
#
# Bin type : 2 | Item ID : ['item301'] | Remaining Capacity :25
#
# Bin type : 2 | Item ID : ['item119'] | Remaining Capacity :18
#
# Bin type : 2 | Item ID : ['item151', 'item690'] | Remaining Capacity :7
#
# Bin type : 3 | Item ID : ['item544', 'item471'] | Remaining Capacity :9
#
# Bin type : 3 | Item ID : ['item457', 'item890'] | Remaining Capacity :8
#
# Bin type : 3 | Item ID : ['item721', 'item600'] | Remaining Capacity :15
#
# Bin type : 2 | Item ID : ['item583'] | Remaining Capacity :16
#
# Bin type : 1 | Item ID : ['item758'] | Remaining Capacity :3
#
# Bin type : 3 | Item ID : ['item350', 'item514'] | Remaining Capacity :16
#
# Bin type : 2 | Item ID : ['item31'] | Remaining Capacity :19
#
# Bin type : 3 | Item ID : ['item493', 'item45'] | Remaining Capacity :16
#
# Bin type : 3 | Item ID : ['item786', 'item815', 'item953'] | Remaining Capacity :10
#
# Bin type : 2 | Item ID : ['item733'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item396', 'item13'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item17', 'item930', 'item587'] | Remaining Capacity :4
#
# Bin type : 2 | Item ID : ['item736', 'item416'] | Remaining Capacity :5
#
# Bin type : 1 | Item ID : ['item237'] | Remaining Capacity :15
#
# Bin type : 3 | Item ID : ['item308', 'item127'] | Remaining Capacity :13
#
# Bin type : 2 | Item ID : ['item999'] | Remaining Capacity :30
#
# Bin type : 3 | Item ID : ['item565', 'item590'] | Remaining Capacity :2
#
# Bin type : 2 | Item ID : ['item780'] | Remaining Capacity :4
#
# Bin type : 2 | Item ID : ['item537', 'item764'] | Remaining Capacity :13
#
# Bin type : 3 | Item ID : ['item501', 'item893'] | Remaining Capacity :4
#
# Bin type : 2 | Item ID : ['item543', 'item811'] | Remaining Capacity :8
#
# Bin type : 3 | Item ID : ['item499', 'item774'] | Remaining Capacity :2
#
# Bin type : 3 | Item ID : ['item242', 'item176'] | Remaining Capacity :59
#
# Bin type : 1 | Item ID : ['item336'] | Remaining Capacity :8
#
# Bin type : 1 | Item ID : ['item417', 'item968'] | Remaining Capacity :10
#
# Bin type : 2 | Item ID : ['item773', 'item106'] | Remaining Capacity :4
#
# Bin type : 2 | Item ID : ['item461', 'item91'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item777', 'item105'] | Remaining Capacity :13
#
# Bin type : 2 | Item ID : ['item881', 'item654'] | Remaining Capacity :6
#
# Bin type : 3 | Item ID : ['item39', 'item502'] | Remaining Capacity :2
#
# Bin type : 3 | Item ID : ['item149', 'item255'] | Remaining Capacity :4
#
# Bin type : 3 | Item ID : ['item542', 'item78'] | Remaining Capacity :14
#
# Bin type : 3 | Item ID : ['item297', 'item637', 'item807'] | Remaining Capacity :7
#
# Bin type : 2 | Item ID : ['item123'] | Remaining Capacity :9
#
# Bin type : 3 | Item ID : ['item905', 'item253'] | Remaining Capacity :19
#
# Bin type : 3 | Item ID : ['item614', 'item767'] | Remaining Capacity :6
#
# Bin type : 3 | Item ID : ['item532', 'item294'] | Remaining Capacity :5
#
# Bin type : 1 | Item ID : ['item568', 'item702'] | Remaining Capacity :19
#
# Bin type : 1 | Item ID : ['item307'] | Remaining Capacity :22
#
# Bin type : 1 | Item ID : ['item670'] | Remaining Capacity :12
#
# Bin type : 2 | Item ID : ['item796'] | Remaining Capacity :28
#
# Bin type : 2 | Item ID : ['item98', 'item134'] | Remaining Capacity :9
#
# Bin type : 2 | Item ID : ['item496'] | Remaining Capacity :8
#
# Bin type : 1 | Item ID : ['item943', 'item346'] | Remaining Capacity :21
#
# Bin type : 2 | Item ID : ['item436'] | Remaining Capacity :6
#
# Bin type : 3 | Item ID : ['item508', 'item315'] | Remaining Capacity :4
#
# Bin type : 3 | Item ID : ['item602', 'item462', 'item68'] | Remaining Capacity :2
#
# Bin type : 2 | Item ID : ['item19'] | Remaining Capacity :8
#
# Bin type : 2 | Item ID : ['item298'] | Remaining Capacity :3
#
# Bin type : 3 | Item ID : ['item288', 'item287', 'item168'] | Remaining Capacity :2
#
# Bin type : 2 | Item ID : ['item250'] | Remaining Capacity :11
#
# Bin type : 3 | Item ID : ['item934', 'item412', 'item683'] | Remaining Capacity :16
#
# Bin type : 3 | Item ID : ['item623', 'item589'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item286', 'item11', 'item205'] | Remaining Capacity :14
#
# Bin type : 3 | Item ID : ['item641', 'item789'] | Remaining Capacity :2
#
# Bin type : 2 | Item ID : ['item929'] | Remaining Capacity :40
#
# Bin type : 2 | Item ID : ['item822'] | Remaining Capacity :36
#
# Bin type : 2 | Item ID : ['item983', 'item413'] | Remaining Capacity :6
#
# Bin type : 3 | Item ID : ['item518', 'item283'] | Remaining Capacity :9
#
# Bin type : 2 | Item ID : ['item885', 'item333'] | Remaining Capacity :3
#
# Bin type : 3 | Item ID : ['item672', 'item32'] | Remaining Capacity :20
#
# Bin type : 3 | Item ID : ['item325', 'item266'] | Remaining Capacity :5
#
# Bin type : 1 | Item ID : ['item219'] | Remaining Capacity :8
#
# Bin type : 1 | Item ID : ['item6'] | Remaining Capacity :5
#
# Bin type : 2 | Item ID : ['item949'] | Remaining Capacity :34
#
# Bin type : 2 | Item ID : ['item906'] | Remaining Capacity :11
#
# Bin type : 3 | Item ID : ['item289', 'item530'] | Remaining Capacity :16
#
# Bin type : 3 | Item ID : ['item486', 'item247'] | Remaining Capacity :9
#
# Bin type : 3 | Item ID : ['item833', 'item338'] | Remaining Capacity :5
#
# Bin type : 3 | Item ID : ['item114', 'item714'] | Remaining Capacity :13
#
# Bin type : 2 | Item ID : ['item386'] | Remaining Capacity :4
#
# Bin type : 1 | Item ID : ['item59'] | Remaining Capacity :5
#
# Bin type : 3 | Item ID : ['item224', 'item931', 'item170'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item944', 'item539', 'item488'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item898'] | Remaining Capacity :4
#
# Bin type : 3 | Item ID : ['item645', 'item178', 'item655'] | Remaining Capacity :8
#
# Bin type : 3 | Item ID : ['item107', 'item284'] | Remaining Capacity :4
#
# Bin type : 2 | Item ID : ['item634'] | Remaining Capacity :7
#
# Bin type : 2 | Item ID : ['item450'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item165', 'item375', 'item705'] | Remaining Capacity :9
#
# Bin type : 2 | Item ID : ['item440'] | Remaining Capacity :23
#
# Bin type : 2 | Item ID : ['item918'] | Remaining Capacity :24
#
# Bin type : 3 | Item ID : ['item20', 'item995'] | Remaining Capacity :6
#
# Bin type : 3 | Item ID : ['item751', 'item538'] | Remaining Capacity :6
#
# Bin type : 2 | Item ID : ['item330', 'item962'] | Remaining Capacity :33
#
# Bin type : 2 | Item ID : ['item574', 'item249'] | Remaining Capacity :7
#
# Bin type : 2 | Item ID : ['item695', 'item588'] | Remaining Capacity :4
#
# Bin type : 2 | Item ID : ['item292'] | Remaining Capacity :4
#
# Bin type : 2 | Item ID : ['item263'] | Remaining Capacity :3
#
# Bin type : 3 | Item ID : ['item836', 'item405'] | Remaining Capacity :5
#
# Bin type : 2 | Item ID : ['item402'] | Remaining Capacity :21
#
# Bin type : 3 | Item ID : ['item354'] | Remaining Capacity :52
#
# Bin type : 1 | Item ID : ['item792', 'item765'] | Remaining Capacity :17
#
# Bin type : 2 | Item ID : ['item886'] | Remaining Capacity :18
#
# Bin type : 3 | Item ID : ['item222', 'item512'] | Remaining Capacity :2
#
# Bin type : 2 | Item ID : ['item268'] | Remaining Capacity :13
#
# Bin type : 3 | Item ID : ['item179', 'item884'] | Remaining Capacity :12
#
# Bin type : 3 | Item ID : ['item271', 'item383'] | Remaining Capacity :55
#
# Bin type : 1 | Item ID : ['item791'] | Remaining Capacity :0
#
# Bin type : 2 | Item ID : ['item33', 'item452'] | Remaining Capacity :3
#
# Bin type : 2 | Item ID : ['item226'] | Remaining Capacity :11
#
# Bin type : 3 | Item ID : ['item631', 'item856', 'item433'] | Remaining Capacity :16
#
# Bin type : 2 | Item ID : ['item980'] | Remaining Capacity :28
#
# Bin type : 3 | Item ID : ['item358', 'item605'] | Remaining Capacity :2
#
# Bin type : 2 | Item ID : ['item769'] | Remaining Capacity :4
#
# Bin type : 3 | Item ID : ['item867', 'item504'] | Remaining Capacity :14
#
# Bin type : 2 | Item ID : ['item996'] | Remaining Capacity :4
#
# Bin type : 3 | Item ID : ['item46', 'item870'] | Remaining Capacity :17
#
# Bin type : 3 | Item ID : ['item334', 'item447'] | Remaining Capacity :2
#
# Bin type : 2 | Item ID : ['item211', 'item238'] | Remaining Capacity :36
#
# Bin type : 1 | Item ID : ['item320'] | Remaining Capacity :25
#
# Bin type : 2 | Item ID : ['item367'] | Remaining Capacity :4
#
# Bin type : 2 | Item ID : ['item73'] | Remaining Capacity :10
#
# Bin type : 2 | Item ID : ['item686'] | Remaining Capacity :4
#
# Bin type : 3 | Item ID : ['item132'] | Remaining Capacity :58
#
# Bin type : 2 | Item ID : ['item467'] | Remaining Capacity :12
#
# Bin type : 1 | Item ID : ['item936'] | Remaining Capacity :5
#
# Bin type : 1 | Item ID : ['item274', 'item122'] | Remaining Capacity :13
#
# Bin type : 3 | Item ID : ['item993', 'item423'] | Remaining Capacity :37
#
# Bin type : 2 | Item ID : ['item264'] | Remaining Capacity :5
#
# Bin type : 3 | Item ID : ['item584', 'item141'] | Remaining Capacity :3
#
# Bin type : 3 | Item ID : ['item90'] | Remaining Capacity :55
#
# Bin type : 2 | Item ID : ['item529'] | Remaining Capacity :20
#
# Bin type : 2 | Item ID : ['item871'] | Remaining Capacity :5
#
# Bin type : 2 | Item ID : ['item322'] | Remaining Capacity :9
#
# Bin type : 2 | Item ID : ['item775'] | Remaining Capacity :4
#
# Bin type : 3 | Item ID : ['item928', 'item143'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item120', 'item411'] | Remaining Capacity :2
#
# Bin type : 2 | Item ID : ['item443'] | Remaining Capacity :9
#
# Bin type : 3 | Item ID : ['item595', 'item659'] | Remaining Capacity :2
#
# Bin type : 2 | Item ID : ['item454'] | Remaining Capacity :0
#
# Bin type : 2 | Item ID : ['item840'] | Remaining Capacity :0
#
# Bin type : 2 | Item ID : ['item857'] | Remaining Capacity :11
#
# Bin type : 2 | Item ID : ['item608'] | Remaining Capacity :9
#
# Bin type : 3 | Item ID : ['item756', 'item927'] | Remaining Capacity :17
#
# Bin type : 2 | Item ID : ['item220'] | Remaining Capacity :47
#
# Bin type : 2 | Item ID : ['item974'] | Remaining Capacity :6
#
# Bin type : 2 | Item ID : ['item118'] | Remaining Capacity :11
#
# Bin type : 1 | Item ID : ['item913'] | Remaining Capacity :9
#
# Bin type : 3 | Item ID : ['item351', 'item186'] | Remaining Capacity :10
#
# Bin type : 3 | Item ID : ['item187', 'item892'] | Remaining Capacity :3
#
# Bin type : 2 | Item ID : ['item421'] | Remaining Capacity :25
#
# Bin type : 2 | Item ID : ['item990'] | Remaining Capacity :11
#
# Bin type : 2 | Item ID : ['item912', 'item394'] | Remaining Capacity :7
#
# Bin type : 2 | Item ID : ['item319'] | Remaining Capacity :13
#
# Bin type : 2 | Item ID : ['item4'] | Remaining Capacity :26
#
# Bin type : 3 | Item ID : ['item752', 'item409'] | Remaining Capacity :14
#
# Bin type : 2 | Item ID : ['item832'] | Remaining Capacity :32
#
# Bin type : 2 | Item ID : ['item86'] | Remaining Capacity :7
#
# Bin type : 3 | Item ID : ['item110', 'item609'] | Remaining Capacity :4
#
# Bin type : 3 | Item ID : ['item942', 'item83', 'item426'] | Remaining Capacity :3
#
# Bin type : 2 | Item ID : ['item439', 'item108'] | Remaining Capacity :7
#
# Bin type : 3 | Item ID : ['item212', 'item312'] | Remaining Capacity :2
#
# Bin type : 3 | Item ID : ['item482', 'item740'] | Remaining Capacity :2
#
# Bin type : 2 | Item ID : ['item523'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item638'] | Remaining Capacity :3
#
# Bin type : 3 | Item ID : ['item937', 'item808'] | Remaining Capacity :8
#
# Bin type : 2 | Item ID : ['item94'] | Remaining Capacity :6
#
# Bin type : 2 | Item ID : ['item390'] | Remaining Capacity :2
#
# Bin type : 1 | Item ID : ['item300'] | Remaining Capacity :5
#
# Bin type : 3 | Item ID : ['item914', 'item9'] | Remaining Capacity :4
#
# Bin type : 3 | Item ID : ['item183', 'item604'] | Remaining Capacity :24
#
# Bin type : 3 | Item ID : ['item648', 'item306'] | Remaining Capacity :7
#
# Bin type : 3 | Item ID : ['item677', 'item241'] | Remaining Capacity :4
#
# Bin type : 3 | Item ID : ['item503', 'item216'] | Remaining Capacity :43
#
# Bin type : 2 | Item ID : ['item491'] | Remaining Capacity :10
#
# Bin type : 3 | Item ID : ['item278', 'item627'] | Remaining Capacity :10
#
# Bin type : 2 | Item ID : ['item372'] | Remaining Capacity :8
#
# Bin type : 3 | Item ID : ['item753', 'item8'] | Remaining Capacity :4
#
# Bin type : 3 | Item ID : ['item850', 'item34'] | Remaining Capacity :4
#
# Bin type : 3 | Item ID : ['item933', 'item229'] | Remaining Capacity :4
#
# Bin type : 3 | Item ID : ['item80', 'item611'] | Remaining Capacity :16
#
# Bin type : 3 | Item ID : ['item554', 'item479'] | Remaining Capacity :32
#
# Bin type : 3 | Item ID : ['item851', 'item453'] | Remaining Capacity :16
#
# Bin type : 3 | Item ID : ['item227', 'item963'] | Remaining Capacity :3
#
# Bin type : 3 | Item ID : ['item724', 'item347'] | Remaining Capacity :13
#
# Bin type : 3 | Item ID : ['item629', 'item745'] | Remaining Capacity :16
#
# Bin type : 3 | Item ID : ['item907', 'item657', 'item316'] | Remaining Capacity :4
#
# Bin type : 2 | Item ID : ['item28'] | Remaining Capacity :7
#
# Bin type : 3 | Item ID : ['item275', 'item910'] | Remaining Capacity :22
#
# Bin type : 2 | Item ID : ['item827'] | Remaining Capacity :2
#
# Bin type : 3 | Item ID : ['item727', 'item757'] | Remaining Capacity :9
#
# Bin type : 2 | Item ID : ['item158'] | Remaining Capacity :6
#
# Bin type : 2 | Item ID : ['item156'] | Remaining Capacity :28
#
# Bin type : 2 | Item ID : ['item309'] | Remaining Capacity :15
#
# Bin type : 2 | Item ID : ['item748'] | Remaining Capacity :13
#
# Bin type : 3 | Item ID : ['item392'] | Remaining Capacity :53
#
# Bin type : 2 | Item ID : ['item49'] | Remaining Capacity :4
#
# Bin type : 2 | Item ID : ['item785'] | Remaining Capacity :1
#
# Bin type : 2 | Item ID : ['item682'] | Remaining Capacity :11
#
# Bin type : 3 | Item ID : ['item804', 'item473'] | Remaining Capacity :2
#
# Bin type : 3 | Item ID : ['item793', 'item446', 'item576'] | Remaining Capacity :15
#
# Bin type : 2 | Item ID : ['item449', 'item10'] | Remaining Capacity :16
#
# Bin type : 3 | Item ID : ['item498', 'item460'] | Remaining Capacity :3
#
# Bin type : 3 | Item ID : ['item828', 'item531'] | Remaining Capacity :15
#
# Bin type : 3 | Item ID : ['item797', 'item391'] | Remaining Capacity :11
#
# Bin type : 2 | Item ID : ['item738', 'item606'] | Remaining Capacity :18
#
# Bin type : 2 | Item ID : ['item208'] | Remaining Capacity :19
#
# Bin type : 3 | Item ID : ['item674', 'item304'] | Remaining Capacity :7
#
# Bin type : 2 | Item ID : ['item911'] | Remaining Capacity :14
#
# Bin type : 2 | Item ID : ['item909'] | Remaining Capacity :16
#
# Bin type : 2 | Item ID : ['item566'] | Remaining Capacity :21
#
# Bin type : 2 | Item ID : ['item701', 'item569'] | Remaining Capacity :16
#
# Bin type : 3 | Item ID : ['item174', 'item77'] | Remaining Capacity :3
#
# Bin type : 2 | Item ID : ['item163'] | Remaining Capacity :3
#
# Bin type : 2 | Item ID : ['item54'] | Remaining Capacity :5
#
# Bin type : 2 | Item ID : ['item725'] | Remaining Capacity :22
#
# Bin type : 3 | Item ID : ['item950', 'item729'] | Remaining Capacity :4
#
# Bin type : 3 | Item ID : ['item895', 'item581'] | Remaining Capacity :4
#
# Bin type : 2 | Item ID : ['item549'] | Remaining Capacity :26
#
# Bin type : 3 | Item ID : ['item182', 'item688'] | Remaining Capacity :16
#
# Bin type : 3 | Item ID : ['item902', 'item926'] | Remaining Capacity :29
#
# Bin type : 2 | Item ID : ['item259'] | Remaining Capacity :1
#
# Bin type : 3 | Item ID : ['item370', 'item244'] | Remaining Capacity :3
#
# Bin type : 3 | Item ID : ['item7', 'item960'] | Remaining Capacity :9
#
# Bin type : 3 | Item ID : ['item524', 'item816'] | Remaining Capacity :7
#
# Bin type : 3 | Item ID : ['item305'] | Remaining Capacity :50
#
# Bin type : 3 | Item ID : ['item343', 'item124'] | Remaining Capacity :15
#
# Bin type : 2 | Item ID : ['item102'] | Remaining Capacity :20
#
# Bin type : 2 | Item ID : ['item282'] | Remaining Capacity :6
#
# Bin type : 2 | Item ID : ['item817'] | Remaining Capacity :18
#
# Bin type : 2 | Item ID : ['item978'] | Remaining Capacity :33

# %%
print(f"N1 | Cost = {N1_COST} | Bins = {N1_BINS} | Time = {N1_TIME}")
print(f"N1 and N4 | Cost = {N1N4_COST} | Bins = {N1N4_BINS} | Time ={N1N4_TIME}")
print(f"N1 and LS | Cost = {N1N4N5N6_COST} | Bins = {N1N4N5N6_BINS} | Time ={N1N4N5N6_TIME}")
print(f"N1,N2 and LS | Cost = {N1N2LS_COST} | Bins = {N1N2LS_BINS} | Time ={N1N2LS_TIME}")
# Out:
# N1 | Cost = 58170 | Bins = 530 | Time = 23.004274368286133
# N1 and N4 | Cost = 52360 | Bins = 448 | Time =42.11266231536865
# N1 and LS | Cost = 52190 | Bins = 461 | Time =31.428625106811523
# N1,N2 and LS | Cost = 52170 | Bins = 466 | Time =47.69585180282593

# %%
# sys.stdout = old_stdout

# log_file.close()
